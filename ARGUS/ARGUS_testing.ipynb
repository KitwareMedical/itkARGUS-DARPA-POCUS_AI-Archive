# %%
import os
import glob

import numpy as np

import itk

import site
site.addsitedir("../ARGUS")

from ARGUS_IO import *

from ARGUS_app_ai import ARGUS_app_ai

# %%
vids = glob.glob("./POCUS AI Test Data/ETT Test Data/*.mp4")
app_ai = ARGUS_app_ai(source="Butterfly")
for vid in vids:
    #try:
    result = app_ai.predict(vid, task="ETT")
    print("")
    #except:
        #print("******* An exception occurred **********")
        #print("")
# Out:
# File: ./POCUS AI Test Data/ETT Test Data\1.mp4
#    Time for Read Video: Read from disk is 0.9256136999999853
#    Time for Read Video is 0.9257247000000461
#    Task: ETT
#    Time for Preprocess for AR is 3.000000106112566e-06
#    Time for Preprocess AR Inference is 3.000000106112566e-07
#    Time for Preprocess for ROI is 0.7504569000000174
#    Time for Preprocess Video is 0.7505974999999125
# Short video: reducing search size min
#    Time for Process Video: ROI Inference is 3.574216799999931
#    Time for Process Video: Decision is 3.600000127335079e-06
#    Time for Process Video is 3.5743468999999095
#    Time for all is 5.250713500000074
#    Prediction: 1
#       Confidence Measure 0: 8
#       Confidence Measure 1: 4
#
# File: ./POCUS AI Test Data/ETT Test Data\10.mp4
#    Time for Read Video: Read from disk is 7.504011799999944
#    Time for Read Video is 7.504183799999964
#    Task: ETT
#    Time for Preprocess for AR is 3.800000058618025e-06
# ...

# %%
vids = glob.glob("./POCUS AI Test Data/PNB Test Data/*.mp4")
app_ai = ARGUS_app_ai(source="Butterfly")
for vid in vids:
    #try:
    result = app_ai.predict(vid, task="PNB")
    print("")
    #except:
        #print("******* An exception occurred **********")
        #print("")
# Out:
# File: ./POCUS AI Test Data/PNB Test Data\1.mp4
#    Time for Read Video: Read from disk is 2.9277149000000016
#    Time for Read Video is 2.9278267000000007
#    Task: PNB
#    Time for Preprocess for AR is 1.6106613000000003
# Class 1 probability adjustments = 0
# Class 1 probability adjustments = 0
# Class 1 probability adjustments = 0
# Class 1 probability adjustments = 0
#    Time for Preprocess AR Inference is 0.22141990000000078
#    Time for Preprocess for ROI is 8.999999998593466e-07
#    Time for Preprocess Video is 1.8323666000000003
#    Time for Process Video: ROI Inference is 0.01282409999999956
#    Time for Process Video: Decision is 2.69999999957804e-06
#    Time for Process Video is 0.012862600000001834
#    Time for all is 4.773087199999999
#    Prediction: 0
#       Confidence Measure 0: 0
#       Confidence Measure 1: 0
#
# File: ./POCUS AI Test Data/PNB Test Data\10.mp4
#    Time for Read Video: Read from disk is 9.3341591
#    Time for Read Video is 9.3345251
# ...

# %%
vids = glob.glob("./POCUS AI Test Data/ONSD Test Data/*.mp4")
app_ai = ARGUS_app_ai(source="Butterfly")
for vid in vids:
    #try:
    result = app_ai.predict(vid, task="ONSD")
    print("")
    #except:
        #print("******* An exception occurred **********")
        #print("")
# Out:
# File: ./POCUS AI Test Data/ONSD Test Data\10. 235.1 Left Long_Video.mp4
# ERROR: Could not load video ./POCUS AI Test Data/ONSD Test Data\10. 235.1 Left Long_Video.mp4
#    Time for Read Video: Read from disk is 1.5178797999997187
#    Time for Read Video is 1.517916299999797
#    Time for all is 1.5179283000002215
#
# File: ./POCUS AI Test Data/ONSD Test Data\11. 234.1 Left Long_Video (Mislabeled).mp4
# ERROR: Could not load video ./POCUS AI Test Data/ONSD Test Data\11. 234.1 Left Long_Video (Mislabeled).mp4
#    Time for Read Video: Read from disk is 0.05407150000019101
#    Time for Read Video is 0.05410260000007838
#    Time for all is 0.054113000000143074
#
# File: ./POCUS AI Test Data/ONSD Test Data\11. 30.1 Left Long_Video.mp4
# RuntimeError: C:\src\ITK\Modules\Core\Common\include\itkImportImageContainer.hxx:191:
# Failed to allocate memory for image.
# ...

# %%
vids = glob.glob("./POCUS AI Test Data/PTX Test Data/*.mp4")
app_ai = ARGUS_app_ai(source="Sonosite")
for vid in vids:
    #try:
    result = app_ai.predict(vid, task="PTX")
    print("")
    #except:
        #print("******* An exception occurred **********")
        #print("")
# Out:
# File: ./POCUS AI Test Data/PTX Test Data\image_1036584980280_CLEAN.mp4
#    Time for Read Video: Read from disk is 0.7406963000003088
#    Time for Read Video is 0.7407948999998553
#    Task: PTX
#    Time for Preprocess for AR is 1.327887500000088
#    Time for Preprocess AR Inference is 0.16037349999987782
#    Time for Preprocess for ROI is 0.004844400000365567
#    Time for Preprocess Video is 1.4932862999999088
#    Time for Process Video: ROI Inference is 0.2371714000000793
#    Time for Process Video: Decision is 3.100000412814552e-06
#    Time for Process Video is 0.23728929999970205
#    Time for all is 2.4714100000001054
#    Prediction: 0
#       Confidence Measure 0: 1.0
#       Confidence Measure 1: 0.0
#
# File: ./POCUS AI Test Data/PTX Test Data\image_1215182877868_CLEAN.mp4
#    Time for Read Video: Read from disk is 0.7327615999997761
#    Time for Read Video is 0.7328633999995873
#    Task: PTX
#    Time for Preprocess for AR is 1.1848033999999643
# ...
