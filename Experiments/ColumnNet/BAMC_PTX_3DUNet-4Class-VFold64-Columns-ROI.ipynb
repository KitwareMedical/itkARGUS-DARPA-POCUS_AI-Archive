# %%
from monai.utils import first, set_determinism
from monai.transforms import (
    AddChanneld,
    AsDiscrete,
    AsDiscreted,
    Compose,
    EnsureChannelFirstd,
    EnsureTyped,
    EnsureType,
    Invertd,
    LabelFilterd,
    LoadImaged,
    RandFlipd,
    RandSpatialCropd,
    RandZoomd,
    Resized,
    ScaleIntensityRanged,
    SpatialCrop,
    SpatialCropd,
    ToTensord,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
from glob import glob

import warnings
warnings.filterwarnings("ignore")

import numpy as np

import itk

import site
site.addsitedir('../../ARGUS')
from ARGUSUtils_Transforms import *

# %%
img1_dir = "../../Data/VFoldData/ColumnData/"

all_images = sorted(glob(os.path.join(img1_dir, '*Class[NS]*[0123456789].mha')))
all_labels = sorted(glob(os.path.join(img1_dir, '*Class[NS]*.roi-overlay.mha')))

print("# of Images =", len(all_images))
print("# of Labels =", len(all_labels))

num_classes = 2

num_columns = 16
num_slices = 48

num_workers_tr = 8
batch_size_tr = 32
num_workers_vl = 8
batch_size_vl = 4

model_filename_base = "BAMC_PTX_3DUNet-4Class.best_model.vfold64-Columns-ROI"

num_images = len(all_images)

num_folds = 10

ns_prefix = ['025ns','026ns','027ns','035ns','048ns','055ns','117ns',
             '135ns','193ns','210ns','215ns','218ns','219ns','221ns','247ns']
s_prefix = ['004s','019s','030s','034s','037s','043s','065s','081s',
            '206s','208s','211s','212s','224s','228s','236s','237s']
# Out:
# # of Images = 90
# # of Labels = 90

# %%
fold_prefix_list = []
ns_count = 0
s_count = 0
for i in range(num_folds):
    if i%2 == 0:
        num_ns = 2
        num_s = 1
        if i > num_folds-3:
            num_s = 2
    else:
        num_ns = 1
        num_s = 2
    f = []
    for ns in range(num_ns):
        f.append([ns_prefix[ns_count+ns]])
    ns_count += num_ns
    for s in range(num_s):
        f.append([s_prefix[s_count+s]])
    s_count += num_s
    fold_prefix_list.append(f)
        
train_files = []
val_files = []
test_files = []
for i in range(num_folds):
    tr_folds = []
    for f in range(i,i+num_folds-2):
        tr_folds.append(fold_prefix_list[f%num_folds])
    tr_folds = list(np.concatenate(tr_folds).flat)
    va_folds = list(np.concatenate(fold_prefix_list[(i+num_folds-2) % num_folds]).flat)
    te_folds = list(np.concatenate(fold_prefix_list[(i+num_folds-1) % num_folds]).flat)
    train_files.append(
            [
                {"image": img, "label": seg}
                for img, seg in zip(
                    [im for im in all_images if any(pref in im for pref in tr_folds)],
                    [se for se in all_labels if any(pref in se for pref in tr_folds)])
            ]
        )
    val_files.append(
            [
                {"image": img, "label": seg}
                for img, seg in zip(
                    [im for im in all_images if any(pref in im for pref in va_folds)],
                    [se for se in all_labels if any(pref in se for pref in va_folds)])
            ]
        )
    test_files.append(
            [
                {"image": img, "label": seg}
                for img, seg in zip(
                    [im for im in all_images if any(pref in im for pref in te_folds)],
                    [se for se in all_labels if any(pref in se for pref in te_folds)])
            ]
        )
    print(len(train_files[i]),len(val_files[i]),len(test_files[i]))
# Out:
# 70 14 6
# 74 6 10
# 72 10 8
# 73 8 9
# 73 9 8
# 74 8 8
# 75 8 7
# 76 7 7
# 70 7 13
# 63 13 14

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AddChanneld(keys=["image", "label"]),
        ScaleIntensityRanged(keys=["image"],
            a_min=0, a_max=255,
            b_min=0.0, b_max=1.0),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=num_slices,
            axis=2,
            keys=['image', 'label']),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=num_columns,
            axis=0,
            require_labeled=True,
            keys=['image', 'label']),
        RandFlipd(prob=0.5, 
            spatial_axis=2,
            keys=['image', 'label']),
        RandFlipd(prob=0.5, 
            spatial_axis=0,
            keys=['image', 'label']),
        RandZoomd(prob=0.5, 
            min_zoom=1.0,
            max_zoom=1.2,
            keys=['image', 'label'],
            keep_size=True,
            mode=['trilinear', 'nearest']),
        ToTensord(keys=["image", "label"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AddChanneld(keys=["image", "label"]),
        ScaleIntensityRanged(keys=["image"],
            a_min=0, a_max=255,
            b_min=0.0, b_max=1.0),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=num_slices,
            axis=2,
            center_slice=30,
            keys=['image', 'label']),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=num_columns,
            axis=0,
            center_slice=num_columns//2,
            keys=['image', 'label']),
        ToTensord(keys=["image", "label"]),
    ]
)

# %%
itkForceDynamicLoading = itk.imread(train_files[0][0]["image"])
print(itkForceDynamicLoading)
arrForceDynamicLoading = itk.GetArrayFromImage(itkForceDynamicLoading)
# Out:
# Image (0x56452c56cf50)
#   RTTI typeinfo:   itk::Image<short, 3u>
#   Reference Count: 1
#   Modified Time: 442
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 246
#   UpdateMTime: 441
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [93, 320, 61]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [93, 320, 61]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [93, 320, 61]
#   Spacing: [1, 1, 1]
#   Origin: [0, 0, 0]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PointToIndexMatrix:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
#     ImportImageContainer (0x56452ce855f0)
#       RTTI typeinfo:   itk::ImportImageContainer<unsigned long, short>
#       Reference Count: 1
#       Modified Time: 438
#       Debug: Off
#       Object Name:
#       Observers:
#         none
#       Pointer: 0x7f9283b2f010
#       Container manages memory: true
#       Size: 1815360
#       Capacity: 1815360

# %%
train_ds = [CacheDataset(data=train_files[i], transform=train_transforms,cache_rate=1.0, num_workers=num_workers_tr)
            for i in range(num_folds)]
train_loader = [DataLoader(train_ds[i], batch_size=batch_size_tr, shuffle=True, num_workers=num_workers_tr) 
                for i in range(num_folds)]

val_ds = [CacheDataset(data=val_files[i], transform=val_transforms, cache_rate=1.0, num_workers=num_workers_vl)
          for i in range(num_folds)]
val_loader = [DataLoader(val_ds[i], batch_size=batch_size_vl, num_workers=num_workers_vl)
              for i in range(num_folds)]
# Out:
# Loading dataset: 100%|██████████████████████████| 70/70 [00:01<00:00, 50.02it/s]
# Loading dataset: 100%|██████████████████████████| 74/74 [00:01<00:00, 59.55it/s]
# Loading dataset: 100%|██████████████████████████| 72/72 [00:01<00:00, 53.17it/s]
# Loading dataset: 100%|██████████████████████████| 73/73 [00:01<00:00, 54.06it/s]
# Loading dataset: 100%|██████████████████████████| 73/73 [00:01<00:00, 53.12it/s]
# Loading dataset: 100%|██████████████████████████| 74/74 [00:01<00:00, 58.51it/s]
# Loading dataset: 100%|██████████████████████████| 75/75 [00:01<00:00, 52.40it/s]
# Loading dataset: 100%|██████████████████████████| 76/76 [00:01<00:00, 52.71it/s]
# Loading dataset: 100%|██████████████████████████| 70/70 [00:01<00:00, 55.24it/s]
# Loading dataset: 100%|██████████████████████████| 63/63 [00:01<00:00, 56.30it/s]
# Loading dataset: 100%|█████████████████████████| 14/14 [00:00<00:00, 438.64it/s]
# Loading dataset: 100%|███████████████████████████| 6/6 [00:00<00:00, 684.58it/s]
# Loading dataset: 100%|█████████████████████████| 10/10 [00:00<00:00, 202.84it/s]
# Loading dataset: 100%|███████████████████████████| 8/8 [00:00<00:00, 251.73it/s]
# Loading dataset: 100%|████████████████████████████| 9/9 [00:00<00:00, 78.83it/s]
# Loading dataset: 100%|████████████████████████████| 8/8 [00:00<00:00, 76.09it/s]
# Loading dataset: 100%|███████████████████████████| 8/8 [00:00<00:00, 215.32it/s]
# Loading dataset: 100%|███████████████████████████| 7/7 [00:00<00:00, 208.03it/s]
# Loading dataset: 100%|███████████████████████████| 7/7 [00:00<00:00, 603.47it/s]
# Loading dataset: 100%|█████████████████████████| 13/13 [00:00<00:00, 110.66it/s]

# %%
device = torch.device("cuda:1")

# %%
def vfold_train(vfold_num, train_loader, val_loader):
    model = UNet(
        dimensions=3,
        in_channels=1,
        out_channels=num_classes,
        channels=(16, 32, 64),
        strides=(2, 2),
        num_res_units=2,
        norm=Norm.BATCH,
    ).to(device)
    loss_function = DiceLoss(to_onehot_y=True, softmax=True)
    optimizer = torch.optim.Adam(model.parameters(), 5e-5)
    dice_metric = DiceMetric(include_background=False, reduction="mean")


    max_epochs = 1000
    val_interval = 2
    best_metric = -1
    best_metric_epoch = -1
    epoch_loss_values = []
    metric_values = []
    post_pred = Compose([EnsureType(), AsDiscrete(argmax=True, to_onehot=True, num_classes=num_classes)])
    post_label = Compose([EnsureType(), AsDiscrete(to_onehot=True, num_classes=num_classes)])

    root_dir = "."

    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"{vfold_num}: epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs, labels = (
                batch_data["image"].to(device),
                batch_data["label"].to(device),
            )
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            print(
                f"{step}/{len(train_ds) // train_loader.batch_size}, "
                f"train_loss: {loss.item():.4f}")
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        print(f"{vfold_num} epoch {epoch + 1} average loss: {epoch_loss:.4f}")

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                for val_data in val_loader:
                    val_inputs, val_labels = (
                        val_data["image"].to(device),
                        val_data["label"].to(device),
                    )
                    roi_size = (num_columns, 320, num_slices)
                    sw_batch_size = batch_size_vl
                    val_outputs = sliding_window_inference(
                        val_inputs, roi_size, sw_batch_size, model)
                    val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                    val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                    # compute metric for current iteration
                    dice_metric(y_pred=val_outputs, y=val_labels)

                # aggregate the final mean dice result
                metric = dice_metric.aggregate().item()
                # reset the status for next validation round
                dice_metric.reset()

                metric_values.append(metric)
                if metric >= best_metric:
                    best_metric = metric
                    best_metric_epoch = epoch + 1
                    torch.save(model.state_dict(), os.path.join(
                        root_dir, model_filename_base+'_'+str(vfold_num)+'.pth'))
                    print("saved new best metric model")
                print(
                    f"current epoch: {epoch + 1} current mean dice: {metric:.8f}"
                    f"\nbest mean dice: {best_metric:.8f} "
                    f"at epoch: {best_metric_epoch}"
                )

    np.save(model_filename_base+"_loss_"+str(vfold_num)+".npy", epoch_loss_values)
    np.save(model_filename_base+"_val_dice_"+str(vfold_num)+".npy", metric_values)

# %%
for i in range(0,num_folds):
    vfold_train(i, train_loader[i], val_loader[i])
# Out:
# ----------
# 0: epoch 1/1000
# 1/0, train_loss: 0.6636
# 2/0, train_loss: 0.6637
# 3/0, train_loss: 0.6513
# 0 epoch 1 average loss: 0.6595
# ----------
# 0: epoch 2/1000
# 1/0, train_loss: 0.6569
# 2/0, train_loss: 0.6534
# 3/0, train_loss: 0.6381
# 0 epoch 2 average loss: 0.6495
# saved new best metric model
# current epoch: 2 current mean dice: 0.26501149
# best mean dice: 0.26501149 at epoch: 2
# ----------
# 0: epoch 3/1000
# 1/0, train_loss: 0.6501
# 2/0, train_loss: 0.6422
# 3/0, train_loss: 0.6588
# 0 epoch 3 average loss: 0.6504
# ----------
# 0: epoch 4/1000
# 1/0, train_loss: 0.6382
# 2/0, train_loss: 0.6435
# 3/0, train_loss: 0.6494
# 0 epoch 4 average loss: 0.6437
# current epoch: 4 current mean dice: 0.26198176
# best mean dice: 0.26501149 at epoch: 2
# ----------
# 0: epoch 5/1000
# 1/0, train_loss: 0.6405
# 2/0, train_loss: 0.6331
# 3/0, train_loss: 0.6258
# 0 epoch 5 average loss: 0.6331
# ----------
# 0: epoch 6/1000
# 1/0, train_loss: 0.6297
# 2/0, train_loss: 0.6351
# 3/0, train_loss: 0.6201
# 0 epoch 6 average loss: 0.6283
# current epoch: 6 current mean dice: 0.26479587
# best mean dice: 0.26501149 at epoch: 2
# ----------
# 0: epoch 7/1000
# 1/0, train_loss: 0.6054
# 2/0, train_loss: 0.6385
# 3/0, train_loss: 0.6904
# 0 epoch 7 average loss: 0.6448
# ----------
# 0: epoch 8/1000
# 1/0, train_loss: 0.6333
# 2/0, train_loss: 0.6195
# 3/0, train_loss: 0.6138
# 0 epoch 8 average loss: 0.6222
# saved new best metric model
# current epoch: 8 current mean dice: 0.26876852
# best mean dice: 0.26876852 at epoch: 8
# ----------
# 0: epoch 9/1000
# 1/0, train_loss: 0.6305
# 2/0, train_loss: 0.6129
# 3/0, train_loss: 0.6157
# 0 epoch 9 average loss: 0.6197
# ----------
# 0: epoch 10/1000
# 1/0, train_loss: 0.6195
# 2/0, train_loss: 0.6147
# 3/0, train_loss: 0.6561
# 0 epoch 10 average loss: 0.6301
# saved new best metric model
# current epoch: 10 current mean dice: 0.27139494
# best mean dice: 0.27139494 at epoch: 10
# ----------
# 0: epoch 11/1000
# 1/0, train_loss: 0.6277
# 2/0, train_loss: 0.6178
# 3/0, train_loss: 0.5899
# 0 epoch 11 average loss: 0.6118
# ----------
# 0: epoch 12/1000
# 1/0, train_loss: 0.6194
# 2/0, train_loss: 0.6234
# 3/0, train_loss: 0.5721
# 0 epoch 12 average loss: 0.6049
# saved new best metric model
# current epoch: 12 current mean dice: 0.27362713
# best mean dice: 0.27362713 at epoch: 12
# ----------
# 0: epoch 13/1000
# 1/0, train_loss: 0.6150
# 2/0, train_loss: 0.6118
# 3/0, train_loss: 0.6468
# 0 epoch 13 average loss: 0.6245
# ----------
# 0: epoch 14/1000
# 1/0, train_loss: 0.6239
# 2/0, train_loss: 0.6085
# 3/0, train_loss: 0.6041
# 0 epoch 14 average loss: 0.6122
# saved new best metric model
# current epoch: 14 current mean dice: 0.27552375
# best mean dice: 0.27552375 at epoch: 14
# ----------
# 0: epoch 15/1000
# 1/0, train_loss: 0.6189
# 2/0, train_loss: 0.6212
# 3/0, train_loss: 0.5765
# 0 epoch 15 average loss: 0.6055
# ----------
# 0: epoch 16/1000
# 1/0, train_loss: 0.6204
# 2/0, train_loss: 0.6115
# 3/0, train_loss: 0.6088
# 0 epoch 16 average loss: 0.6136
# saved new best metric model
# current epoch: 16 current mean dice: 0.27749160
# best mean dice: 0.27749160 at epoch: 16
# ----------
# 0: epoch 17/1000
# 1/0, train_loss: 0.6252
# 2/0, train_loss: 0.5956
# 3/0, train_loss: 0.6522
# 0 epoch 17 average loss: 0.6243
# ----------
# 0: epoch 18/1000
# 1/0, train_loss: 0.6027
# 2/0, train_loss: 0.6192
# 3/0, train_loss: 0.6293
# 0 epoch 18 average loss: 0.6170
# saved new best metric model
# current epoch: 18 current mean dice: 0.27991816
# best mean dice: 0.27991816 at epoch: 18
# ----------
# 0: epoch 19/1000
# 1/0, train_loss: 0.6139
# 2/0, train_loss: 0.6080
# 3/0, train_loss: 0.6254
# 0 epoch 19 average loss: 0.6158
# ----------
# 0: epoch 20/1000
# 1/0, train_loss: 0.6063
# 2/0, train_loss: 0.6152
# 3/0, train_loss: 0.6268
# 0 epoch 20 average loss: 0.6161
# saved new best metric model
# current epoch: 20 current mean dice: 0.28193277
# best mean dice: 0.28193277 at epoch: 20
# ----------
# 0: epoch 21/1000
# 1/0, train_loss: 0.6132
# 2/0, train_loss: 0.6136
# 3/0, train_loss: 0.5731
# 0 epoch 21 average loss: 0.6000
# ----------
# 0: epoch 22/1000
# 1/0, train_loss: 0.6078
# 2/0, train_loss: 0.6259
# 3/0, train_loss: 0.5483
# 0 epoch 22 average loss: 0.5940
# saved new best metric model
# current epoch: 22 current mean dice: 0.28296503
# best mean dice: 0.28296503 at epoch: 22
# ----------
# 0: epoch 23/1000
# 1/0, train_loss: 0.6161
# 2/0, train_loss: 0.5993
# 3/0, train_loss: 0.6181
# 0 epoch 23 average loss: 0.6112
# ----------
# 0: epoch 24/1000
# 1/0, train_loss: 0.6013
# 2/0, train_loss: 0.6093
# 3/0, train_loss: 0.6195
# 0 epoch 24 average loss: 0.6100
# saved new best metric model
# current epoch: 24 current mean dice: 0.28583142
# best mean dice: 0.28583142 at epoch: 24
# ----------
# 0: epoch 25/1000
# 1/0, train_loss: 0.6128
# 2/0, train_loss: 0.6048
# 3/0, train_loss: 0.5697
# 0 epoch 25 average loss: 0.5957
# ----------
# 0: epoch 26/1000
# 1/0, train_loss: 0.6131
# 2/0, train_loss: 0.6050
# 3/0, train_loss: 0.5631
# 0 epoch 26 average loss: 0.5937
# saved new best metric model
# current epoch: 26 current mean dice: 0.28710121
# best mean dice: 0.28710121 at epoch: 26
# ----------
# 0: epoch 27/1000
# 1/0, train_loss: 0.6091
# 2/0, train_loss: 0.6105
# 3/0, train_loss: 0.5877
# 0 epoch 27 average loss: 0.6024
# ----------
# 0: epoch 28/1000
# 1/0, train_loss: 0.6201
# 2/0, train_loss: 0.6032
# 3/0, train_loss: 0.5501
# 0 epoch 28 average loss: 0.5911
# saved new best metric model
# current epoch: 28 current mean dice: 0.29184350
# best mean dice: 0.29184350 at epoch: 28
# ----------
# 0: epoch 29/1000
# 1/0, train_loss: 0.5941
# 2/0, train_loss: 0.6064
# 3/0, train_loss: 0.6399
# 0 epoch 29 average loss: 0.6135
# ----------
# 0: epoch 30/1000
# 1/0, train_loss: 0.5917
# 2/0, train_loss: 0.6199
# 3/0, train_loss: 0.5996
# 0 epoch 30 average loss: 0.6038
# saved new best metric model
# current epoch: 30 current mean dice: 0.29187635
# best mean dice: 0.29187635 at epoch: 30
# ----------
# 0: epoch 31/1000
# 1/0, train_loss: 0.5974
# 2/0, train_loss: 0.6090
# 3/0, train_loss: 0.6016
# 0 epoch 31 average loss: 0.6027
# ----------
# 0: epoch 32/1000
# 1/0, train_loss: 0.6210
# 2/0, train_loss: 0.5871
# 3/0, train_loss: 0.5754
# 0 epoch 32 average loss: 0.5945
# saved new best metric model
# current epoch: 32 current mean dice: 0.30288935
# best mean dice: 0.30288935 at epoch: 32
# ----------
# 0: epoch 33/1000
# 1/0, train_loss: 0.6150
# 2/0, train_loss: 0.5966
# 3/0, train_loss: 0.5566
# 0 epoch 33 average loss: 0.5894
# ----------
# 0: epoch 34/1000
# 1/0, train_loss: 0.6135
# 2/0, train_loss: 0.5745
# 3/0, train_loss: 0.6276
# 0 epoch 34 average loss: 0.6052
# current epoch: 34 current mean dice: 0.30123690
# best mean dice: 0.30288935 at epoch: 32
# ----------
# 0: epoch 35/1000
# 1/0, train_loss: 0.5923
# 2/0, train_loss: 0.6098
# 3/0, train_loss: 0.5812
# 0 epoch 35 average loss: 0.5944
# ----------
# 0: epoch 36/1000
# 1/0, train_loss: 0.6106
# 2/0, train_loss: 0.5825
# 3/0, train_loss: 0.6343
# 0 epoch 36 average loss: 0.6092
# current epoch: 36 current mean dice: 0.30267501
# best mean dice: 0.30288935 at epoch: 32
# ----------
# 0: epoch 37/1000
# 1/0, train_loss: 0.5934
# 2/0, train_loss: 0.5988
# 3/0, train_loss: 0.6072
# 0 epoch 37 average loss: 0.5998
# ----------
# 0: epoch 38/1000
# 1/0, train_loss: 0.6044
# 2/0, train_loss: 0.5916
# 3/0, train_loss: 0.6006
# 0 epoch 38 average loss: 0.5989
# saved new best metric model
# current epoch: 38 current mean dice: 0.32302904
# best mean dice: 0.32302904 at epoch: 38
# ----------
# 0: epoch 39/1000
# 1/0, train_loss: 0.6127
# 2/0, train_loss: 0.5761
# 3/0, train_loss: 0.6245
# 0 epoch 39 average loss: 0.6044
# ----------
# 0: epoch 40/1000
# 1/0, train_loss: 0.5918
# 2/0, train_loss: 0.5921
# 3/0, train_loss: 0.6438
# 0 epoch 40 average loss: 0.6092
# saved new best metric model
# current epoch: 40 current mean dice: 0.32859215
# best mean dice: 0.32859215 at epoch: 40
# ----------
# 0: epoch 41/1000
# 1/0, train_loss: 0.5971
# 2/0, train_loss: 0.6065
# 3/0, train_loss: 0.5515
# 0 epoch 41 average loss: 0.5851
# ----------
# 0: epoch 42/1000
# 1/0, train_loss: 0.5903
# 2/0, train_loss: 0.5917
# 3/0, train_loss: 0.6073
# 0 epoch 42 average loss: 0.5964
# saved new best metric model
# current epoch: 42 current mean dice: 0.33375916
# best mean dice: 0.33375916 at epoch: 42
# ----------
# 0: epoch 43/1000
# 1/0, train_loss: 0.6063
# 2/0, train_loss: 0.5804
# 3/0, train_loss: 0.6207
# 0 epoch 43 average loss: 0.6025
# ----------
# 0: epoch 44/1000
# 1/0, train_loss: 0.5918
# 2/0, train_loss: 0.5838
# 3/0, train_loss: 0.6373
# 0 epoch 44 average loss: 0.6043
# saved new best metric model
# current epoch: 44 current mean dice: 0.34138811
# best mean dice: 0.34138811 at epoch: 44
# ----------
# 0: epoch 45/1000
# 1/0, train_loss: 0.5877
# 2/0, train_loss: 0.5972
# 3/0, train_loss: 0.5928
# 0 epoch 45 average loss: 0.5926
# ----------
# 0: epoch 46/1000
# 1/0, train_loss: 0.5879
# 2/0, train_loss: 0.5939
# 3/0, train_loss: 0.5603
# 0 epoch 46 average loss: 0.5807
# current epoch: 46 current mean dice: 0.33904925
# best mean dice: 0.34138811 at epoch: 44
# ----------
# 0: epoch 47/1000
# 1/0, train_loss: 0.5815
# 2/0, train_loss: 0.5989
# 3/0, train_loss: 0.5819
# 0 epoch 47 average loss: 0.5874
# ----------
# 0: epoch 48/1000
# 1/0, train_loss: 0.5818
# 2/0, train_loss: 0.5867
# 3/0, train_loss: 0.6700
# 0 epoch 48 average loss: 0.6128
# saved new best metric model
# current epoch: 48 current mean dice: 0.35545954
# best mean dice: 0.35545954 at epoch: 48
# ----------
# 0: epoch 49/1000
# 1/0, train_loss: 0.5800
# 2/0, train_loss: 0.6108
# 3/0, train_loss: 0.5606
# 0 epoch 49 average loss: 0.5838
# ----------
# 0: epoch 50/1000
# 1/0, train_loss: 0.6093
# 2/0, train_loss: 0.5641
# 3/0, train_loss: 0.6052
# 0 epoch 50 average loss: 0.5929
# current epoch: 50 current mean dice: 0.33885011
# best mean dice: 0.35545954 at epoch: 48
# ----------
# 0: epoch 51/1000
# 1/0, train_loss: 0.5695
# 2/0, train_loss: 0.5852
# 3/0, train_loss: 0.6579
# 0 epoch 51 average loss: 0.6042
# ----------
# 0: epoch 52/1000
# 1/0, train_loss: 0.5959
# 2/0, train_loss: 0.5894
# 3/0, train_loss: 0.5715
# 0 epoch 52 average loss: 0.5856
# current epoch: 52 current mean dice: 0.35139596
# best mean dice: 0.35545954 at epoch: 48
# ----------
# 0: epoch 53/1000
# 1/0, train_loss: 0.5820
# 2/0, train_loss: 0.6002
# 3/0, train_loss: 0.5746
# 0 epoch 53 average loss: 0.5856
# ----------
# 0: epoch 54/1000
# 1/0, train_loss: 0.5918
# 2/0, train_loss: 0.5908
# 3/0, train_loss: 0.5204
# 0 epoch 54 average loss: 0.5676
# current epoch: 54 current mean dice: 0.35441545
# best mean dice: 0.35545954 at epoch: 48
# ----------
# 0: epoch 55/1000
# 1/0, train_loss: 0.5522
# 2/0, train_loss: 0.6152
# 3/0, train_loss: 0.5940
# 0 epoch 55 average loss: 0.5872
# ----------
# 0: epoch 56/1000
# 1/0, train_loss: 0.5843
# 2/0, train_loss: 0.5768
# 3/0, train_loss: 0.6227
# 0 epoch 56 average loss: 0.5946
# saved new best metric model
# current epoch: 56 current mean dice: 0.36558819
# best mean dice: 0.36558819 at epoch: 56
# ----------
# 0: epoch 57/1000
# 1/0, train_loss: 0.5997
# 2/0, train_loss: 0.5656
# 3/0, train_loss: 0.6063
# 0 epoch 57 average loss: 0.5905
# ----------
# 0: epoch 58/1000
# 1/0, train_loss: 0.5836
# 2/0, train_loss: 0.5919
# 3/0, train_loss: 0.5758
# 0 epoch 58 average loss: 0.5838
# current epoch: 58 current mean dice: 0.32396445
# best mean dice: 0.36558819 at epoch: 56
# ----------
# 0: epoch 59/1000
# 1/0, train_loss: 0.5588
# 2/0, train_loss: 0.5985
# 3/0, train_loss: 0.6543
# 0 epoch 59 average loss: 0.6039
# ----------
# 0: epoch 60/1000
# 1/0, train_loss: 0.5796
# 2/0, train_loss: 0.5773
# 3/0, train_loss: 0.5972
# 0 epoch 60 average loss: 0.5847
# saved new best metric model
# current epoch: 60 current mean dice: 0.37826085
# best mean dice: 0.37826085 at epoch: 60
# ----------
# 0: epoch 61/1000
# 1/0, train_loss: 0.5842
# 2/0, train_loss: 0.5805
# 3/0, train_loss: 0.5608
# 0 epoch 61 average loss: 0.5752
# ----------
# 0: epoch 62/1000
# 1/0, train_loss: 0.5547
# 2/0, train_loss: 0.6035
# 3/0, train_loss: 0.5609
# 0 epoch 62 average loss: 0.5730
# saved new best metric model
# current epoch: 62 current mean dice: 0.37972251
# best mean dice: 0.37972251 at epoch: 62
# ----------
# 0: epoch 63/1000
# 1/0, train_loss: 0.5828
# 2/0, train_loss: 0.5715
# 3/0, train_loss: 0.6120
# 0 epoch 63 average loss: 0.5888
# ----------
# 0: epoch 64/1000
# 1/0, train_loss: 0.5858
# 2/0, train_loss: 0.5695
# 3/0, train_loss: 0.5929
# 0 epoch 64 average loss: 0.5827
# current epoch: 64 current mean dice: 0.34891310
# best mean dice: 0.37972251 at epoch: 62
# ----------
# 0: epoch 65/1000
# 1/0, train_loss: 0.5729
# 2/0, train_loss: 0.5909
# 3/0, train_loss: 0.5553
# 0 epoch 65 average loss: 0.5730
# ----------
# 0: epoch 66/1000
# 1/0, train_loss: 0.5783
# 2/0, train_loss: 0.5774
# 3/0, train_loss: 0.5722
# 0 epoch 66 average loss: 0.5759
# saved new best metric model
# current epoch: 66 current mean dice: 0.39391157
# best mean dice: 0.39391157 at epoch: 66
# ----------
# 0: epoch 67/1000
# 1/0, train_loss: 0.5935
# 2/0, train_loss: 0.5621
# 3/0, train_loss: 0.6002
# 0 epoch 67 average loss: 0.5853
# ----------
# 0: epoch 68/1000
# 1/0, train_loss: 0.5696
# 2/0, train_loss: 0.5903
# 3/0, train_loss: 0.5507
# 0 epoch 68 average loss: 0.5702
# current epoch: 68 current mean dice: 0.39230204
# best mean dice: 0.39391157 at epoch: 66
# ----------
# 0: epoch 69/1000
# 1/0, train_loss: 0.5812
# 2/0, train_loss: 0.5573
# 3/0, train_loss: 0.6191
# 0 epoch 69 average loss: 0.5859
# ----------
# 0: epoch 70/1000
# 1/0, train_loss: 0.5579
# 2/0, train_loss: 0.5841
# 3/0, train_loss: 0.5650
# 0 epoch 70 average loss: 0.5690
# current epoch: 70 current mean dice: 0.36554793
# best mean dice: 0.39391157 at epoch: 66
# ----------
# 0: epoch 71/1000
# 1/0, train_loss: 0.5794
# 2/0, train_loss: 0.5852
# 3/0, train_loss: 0.5146
# 0 epoch 71 average loss: 0.5597
# ----------
# 0: epoch 72/1000
# 1/0, train_loss: 0.5815
# 2/0, train_loss: 0.5728
# 3/0, train_loss: 0.5582
# 0 epoch 72 average loss: 0.5708
# saved new best metric model
# current epoch: 72 current mean dice: 0.40170613
# best mean dice: 0.40170613 at epoch: 72
# ----------
# 0: epoch 73/1000
# 1/0, train_loss: 0.5717
# 2/0, train_loss: 0.5567
# 3/0, train_loss: 0.5863
# 0 epoch 73 average loss: 0.5715
# ----------
# 0: epoch 74/1000
# 1/0, train_loss: 0.5741
# 2/0, train_loss: 0.5689
# 3/0, train_loss: 0.5921
# 0 epoch 74 average loss: 0.5784
# saved new best metric model
# current epoch: 74 current mean dice: 0.40194783
# best mean dice: 0.40194783 at epoch: 74
# ----------
# 0: epoch 75/1000
# 1/0, train_loss: 0.5977
# 2/0, train_loss: 0.5502
# 3/0, train_loss: 0.5536
# 0 epoch 75 average loss: 0.5672
# ----------
# 0: epoch 76/1000
# 1/0, train_loss: 0.5503
# 2/0, train_loss: 0.5964
# 3/0, train_loss: 0.5363
# 0 epoch 76 average loss: 0.5610
# saved new best metric model
# current epoch: 76 current mean dice: 0.41418210
# best mean dice: 0.41418210 at epoch: 76
# ----------
# 0: epoch 77/1000
# 1/0, train_loss: 0.5606
# 2/0, train_loss: 0.5659
# 3/0, train_loss: 0.6162
# 0 epoch 77 average loss: 0.5809
# ----------
# 0: epoch 78/1000
# 1/0, train_loss: 0.5728
# 2/0, train_loss: 0.5669
# 3/0, train_loss: 0.5456
# 0 epoch 78 average loss: 0.5618
# current epoch: 78 current mean dice: 0.40927568
# best mean dice: 0.41418210 at epoch: 76
# ----------
# 0: epoch 79/1000
# 1/0, train_loss: 0.5571
# 2/0, train_loss: 0.5778
# 3/0, train_loss: 0.5760
# 0 epoch 79 average loss: 0.5703
# ----------
# 0: epoch 80/1000
# 1/0, train_loss: 0.5788
# 2/0, train_loss: 0.5475
# 3/0, train_loss: 0.6106
# 0 epoch 80 average loss: 0.5790
# saved new best metric model
# current epoch: 80 current mean dice: 0.41707256
# best mean dice: 0.41707256 at epoch: 80
# ----------
# 0: epoch 81/1000
# 1/0, train_loss: 0.5713
# 2/0, train_loss: 0.5627
# 3/0, train_loss: 0.5330
# 0 epoch 81 average loss: 0.5556
# ----------
# 0: epoch 82/1000
# 1/0, train_loss: 0.5743
# 2/0, train_loss: 0.5506
# 3/0, train_loss: 0.5868
# 0 epoch 82 average loss: 0.5706
# saved new best metric model
# current epoch: 82 current mean dice: 0.42600742
# best mean dice: 0.42600742 at epoch: 82
# ----------
# 0: epoch 83/1000
# 1/0, train_loss: 0.5606
# 2/0, train_loss: 0.5568
# 3/0, train_loss: 0.5828
# 0 epoch 83 average loss: 0.5667
# ----------
# 0: epoch 84/1000
# 1/0, train_loss: 0.5771
# 2/0, train_loss: 0.5656
# 3/0, train_loss: 0.4700
# 0 epoch 84 average loss: 0.5376
# saved new best metric model
# current epoch: 84 current mean dice: 0.43448916
# best mean dice: 0.43448916 at epoch: 84
# ----------
# 0: epoch 85/1000
# 1/0, train_loss: 0.5533
# 2/0, train_loss: 0.5618
# 3/0, train_loss: 0.5691
# 0 epoch 85 average loss: 0.5614
# ----------
# 0: epoch 86/1000
# 1/0, train_loss: 0.5438
# 2/0, train_loss: 0.5747
# 3/0, train_loss: 0.5485
# 0 epoch 86 average loss: 0.5557
# saved new best metric model
# current epoch: 86 current mean dice: 0.44294080
# best mean dice: 0.44294080 at epoch: 86
# ----------
# 0: epoch 87/1000
# 1/0, train_loss: 0.5791
# 2/0, train_loss: 0.5253
# 3/0, train_loss: 0.5820
# 0 epoch 87 average loss: 0.5621
# ----------
# 0: epoch 88/1000
# 1/0, train_loss: 0.5503
# 2/0, train_loss: 0.5562
# 3/0, train_loss: 0.5628
# 0 epoch 88 average loss: 0.5564
# saved new best metric model
# current epoch: 88 current mean dice: 0.44680080
# best mean dice: 0.44680080 at epoch: 88
# ----------
# 0: epoch 89/1000
# 1/0, train_loss: 0.5303
# 2/0, train_loss: 0.5726
# 3/0, train_loss: 0.5640
# 0 epoch 89 average loss: 0.5556
# ----------
# 0: epoch 90/1000
# 1/0, train_loss: 0.5673
# 2/0, train_loss: 0.5577
# 3/0, train_loss: 0.4742
# 0 epoch 90 average loss: 0.5331
# saved new best metric model
# current epoch: 90 current mean dice: 0.46315384
# best mean dice: 0.46315384 at epoch: 90
# ----------
# 0: epoch 91/1000
# 1/0, train_loss: 0.5745
# 2/0, train_loss: 0.5368
# 3/0, train_loss: 0.4819
# 0 epoch 91 average loss: 0.5311
# ----------
# 0: epoch 92/1000
# 1/0, train_loss: 0.5230
# 2/0, train_loss: 0.5732
# 3/0, train_loss: 0.5245
# 0 epoch 92 average loss: 0.5402
# saved new best metric model
# current epoch: 92 current mean dice: 0.46922526
# best mean dice: 0.46922526 at epoch: 92
# ----------
# 0: epoch 93/1000
# 1/0, train_loss: 0.5374
# 2/0, train_loss: 0.5579
# 3/0, train_loss: 0.5578
# 0 epoch 93 average loss: 0.5510
# ----------
# 0: epoch 94/1000
# 1/0, train_loss: 0.5326
# 2/0, train_loss: 0.5588
# 3/0, train_loss: 0.5561
# 0 epoch 94 average loss: 0.5492
# saved new best metric model
# current epoch: 94 current mean dice: 0.47783282
# best mean dice: 0.47783282 at epoch: 94
# ----------
# 0: epoch 95/1000
# 1/0, train_loss: 0.5604
# 2/0, train_loss: 0.5363
# 3/0, train_loss: 0.5049
# 0 epoch 95 average loss: 0.5339
# ----------
# 0: epoch 96/1000
# 1/0, train_loss: 0.5412
# 2/0, train_loss: 0.5387
# 3/0, train_loss: 0.6178
# 0 epoch 96 average loss: 0.5659
# current epoch: 96 current mean dice: 0.47281015
# best mean dice: 0.47783282 at epoch: 94
# ----------
# 0: epoch 97/1000
# 1/0, train_loss: 0.5467
# 2/0, train_loss: 0.5352
# 3/0, train_loss: 0.5673
# 0 epoch 97 average loss: 0.5497
# ----------
# 0: epoch 98/1000
# 1/0, train_loss: 0.5203
# 2/0, train_loss: 0.5597
# 3/0, train_loss: 0.6030
# 0 epoch 98 average loss: 0.5610
# saved new best metric model
# current epoch: 98 current mean dice: 0.51347733
# best mean dice: 0.51347733 at epoch: 98
# ----------
# 0: epoch 99/1000
# 1/0, train_loss: 0.5734
# 2/0, train_loss: 0.5158
# 3/0, train_loss: 0.4772
# 0 epoch 99 average loss: 0.5222
# ----------
# 0: epoch 100/1000
# 1/0, train_loss: 0.5360
# 2/0, train_loss: 0.5419
# 3/0, train_loss: 0.5433
# 0 epoch 100 average loss: 0.5404
# saved new best metric model
# current epoch: 100 current mean dice: 0.51973206
# best mean dice: 0.51973206 at epoch: 100
# ----------
# 0: epoch 101/1000
# 1/0, train_loss: 0.5572
# 2/0, train_loss: 0.5209
# 3/0, train_loss: 0.5217
# 0 epoch 101 average loss: 0.5333
# ----------
# 0: epoch 102/1000
# 1/0, train_loss: 0.5418
# 2/0, train_loss: 0.5312
# 3/0, train_loss: 0.5434
# 0 epoch 102 average loss: 0.5388
# saved new best metric model
# current epoch: 102 current mean dice: 0.53835344
# best mean dice: 0.53835344 at epoch: 102
# ----------
# 0: epoch 103/1000
# 1/0, train_loss: 0.5411
# 2/0, train_loss: 0.5285
# 3/0, train_loss: 0.5912
# 0 epoch 103 average loss: 0.5536
# ----------
# 0: epoch 104/1000
# 1/0, train_loss: 0.5394
# 2/0, train_loss: 0.5397
# 3/0, train_loss: 0.5102
# 0 epoch 104 average loss: 0.5297
# current epoch: 104 current mean dice: 0.53235251
# best mean dice: 0.53835344 at epoch: 102
# ----------
# 0: epoch 105/1000
# 1/0, train_loss: 0.4880
# 2/0, train_loss: 0.5735
# 3/0, train_loss: 0.5629
# 0 epoch 105 average loss: 0.5414
# ----------
# 0: epoch 106/1000
# 1/0, train_loss: 0.5429
# 2/0, train_loss: 0.5168
# 3/0, train_loss: 0.5381
# 0 epoch 106 average loss: 0.5326
# current epoch: 106 current mean dice: 0.52160680
# best mean dice: 0.53835344 at epoch: 102
# ----------
# 0: epoch 107/1000
# 1/0, train_loss: 0.5138
# 2/0, train_loss: 0.5394
# 3/0, train_loss: 0.6239
# 0 epoch 107 average loss: 0.5590
# ----------
# 0: epoch 108/1000
# 1/0, train_loss: 0.5319
# 2/0, train_loss: 0.5213
# 3/0, train_loss: 0.5674
# 0 epoch 108 average loss: 0.5402
# saved new best metric model
# current epoch: 108 current mean dice: 0.57455689
# best mean dice: 0.57455689 at epoch: 108
# ----------
# 0: epoch 109/1000
# 1/0, train_loss: 0.5294
# 2/0, train_loss: 0.5272
# 3/0, train_loss: 0.5239
# 0 epoch 109 average loss: 0.5268
# ----------
# 0: epoch 110/1000
# 1/0, train_loss: 0.5365
# 2/0, train_loss: 0.5218
# 3/0, train_loss: 0.5288
# 0 epoch 110 average loss: 0.5290
# current epoch: 110 current mean dice: 0.54509383
# best mean dice: 0.57455689 at epoch: 108
# ----------
# 0: epoch 111/1000
# 1/0, train_loss: 0.5307
# 2/0, train_loss: 0.5225
# 3/0, train_loss: 0.5348
# 0 epoch 111 average loss: 0.5293
# ----------
# 0: epoch 112/1000
# 1/0, train_loss: 0.5447
# 2/0, train_loss: 0.5137
# 3/0, train_loss: 0.5480
# 0 epoch 112 average loss: 0.5355
# saved new best metric model
# current epoch: 112 current mean dice: 0.58895844
# best mean dice: 0.58895844 at epoch: 112
# ----------
# 0: epoch 113/1000
# 1/0, train_loss: 0.5231
# 2/0, train_loss: 0.5243
# 3/0, train_loss: 0.5931
# 0 epoch 113 average loss: 0.5468
# ----------
# 0: epoch 114/1000
# 1/0, train_loss: 0.5099
# 2/0, train_loss: 0.5447
# 3/0, train_loss: 0.5409
# 0 epoch 114 average loss: 0.5318
# current epoch: 114 current mean dice: 0.48630452
# best mean dice: 0.58895844 at epoch: 112
# ----------
# 0: epoch 115/1000
# 1/0, train_loss: 0.5467
# 2/0, train_loss: 0.4933
# 3/0, train_loss: 0.5979
# 0 epoch 115 average loss: 0.5460
# ----------
# 0: epoch 116/1000
# 1/0, train_loss: 0.5123
# 2/0, train_loss: 0.5366
# 3/0, train_loss: 0.4896
# 0 epoch 116 average loss: 0.5129
# current epoch: 116 current mean dice: 0.51282078
# best mean dice: 0.58895844 at epoch: 112
# ----------
# 0: epoch 117/1000
# 1/0, train_loss: 0.5452
# 2/0, train_loss: 0.5079
# 3/0, train_loss: 0.4715
# 0 epoch 117 average loss: 0.5082
# ----------
# 0: epoch 118/1000
# 1/0, train_loss: 0.5350
# 2/0, train_loss: 0.4976
# 3/0, train_loss: 0.5611
# 0 epoch 118 average loss: 0.5312
# saved new best metric model
# current epoch: 118 current mean dice: 0.61848402
# best mean dice: 0.61848402 at epoch: 118
# ----------
# 0: epoch 119/1000
# 1/0, train_loss: 0.5263
# 2/0, train_loss: 0.5247
# 3/0, train_loss: 0.4831
# 0 epoch 119 average loss: 0.5114
# ----------
# 0: epoch 120/1000
# 1/0, train_loss: 0.5120
# 2/0, train_loss: 0.5342
# 3/0, train_loss: 0.4849
# 0 epoch 120 average loss: 0.5104
# current epoch: 120 current mean dice: 0.60021466
# best mean dice: 0.61848402 at epoch: 118
# ----------
# 0: epoch 121/1000
# 1/0, train_loss: 0.5313
# 2/0, train_loss: 0.4957
# 3/0, train_loss: 0.5332
# 0 epoch 121 average loss: 0.5201
# ----------
# 0: epoch 122/1000
# 1/0, train_loss: 0.5561
# 2/0, train_loss: 0.4779
# 3/0, train_loss: 0.5270
# 0 epoch 122 average loss: 0.5203
# current epoch: 122 current mean dice: 0.59256524
# best mean dice: 0.61848402 at epoch: 118
# ----------
# 0: epoch 123/1000
# 1/0, train_loss: 0.5166
# 2/0, train_loss: 0.5242
# 3/0, train_loss: 0.4703
# 0 epoch 123 average loss: 0.5037
# ----------
# 0: epoch 124/1000
# 1/0, train_loss: 0.5362
# 2/0, train_loss: 0.5263
# 3/0, train_loss: 0.4224
# 0 epoch 124 average loss: 0.4950
# current epoch: 124 current mean dice: 0.60889548
# best mean dice: 0.61848402 at epoch: 118
# ----------
# 0: epoch 125/1000
# 1/0, train_loss: 0.5038
# 2/0, train_loss: 0.5106
# 3/0, train_loss: 0.5997
# 0 epoch 125 average loss: 0.5380
# ----------
# 0: epoch 126/1000
# 1/0, train_loss: 0.5160
# 2/0, train_loss: 0.5269
# 3/0, train_loss: 0.4590
# 0 epoch 126 average loss: 0.5006
# current epoch: 126 current mean dice: 0.57148987
# best mean dice: 0.61848402 at epoch: 118
# ----------
# 0: epoch 127/1000
# 1/0, train_loss: 0.5129
# 2/0, train_loss: 0.5187
# 3/0, train_loss: 0.4747
# 0 epoch 127 average loss: 0.5021
# ----------
# 0: epoch 128/1000
# 1/0, train_loss: 0.5217
# 2/0, train_loss: 0.5236
# 3/0, train_loss: 0.4635
# 0 epoch 128 average loss: 0.5029
# saved new best metric model
# current epoch: 128 current mean dice: 0.62231475
# best mean dice: 0.62231475 at epoch: 128
# ----------
# 0: epoch 129/1000
# 1/0, train_loss: 0.5383
# 2/0, train_loss: 0.5025
# 3/0, train_loss: 0.4482
# 0 epoch 129 average loss: 0.4963
# ----------
# 0: epoch 130/1000
# 1/0, train_loss: 0.4973
# 2/0, train_loss: 0.5220
# 3/0, train_loss: 0.5096
# 0 epoch 130 average loss: 0.5096
# current epoch: 130 current mean dice: 0.50975531
# best mean dice: 0.62231475 at epoch: 128
# ----------
# 0: epoch 131/1000
# 1/0, train_loss: 0.4821
# 2/0, train_loss: 0.5231
# 3/0, train_loss: 0.5831
# 0 epoch 131 average loss: 0.5294
# ----------
# 0: epoch 132/1000
# 1/0, train_loss: 0.5184
# 2/0, train_loss: 0.5024
# 3/0, train_loss: 0.5632
# 0 epoch 132 average loss: 0.5280
# current epoch: 132 current mean dice: 0.55996448
# best mean dice: 0.62231475 at epoch: 128
# ----------
# 0: epoch 133/1000
# 1/0, train_loss: 0.5143
# 2/0, train_loss: 0.5160
# 3/0, train_loss: 0.4264
# 0 epoch 133 average loss: 0.4856
# ----------
# 0: epoch 134/1000
# 1/0, train_loss: 0.5088
# 2/0, train_loss: 0.4874
# 3/0, train_loss: 0.5637
# 0 epoch 134 average loss: 0.5200
# saved new best metric model
# current epoch: 134 current mean dice: 0.62356025
# best mean dice: 0.62356025 at epoch: 134
# ----------
# 0: epoch 135/1000
# 1/0, train_loss: 0.5173
# 2/0, train_loss: 0.5057
# 3/0, train_loss: 0.4224
# 0 epoch 135 average loss: 0.4818
# ----------
# 0: epoch 136/1000
# 1/0, train_loss: 0.4793
# 2/0, train_loss: 0.5259
# 3/0, train_loss: 0.5346
# 0 epoch 136 average loss: 0.5133
# current epoch: 136 current mean dice: 0.59109432
# best mean dice: 0.62356025 at epoch: 134
# ----------
# 0: epoch 137/1000
# 1/0, train_loss: 0.5039
# 2/0, train_loss: 0.5028
# 3/0, train_loss: 0.5070
# 0 epoch 137 average loss: 0.5046
# ----------
# 0: epoch 138/1000
# 1/0, train_loss: 0.4837
# 2/0, train_loss: 0.5464
# 3/0, train_loss: 0.4016
# 0 epoch 138 average loss: 0.4772
# current epoch: 138 current mean dice: 0.58793759
# best mean dice: 0.62356025 at epoch: 134
# ----------
# 0: epoch 139/1000
# 1/0, train_loss: 0.4985
# 2/0, train_loss: 0.5163
# 3/0, train_loss: 0.4717
# 0 epoch 139 average loss: 0.4955
# ----------
# 0: epoch 140/1000
# 1/0, train_loss: 0.5246
# 2/0, train_loss: 0.4866
# 3/0, train_loss: 0.4829
# 0 epoch 140 average loss: 0.4980
# saved new best metric model
# current epoch: 140 current mean dice: 0.63950986
# best mean dice: 0.63950986 at epoch: 140
# ----------
# 0: epoch 141/1000
# 1/0, train_loss: 0.4961
# 2/0, train_loss: 0.5059
# 3/0, train_loss: 0.4846
# 0 epoch 141 average loss: 0.4955
# ----------
# 0: epoch 142/1000
# 1/0, train_loss: 0.4748
# 2/0, train_loss: 0.5319
# 3/0, train_loss: 0.4935
# 0 epoch 142 average loss: 0.5001
# saved new best metric model
# current epoch: 142 current mean dice: 0.65035808
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 143/1000
# 1/0, train_loss: 0.4869
# 2/0, train_loss: 0.4899
# 3/0, train_loss: 0.5625
# 0 epoch 143 average loss: 0.5131
# ----------
# 0: epoch 144/1000
# 1/0, train_loss: 0.5003
# 2/0, train_loss: 0.5114
# 3/0, train_loss: 0.4221
# 0 epoch 144 average loss: 0.4779
# current epoch: 144 current mean dice: 0.57576346
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 145/1000
# 1/0, train_loss: 0.5112
# 2/0, train_loss: 0.4864
# 3/0, train_loss: 0.5181
# 0 epoch 145 average loss: 0.5052
# ----------
# 0: epoch 146/1000
# 1/0, train_loss: 0.4939
# 2/0, train_loss: 0.5017
# 3/0, train_loss: 0.4961
# 0 epoch 146 average loss: 0.4972
# current epoch: 146 current mean dice: 0.55384117
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 147/1000
# 1/0, train_loss: 0.4961
# 2/0, train_loss: 0.5074
# 3/0, train_loss: 0.4197
# 0 epoch 147 average loss: 0.4744
# ----------
# 0: epoch 148/1000
# 1/0, train_loss: 0.5143
# 2/0, train_loss: 0.4643
# 3/0, train_loss: 0.6002
# 0 epoch 148 average loss: 0.5263
# current epoch: 148 current mean dice: 0.64360315
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 149/1000
# 1/0, train_loss: 0.4924
# 2/0, train_loss: 0.4879
# 3/0, train_loss: 0.4906
# 0 epoch 149 average loss: 0.4903
# ----------
# 0: epoch 150/1000
# 1/0, train_loss: 0.4770
# 2/0, train_loss: 0.4979
# 3/0, train_loss: 0.5453
# 0 epoch 150 average loss: 0.5067
# current epoch: 150 current mean dice: 0.64285660
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 151/1000
# 1/0, train_loss: 0.5251
# 2/0, train_loss: 0.4527
# 3/0, train_loss: 0.5678
# 0 epoch 151 average loss: 0.5152
# ----------
# 0: epoch 152/1000
# 1/0, train_loss: 0.4844
# 2/0, train_loss: 0.4911
# 3/0, train_loss: 0.4898
# 0 epoch 152 average loss: 0.4884
# current epoch: 152 current mean dice: 0.61814237
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 153/1000
# 1/0, train_loss: 0.5047
# 2/0, train_loss: 0.4837
# 3/0, train_loss: 0.4544
# 0 epoch 153 average loss: 0.4810
# ----------
# 0: epoch 154/1000
# 1/0, train_loss: 0.4977
# 2/0, train_loss: 0.4829
# 3/0, train_loss: 0.4915
# 0 epoch 154 average loss: 0.4907
# current epoch: 154 current mean dice: 0.60914761
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 155/1000
# 1/0, train_loss: 0.4914
# 2/0, train_loss: 0.4735
# 3/0, train_loss: 0.5701
# 0 epoch 155 average loss: 0.5116
# ----------
# 0: epoch 156/1000
# 1/0, train_loss: 0.4598
# 2/0, train_loss: 0.5189
# 3/0, train_loss: 0.4926
# 0 epoch 156 average loss: 0.4904
# current epoch: 156 current mean dice: 0.63499230
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 157/1000
# 1/0, train_loss: 0.5073
# 2/0, train_loss: 0.4792
# 3/0, train_loss: 0.5129
# 0 epoch 157 average loss: 0.4998
# ----------
# 0: epoch 158/1000
# 1/0, train_loss: 0.4639
# 2/0, train_loss: 0.5140
# 3/0, train_loss: 0.5422
# 0 epoch 158 average loss: 0.5067
# current epoch: 158 current mean dice: 0.61628646
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 159/1000
# 1/0, train_loss: 0.5221
# 2/0, train_loss: 0.4382
# 3/0, train_loss: 0.5762
# 0 epoch 159 average loss: 0.5122
# ----------
# 0: epoch 160/1000
# 1/0, train_loss: 0.4794
# 2/0, train_loss: 0.4976
# 3/0, train_loss: 0.5083
# 0 epoch 160 average loss: 0.4951
# current epoch: 160 current mean dice: 0.57047683
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 161/1000
# 1/0, train_loss: 0.4855
# 2/0, train_loss: 0.4810
# 3/0, train_loss: 0.5504
# 0 epoch 161 average loss: 0.5056
# ----------
# 0: epoch 162/1000
# 1/0, train_loss: 0.4595
# 2/0, train_loss: 0.5134
# 3/0, train_loss: 0.5095
# 0 epoch 162 average loss: 0.4941
# current epoch: 162 current mean dice: 0.63465631
# best mean dice: 0.65035808 at epoch: 142
# ----------
# 0: epoch 163/1000
# 1/0, train_loss: 0.4629
# 2/0, train_loss: 0.4992
# 3/0, train_loss: 0.5343
# 0 epoch 163 average loss: 0.4988
# ----------
# 0: epoch 164/1000
# 1/0, train_loss: 0.5069
# 2/0, train_loss: 0.4828
# 3/0, train_loss: 0.3823
# 0 epoch 164 average loss: 0.4574
# saved new best metric model
# current epoch: 164 current mean dice: 0.69653034
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 165/1000
# 1/0, train_loss: 0.4440
# 2/0, train_loss: 0.5073
# 3/0, train_loss: 0.5352
# 0 epoch 165 average loss: 0.4955
# ----------
# 0: epoch 166/1000
# 1/0, train_loss: 0.5028
# 2/0, train_loss: 0.4666
# 3/0, train_loss: 0.4383
# 0 epoch 166 average loss: 0.4692
# current epoch: 166 current mean dice: 0.61206448
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 167/1000
# 1/0, train_loss: 0.4787
# 2/0, train_loss: 0.4852
# 3/0, train_loss: 0.5339
# 0 epoch 167 average loss: 0.4993
# ----------
# 0: epoch 168/1000
# 1/0, train_loss: 0.4575
# 2/0, train_loss: 0.5101
# 3/0, train_loss: 0.5012
# 0 epoch 168 average loss: 0.4896
# current epoch: 168 current mean dice: 0.60845929
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 169/1000
# 1/0, train_loss: 0.4912
# 2/0, train_loss: 0.4673
# 3/0, train_loss: 0.4918
# 0 epoch 169 average loss: 0.4834
# ----------
# 0: epoch 170/1000
# 1/0, train_loss: 0.5126
# 2/0, train_loss: 0.4397
# 3/0, train_loss: 0.4774
# 0 epoch 170 average loss: 0.4765
# current epoch: 170 current mean dice: 0.64397067
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 171/1000
# 1/0, train_loss: 0.5068
# 2/0, train_loss: 0.4737
# 3/0, train_loss: 0.3780
# 0 epoch 171 average loss: 0.4528
# ----------
# 0: epoch 172/1000
# 1/0, train_loss: 0.4876
# 2/0, train_loss: 0.4705
# 3/0, train_loss: 0.4364
# 0 epoch 172 average loss: 0.4649
# current epoch: 172 current mean dice: 0.64547378
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 173/1000
# 1/0, train_loss: 0.4878
# 2/0, train_loss: 0.4630
# 3/0, train_loss: 0.5428
# 0 epoch 173 average loss: 0.4979
# ----------
# 0: epoch 174/1000
# 1/0, train_loss: 0.4712
# 2/0, train_loss: 0.4930
# 3/0, train_loss: 0.4315
# 0 epoch 174 average loss: 0.4652
# current epoch: 174 current mean dice: 0.61768043
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 175/1000
# 1/0, train_loss: 0.4561
# 2/0, train_loss: 0.4708
# 3/0, train_loss: 0.5757
# 0 epoch 175 average loss: 0.5009
# ----------
# 0: epoch 176/1000
# 1/0, train_loss: 0.4913
# 2/0, train_loss: 0.4591
# 3/0, train_loss: 0.4897
# 0 epoch 176 average loss: 0.4800
# current epoch: 176 current mean dice: 0.62390333
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 177/1000
# 1/0, train_loss: 0.4824
# 2/0, train_loss: 0.4861
# 3/0, train_loss: 0.3882
# 0 epoch 177 average loss: 0.4522
# ----------
# 0: epoch 178/1000
# 1/0, train_loss: 0.4557
# 2/0, train_loss: 0.4964
# 3/0, train_loss: 0.4781
# 0 epoch 178 average loss: 0.4768
# current epoch: 178 current mean dice: 0.61243588
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 179/1000
# 1/0, train_loss: 0.4739
# 2/0, train_loss: 0.4700
# 3/0, train_loss: 0.5160
# 0 epoch 179 average loss: 0.4866
# ----------
# 0: epoch 180/1000
# 1/0, train_loss: 0.4999
# 2/0, train_loss: 0.4547
# 3/0, train_loss: 0.4409
# 0 epoch 180 average loss: 0.4652
# current epoch: 180 current mean dice: 0.66365993
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 181/1000
# 1/0, train_loss: 0.5092
# 2/0, train_loss: 0.4529
# 3/0, train_loss: 0.3767
# 0 epoch 181 average loss: 0.4463
# ----------
# 0: epoch 182/1000
# 1/0, train_loss: 0.4561
# 2/0, train_loss: 0.4986
# 3/0, train_loss: 0.4170
# 0 epoch 182 average loss: 0.4573
# current epoch: 182 current mean dice: 0.54064280
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 183/1000
# 1/0, train_loss: 0.4650
# 2/0, train_loss: 0.4659
# 3/0, train_loss: 0.5190
# 0 epoch 183 average loss: 0.4833
# ----------
# 0: epoch 184/1000
# 1/0, train_loss: 0.5019
# 2/0, train_loss: 0.4360
# 3/0, train_loss: 0.4685
# 0 epoch 184 average loss: 0.4688
# current epoch: 184 current mean dice: 0.60351628
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 185/1000
# 1/0, train_loss: 0.4569
# 2/0, train_loss: 0.4889
# 3/0, train_loss: 0.4556
# 0 epoch 185 average loss: 0.4671
# ----------
# 0: epoch 186/1000
# 1/0, train_loss: 0.4286
# 2/0, train_loss: 0.4815
# 3/0, train_loss: 0.6318
# 0 epoch 186 average loss: 0.5140
# current epoch: 186 current mean dice: 0.68746573
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 187/1000
# 1/0, train_loss: 0.4405
# 2/0, train_loss: 0.4952
# 3/0, train_loss: 0.4799
# 0 epoch 187 average loss: 0.4719
# ----------
# 0: epoch 188/1000
# 1/0, train_loss: 0.5039
# 2/0, train_loss: 0.4483
# 3/0, train_loss: 0.4035
# 0 epoch 188 average loss: 0.4519
# current epoch: 188 current mean dice: 0.61001515
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 189/1000
# 1/0, train_loss: 0.4900
# 2/0, train_loss: 0.4477
# 3/0, train_loss: 0.4881
# 0 epoch 189 average loss: 0.4752
# ----------
# 0: epoch 190/1000
# 1/0, train_loss: 0.4584
# 2/0, train_loss: 0.4667
# 3/0, train_loss: 0.5551
# 0 epoch 190 average loss: 0.4934
# current epoch: 190 current mean dice: 0.65447414
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 191/1000
# 1/0, train_loss: 0.4845
# 2/0, train_loss: 0.4565
# 3/0, train_loss: 0.4111
# 0 epoch 191 average loss: 0.4507
# ----------
# 0: epoch 192/1000
# 1/0, train_loss: 0.4731
# 2/0, train_loss: 0.4548
# 3/0, train_loss: 0.5279
# 0 epoch 192 average loss: 0.4853
# current epoch: 192 current mean dice: 0.68626314
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 193/1000
# 1/0, train_loss: 0.4586
# 2/0, train_loss: 0.4640
# 3/0, train_loss: 0.4652
# 0 epoch 193 average loss: 0.4626
# ----------
# 0: epoch 194/1000
# 1/0, train_loss: 0.4758
# 2/0, train_loss: 0.4550
# 3/0, train_loss: 0.4889
# 0 epoch 194 average loss: 0.4733
# current epoch: 194 current mean dice: 0.57481629
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 195/1000
# 1/0, train_loss: 0.4796
# 2/0, train_loss: 0.4695
# 3/0, train_loss: 0.4520
# 0 epoch 195 average loss: 0.4670
# ----------
# 0: epoch 196/1000
# 1/0, train_loss: 0.4602
# 2/0, train_loss: 0.4737
# 3/0, train_loss: 0.4736
# 0 epoch 196 average loss: 0.4692
# current epoch: 196 current mean dice: 0.58336037
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 197/1000
# 1/0, train_loss: 0.4515
# 2/0, train_loss: 0.4565
# 3/0, train_loss: 0.5347
# 0 epoch 197 average loss: 0.4809
# ----------
# 0: epoch 198/1000
# 1/0, train_loss: 0.4257
# 2/0, train_loss: 0.4753
# 3/0, train_loss: 0.5915
# 0 epoch 198 average loss: 0.4975
# current epoch: 198 current mean dice: 0.67595416
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 199/1000
# 1/0, train_loss: 0.4502
# 2/0, train_loss: 0.4876
# 3/0, train_loss: 0.3737
# 0 epoch 199 average loss: 0.4371
# ----------
# 0: epoch 200/1000
# 1/0, train_loss: 0.4846
# 2/0, train_loss: 0.4387
# 3/0, train_loss: 0.4842
# 0 epoch 200 average loss: 0.4691
# current epoch: 200 current mean dice: 0.65565348
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 201/1000
# 1/0, train_loss: 0.4581
# 2/0, train_loss: 0.4601
# 3/0, train_loss: 0.5105
# 0 epoch 201 average loss: 0.4762
# ----------
# 0: epoch 202/1000
# 1/0, train_loss: 0.4575
# 2/0, train_loss: 0.4426
# 3/0, train_loss: 0.5580
# 0 epoch 202 average loss: 0.4860
# current epoch: 202 current mean dice: 0.61061668
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 203/1000
# 1/0, train_loss: 0.4470
# 2/0, train_loss: 0.4629
# 3/0, train_loss: 0.4829
# 0 epoch 203 average loss: 0.4643
# ----------
# 0: epoch 204/1000
# 1/0, train_loss: 0.4446
# 2/0, train_loss: 0.4806
# 3/0, train_loss: 0.4015
# 0 epoch 204 average loss: 0.4422
# current epoch: 204 current mean dice: 0.69377065
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 205/1000
# 1/0, train_loss: 0.4759
# 2/0, train_loss: 0.4655
# 3/0, train_loss: 0.4107
# 0 epoch 205 average loss: 0.4507
# ----------
# 0: epoch 206/1000
# 1/0, train_loss: 0.4846
# 2/0, train_loss: 0.4254
# 3/0, train_loss: 0.4547
# 0 epoch 206 average loss: 0.4549
# current epoch: 206 current mean dice: 0.65335536
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 207/1000
# 1/0, train_loss: 0.5076
# 2/0, train_loss: 0.4077
# 3/0, train_loss: 0.4522
# 0 epoch 207 average loss: 0.4559
# ----------
# 0: epoch 208/1000
# 1/0, train_loss: 0.4597
# 2/0, train_loss: 0.4549
# 3/0, train_loss: 0.4597
# 0 epoch 208 average loss: 0.4581
# current epoch: 208 current mean dice: 0.65739417
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 209/1000
# 1/0, train_loss: 0.4499
# 2/0, train_loss: 0.4617
# 3/0, train_loss: 0.4238
# 0 epoch 209 average loss: 0.4451
# ----------
# 0: epoch 210/1000
# 1/0, train_loss: 0.4582
# 2/0, train_loss: 0.4637
# 3/0, train_loss: 0.4758
# 0 epoch 210 average loss: 0.4659
# current epoch: 210 current mean dice: 0.62149525
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 211/1000
# 1/0, train_loss: 0.4496
# 2/0, train_loss: 0.4687
# 3/0, train_loss: 0.4900
# 0 epoch 211 average loss: 0.4694
# ----------
# 0: epoch 212/1000
# 1/0, train_loss: 0.4461
# 2/0, train_loss: 0.4400
# 3/0, train_loss: 0.5073
# 0 epoch 212 average loss: 0.4644
# current epoch: 212 current mean dice: 0.55445093
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 213/1000
# 1/0, train_loss: 0.4265
# 2/0, train_loss: 0.4812
# 3/0, train_loss: 0.4176
# 0 epoch 213 average loss: 0.4418
# ----------
# 0: epoch 214/1000
# 1/0, train_loss: 0.4598
# 2/0, train_loss: 0.4604
# 3/0, train_loss: 0.3960
# 0 epoch 214 average loss: 0.4387
# current epoch: 214 current mean dice: 0.66306370
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 215/1000
# 1/0, train_loss: 0.4293
# 2/0, train_loss: 0.4870
# 3/0, train_loss: 0.3960
# 0 epoch 215 average loss: 0.4374
# ----------
# 0: epoch 216/1000
# 1/0, train_loss: 0.4425
# 2/0, train_loss: 0.4733
# 3/0, train_loss: 0.3606
# 0 epoch 216 average loss: 0.4255
# current epoch: 216 current mean dice: 0.64267284
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 217/1000
# 1/0, train_loss: 0.4487
# 2/0, train_loss: 0.4452
# 3/0, train_loss: 0.4639
# 0 epoch 217 average loss: 0.4526
# ----------
# 0: epoch 218/1000
# 1/0, train_loss: 0.5040
# 2/0, train_loss: 0.4123
# 3/0, train_loss: 0.4256
# 0 epoch 218 average loss: 0.4473
# current epoch: 218 current mean dice: 0.59993619
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 219/1000
# 1/0, train_loss: 0.4373
# 2/0, train_loss: 0.4821
# 3/0, train_loss: 0.3543
# 0 epoch 219 average loss: 0.4246
# ----------
# 0: epoch 220/1000
# 1/0, train_loss: 0.4541
# 2/0, train_loss: 0.4528
# 3/0, train_loss: 0.4386
# 0 epoch 220 average loss: 0.4485
# current epoch: 220 current mean dice: 0.67917633
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 221/1000
# 1/0, train_loss: 0.4345
# 2/0, train_loss: 0.4639
# 3/0, train_loss: 0.4284
# 0 epoch 221 average loss: 0.4422
# ----------
# 0: epoch 222/1000
# 1/0, train_loss: 0.4484
# 2/0, train_loss: 0.4442
# 3/0, train_loss: 0.4835
# 0 epoch 222 average loss: 0.4587
# current epoch: 222 current mean dice: 0.64196211
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 223/1000
# 1/0, train_loss: 0.4545
# 2/0, train_loss: 0.4506
# 3/0, train_loss: 0.4562
# 0 epoch 223 average loss: 0.4537
# ----------
# 0: epoch 224/1000
# 1/0, train_loss: 0.4133
# 2/0, train_loss: 0.4720
# 3/0, train_loss: 0.5102
# 0 epoch 224 average loss: 0.4652
# current epoch: 224 current mean dice: 0.50857991
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 225/1000
# 1/0, train_loss: 0.4609
# 2/0, train_loss: 0.4297
# 3/0, train_loss: 0.5118
# 0 epoch 225 average loss: 0.4675
# ----------
# 0: epoch 226/1000
# 1/0, train_loss: 0.4551
# 2/0, train_loss: 0.4636
# 3/0, train_loss: 0.3928
# 0 epoch 226 average loss: 0.4372
# current epoch: 226 current mean dice: 0.54873192
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 227/1000
# 1/0, train_loss: 0.4365
# 2/0, train_loss: 0.4494
# 3/0, train_loss: 0.5255
# 0 epoch 227 average loss: 0.4705
# ----------
# 0: epoch 228/1000
# 1/0, train_loss: 0.4071
# 2/0, train_loss: 0.4827
# 3/0, train_loss: 0.4330
# 0 epoch 228 average loss: 0.4409
# current epoch: 228 current mean dice: 0.66824818
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 229/1000
# 1/0, train_loss: 0.4425
# 2/0, train_loss: 0.4206
# 3/0, train_loss: 0.5508
# 0 epoch 229 average loss: 0.4713
# ----------
# 0: epoch 230/1000
# 1/0, train_loss: 0.4540
# 2/0, train_loss: 0.4227
# 3/0, train_loss: 0.4968
# 0 epoch 230 average loss: 0.4578
# current epoch: 230 current mean dice: 0.45488834
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 231/1000
# 1/0, train_loss: 0.4139
# 2/0, train_loss: 0.4675
# 3/0, train_loss: 0.5293
# 0 epoch 231 average loss: 0.4703
# ----------
# 0: epoch 232/1000
# 1/0, train_loss: 0.4405
# 2/0, train_loss: 0.4462
# 3/0, train_loss: 0.4396
# 0 epoch 232 average loss: 0.4421
# current epoch: 232 current mean dice: 0.64424056
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 233/1000
# 1/0, train_loss: 0.4379
# 2/0, train_loss: 0.4419
# 3/0, train_loss: 0.4239
# 0 epoch 233 average loss: 0.4346
# ----------
# 0: epoch 234/1000
# 1/0, train_loss: 0.4130
# 2/0, train_loss: 0.4842
# 3/0, train_loss: 0.4529
# 0 epoch 234 average loss: 0.4500
# current epoch: 234 current mean dice: 0.58048481
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 235/1000
# 1/0, train_loss: 0.4734
# 2/0, train_loss: 0.3880
# 3/0, train_loss: 0.5075
# 0 epoch 235 average loss: 0.4563
# ----------
# 0: epoch 236/1000
# 1/0, train_loss: 0.4650
# 2/0, train_loss: 0.4363
# 3/0, train_loss: 0.3504
# 0 epoch 236 average loss: 0.4172
# current epoch: 236 current mean dice: 0.58147788
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 237/1000
# 1/0, train_loss: 0.4117
# 2/0, train_loss: 0.4529
# 3/0, train_loss: 0.4952
# 0 epoch 237 average loss: 0.4533
# ----------
# 0: epoch 238/1000
# 1/0, train_loss: 0.4223
# 2/0, train_loss: 0.4479
# 3/0, train_loss: 0.4850
# 0 epoch 238 average loss: 0.4517
# current epoch: 238 current mean dice: 0.68350720
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 239/1000
# 1/0, train_loss: 0.4083
# 2/0, train_loss: 0.4485
# 3/0, train_loss: 0.5592
# 0 epoch 239 average loss: 0.4720
# ----------
# 0: epoch 240/1000
# 1/0, train_loss: 0.4469
# 2/0, train_loss: 0.4406
# 3/0, train_loss: 0.3965
# 0 epoch 240 average loss: 0.4280
# current epoch: 240 current mean dice: 0.68927592
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 241/1000
# 1/0, train_loss: 0.4266
# 2/0, train_loss: 0.4397
# 3/0, train_loss: 0.5045
# 0 epoch 241 average loss: 0.4569
# ----------
# 0: epoch 242/1000
# 1/0, train_loss: 0.3767
# 2/0, train_loss: 0.4725
# 3/0, train_loss: 0.5363
# 0 epoch 242 average loss: 0.4619
# current epoch: 242 current mean dice: 0.59189862
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 243/1000
# 1/0, train_loss: 0.4081
# 2/0, train_loss: 0.4819
# 3/0, train_loss: 0.3972
# 0 epoch 243 average loss: 0.4291
# ----------
# 0: epoch 244/1000
# 1/0, train_loss: 0.4511
# 2/0, train_loss: 0.4227
# 3/0, train_loss: 0.4786
# 0 epoch 244 average loss: 0.4508
# current epoch: 244 current mean dice: 0.68300670
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 245/1000
# 1/0, train_loss: 0.4544
# 2/0, train_loss: 0.4202
# 3/0, train_loss: 0.4026
# 0 epoch 245 average loss: 0.4258
# ----------
# 0: epoch 246/1000
# 1/0, train_loss: 0.3806
# 2/0, train_loss: 0.4693
# 3/0, train_loss: 0.5524
# 0 epoch 246 average loss: 0.4675
# current epoch: 246 current mean dice: 0.67943400
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 247/1000
# 1/0, train_loss: 0.4239
# 2/0, train_loss: 0.4552
# 3/0, train_loss: 0.3791
# 0 epoch 247 average loss: 0.4194
# ----------
# 0: epoch 248/1000
# 1/0, train_loss: 0.4348
# 2/0, train_loss: 0.4398
# 3/0, train_loss: 0.4073
# 0 epoch 248 average loss: 0.4273
# current epoch: 248 current mean dice: 0.67167926
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 249/1000
# 1/0, train_loss: 0.4752
# 2/0, train_loss: 0.3964
# 3/0, train_loss: 0.4463
# 0 epoch 249 average loss: 0.4393
# ----------
# 0: epoch 250/1000
# 1/0, train_loss: 0.4389
# 2/0, train_loss: 0.4276
# 3/0, train_loss: 0.4808
# 0 epoch 250 average loss: 0.4491
# current epoch: 250 current mean dice: 0.63577425
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 251/1000
# 1/0, train_loss: 0.4058
# 2/0, train_loss: 0.4648
# 3/0, train_loss: 0.4111
# 0 epoch 251 average loss: 0.4272
# ----------
# 0: epoch 252/1000
# 1/0, train_loss: 0.4316
# 2/0, train_loss: 0.4471
# 3/0, train_loss: 0.3803
# 0 epoch 252 average loss: 0.4197
# current epoch: 252 current mean dice: 0.65558094
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 253/1000
# 1/0, train_loss: 0.4215
# 2/0, train_loss: 0.4452
# 3/0, train_loss: 0.4340
# 0 epoch 253 average loss: 0.4335
# ----------
# 0: epoch 254/1000
# 1/0, train_loss: 0.4435
# 2/0, train_loss: 0.4100
# 3/0, train_loss: 0.4989
# 0 epoch 254 average loss: 0.4508
# current epoch: 254 current mean dice: 0.63844484
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 255/1000
# 1/0, train_loss: 0.4272
# 2/0, train_loss: 0.4456
# 3/0, train_loss: 0.3701
# 0 epoch 255 average loss: 0.4143
# ----------
# 0: epoch 256/1000
# 1/0, train_loss: 0.4397
# 2/0, train_loss: 0.4272
# 3/0, train_loss: 0.4449
# 0 epoch 256 average loss: 0.4373
# current epoch: 256 current mean dice: 0.57437062
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 257/1000
# 1/0, train_loss: 0.4808
# 2/0, train_loss: 0.3787
# 3/0, train_loss: 0.4338
# 0 epoch 257 average loss: 0.4311
# ----------
# 0: epoch 258/1000
# 1/0, train_loss: 0.4070
# 2/0, train_loss: 0.4623
# 3/0, train_loss: 0.4682
# 0 epoch 258 average loss: 0.4458
# current epoch: 258 current mean dice: 0.66622394
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 259/1000
# 1/0, train_loss: 0.4462
# 2/0, train_loss: 0.4260
# 3/0, train_loss: 0.4461
# 0 epoch 259 average loss: 0.4394
# ----------
# 0: epoch 260/1000
# 1/0, train_loss: 0.4460
# 2/0, train_loss: 0.4072
# 3/0, train_loss: 0.5152
# 0 epoch 260 average loss: 0.4561
# current epoch: 260 current mean dice: 0.67949963
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 261/1000
# 1/0, train_loss: 0.4415
# 2/0, train_loss: 0.4239
# 3/0, train_loss: 0.4834
# 0 epoch 261 average loss: 0.4496
# ----------
# 0: epoch 262/1000
# 1/0, train_loss: 0.4280
# 2/0, train_loss: 0.4323
# 3/0, train_loss: 0.4332
# 0 epoch 262 average loss: 0.4312
# current epoch: 262 current mean dice: 0.63859630
# best mean dice: 0.69653034 at epoch: 164
# ----------
# 0: epoch 263/1000
# 1/0, train_loss: 0.4014
# 2/0, train_loss: 0.4588
# 3/0, train_loss: 0.4240
# 0 epoch 263 average loss: 0.4281
# ----------
# 0: epoch 264/1000
# ...
# best mean dice: 0.75806177 at epoch: 824
# ----------
# 9: epoch 899/1000
# 1/0, train_loss: 0.2987
# 2/0, train_loss: 0.3493
# 9 epoch 899 average loss: 0.3240
# ----------
# 9: epoch 900/1000
# 1/0, train_loss: 0.3298
# 2/0, train_loss: 0.3239
# 9 epoch 900 average loss: 0.3269
# saved new best metric model
# current epoch: 900 current mean dice: 0.75897998
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 901/1000
# 1/0, train_loss: 0.3214
# 2/0, train_loss: 0.3416
# 9 epoch 901 average loss: 0.3315
# ----------
# 9: epoch 902/1000
# 1/0, train_loss: 0.3536
# 2/0, train_loss: 0.3130
# 9 epoch 902 average loss: 0.3333
# current epoch: 902 current mean dice: 0.75236118
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 903/1000
# 1/0, train_loss: 0.3459
# 2/0, train_loss: 0.3050
# 9 epoch 903 average loss: 0.3255
# ----------
# 9: epoch 904/1000
# 1/0, train_loss: 0.3271
# 2/0, train_loss: 0.3275
# 9 epoch 904 average loss: 0.3273
# current epoch: 904 current mean dice: 0.69936210
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 905/1000
# 1/0, train_loss: 0.3422
# 2/0, train_loss: 0.3096
# 9 epoch 905 average loss: 0.3259
# ----------
# 9: epoch 906/1000
# 1/0, train_loss: 0.3147
# 2/0, train_loss: 0.3455
# 9 epoch 906 average loss: 0.3301
# current epoch: 906 current mean dice: 0.72645879
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 907/1000
# 1/0, train_loss: 0.3128
# 2/0, train_loss: 0.3285
# 9 epoch 907 average loss: 0.3206
# ----------
# 9: epoch 908/1000
# 1/0, train_loss: 0.2899
# 2/0, train_loss: 0.3550
# 9 epoch 908 average loss: 0.3225
# current epoch: 908 current mean dice: 0.70986521
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 909/1000
# 1/0, train_loss: 0.3445
# 2/0, train_loss: 0.3166
# 9 epoch 909 average loss: 0.3306
# ----------
# 9: epoch 910/1000
# 1/0, train_loss: 0.3464
# 2/0, train_loss: 0.3239
# 9 epoch 910 average loss: 0.3352
# current epoch: 910 current mean dice: 0.72590965
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 911/1000
# 1/0, train_loss: 0.2899
# 2/0, train_loss: 0.3583
# 9 epoch 911 average loss: 0.3241
# ----------
# 9: epoch 912/1000
# 1/0, train_loss: 0.3741
# 2/0, train_loss: 0.2795
# 9 epoch 912 average loss: 0.3268
# current epoch: 912 current mean dice: 0.75020552
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 913/1000
# 1/0, train_loss: 0.2766
# 2/0, train_loss: 0.3579
# 9 epoch 913 average loss: 0.3172
# ----------
# 9: epoch 914/1000
# 1/0, train_loss: 0.3232
# 2/0, train_loss: 0.3195
# 9 epoch 914 average loss: 0.3213
# current epoch: 914 current mean dice: 0.74432164
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 915/1000
# 1/0, train_loss: 0.3335
# 2/0, train_loss: 0.3188
# 9 epoch 915 average loss: 0.3262
# ----------
# 9: epoch 916/1000
# 1/0, train_loss: 0.3010
# 2/0, train_loss: 0.3402
# 9 epoch 916 average loss: 0.3206
# current epoch: 916 current mean dice: 0.74263275
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 917/1000
# 1/0, train_loss: 0.3527
# 2/0, train_loss: 0.2842
# 9 epoch 917 average loss: 0.3184
# ----------
# 9: epoch 918/1000
# 1/0, train_loss: 0.3075
# 2/0, train_loss: 0.3393
# 9 epoch 918 average loss: 0.3234
# current epoch: 918 current mean dice: 0.74314106
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 919/1000
# 1/0, train_loss: 0.3579
# 2/0, train_loss: 0.2933
# 9 epoch 919 average loss: 0.3256
# ----------
# 9: epoch 920/1000
# 1/0, train_loss: 0.3360
# 2/0, train_loss: 0.3006
# 9 epoch 920 average loss: 0.3183
# current epoch: 920 current mean dice: 0.74993175
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 921/1000
# 1/0, train_loss: 0.3537
# 2/0, train_loss: 0.2958
# 9 epoch 921 average loss: 0.3248
# ----------
# 9: epoch 922/1000
# 1/0, train_loss: 0.2792
# 2/0, train_loss: 0.3607
# 9 epoch 922 average loss: 0.3200
# current epoch: 922 current mean dice: 0.75408244
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 923/1000
# 1/0, train_loss: 0.3463
# 2/0, train_loss: 0.3026
# 9 epoch 923 average loss: 0.3244
# ----------
# 9: epoch 924/1000
# 1/0, train_loss: 0.3654
# 2/0, train_loss: 0.2895
# 9 epoch 924 average loss: 0.3274
# current epoch: 924 current mean dice: 0.73484069
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 925/1000
# 1/0, train_loss: 0.2881
# 2/0, train_loss: 0.3644
# 9 epoch 925 average loss: 0.3263
# ----------
# 9: epoch 926/1000
# 1/0, train_loss: 0.3490
# 2/0, train_loss: 0.2974
# 9 epoch 926 average loss: 0.3232
# current epoch: 926 current mean dice: 0.74196315
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 927/1000
# 1/0, train_loss: 0.3364
# 2/0, train_loss: 0.3063
# 9 epoch 927 average loss: 0.3214
# ----------
# 9: epoch 928/1000
# 1/0, train_loss: 0.3359
# 2/0, train_loss: 0.3112
# 9 epoch 928 average loss: 0.3236
# current epoch: 928 current mean dice: 0.73531640
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 929/1000
# 1/0, train_loss: 0.3277
# 2/0, train_loss: 0.3143
# 9 epoch 929 average loss: 0.3210
# ----------
# 9: epoch 930/1000
# 1/0, train_loss: 0.3034
# 2/0, train_loss: 0.3319
# 9 epoch 930 average loss: 0.3177
# current epoch: 930 current mean dice: 0.74506038
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 931/1000
# 1/0, train_loss: 0.3447
# 2/0, train_loss: 0.2989
# 9 epoch 931 average loss: 0.3218
# ----------
# 9: epoch 932/1000
# 1/0, train_loss: 0.3587
# 2/0, train_loss: 0.2748
# 9 epoch 932 average loss: 0.3167
# current epoch: 932 current mean dice: 0.72775984
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 933/1000
# 1/0, train_loss: 0.3259
# 2/0, train_loss: 0.3114
# 9 epoch 933 average loss: 0.3186
# ----------
# 9: epoch 934/1000
# 1/0, train_loss: 0.3120
# 2/0, train_loss: 0.3283
# 9 epoch 934 average loss: 0.3202
# current epoch: 934 current mean dice: 0.74106520
# best mean dice: 0.75897998 at epoch: 900
# ----------
# 9: epoch 935/1000
# 1/0, train_loss: 0.3257
# 2/0, train_loss: 0.3365
# 9 epoch 935 average loss: 0.3311
# ----------
# 9: epoch 936/1000
# 1/0, train_loss: 0.3332
# 2/0, train_loss: 0.3114
# 9 epoch 936 average loss: 0.3223
# saved new best metric model
# current epoch: 936 current mean dice: 0.75916898
# best mean dice: 0.75916898 at epoch: 936
# ----------
# 9: epoch 937/1000
# 1/0, train_loss: 0.2992
# 2/0, train_loss: 0.3620
# 9 epoch 937 average loss: 0.3306
# ----------
# 9: epoch 938/1000
# 1/0, train_loss: 0.2554
# 2/0, train_loss: 0.3874
# 9 epoch 938 average loss: 0.3214
# current epoch: 938 current mean dice: 0.75841695
# best mean dice: 0.75916898 at epoch: 936
# ----------
# 9: epoch 939/1000
# 1/0, train_loss: 0.3140
# 2/0, train_loss: 0.3251
# 9 epoch 939 average loss: 0.3195
# ----------
# 9: epoch 940/1000
# 1/0, train_loss: 0.3704
# 2/0, train_loss: 0.2681
# 9 epoch 940 average loss: 0.3192
# saved new best metric model
# current epoch: 940 current mean dice: 0.76490986
# best mean dice: 0.76490986 at epoch: 940
# ----------
# 9: epoch 941/1000
# 1/0, train_loss: 0.3413
# 2/0, train_loss: 0.2993
# 9 epoch 941 average loss: 0.3203
# ----------
# 9: epoch 942/1000
# 1/0, train_loss: 0.3250
# 2/0, train_loss: 0.3125
# 9 epoch 942 average loss: 0.3187
# current epoch: 942 current mean dice: 0.75988901
# best mean dice: 0.76490986 at epoch: 940
# ----------
# 9: epoch 943/1000
# 1/0, train_loss: 0.2708
# 2/0, train_loss: 0.3781
# 9 epoch 943 average loss: 0.3244
# ----------
# 9: epoch 944/1000
# 1/0, train_loss: 0.2812
# 2/0, train_loss: 0.3751
# 9 epoch 944 average loss: 0.3281
# current epoch: 944 current mean dice: 0.75805712
# best mean dice: 0.76490986 at epoch: 940
# ----------
# 9: epoch 945/1000
# 1/0, train_loss: 0.3221
# 2/0, train_loss: 0.3213
# 9 epoch 945 average loss: 0.3217
# ----------
# 9: epoch 946/1000
# 1/0, train_loss: 0.3288
# 2/0, train_loss: 0.3148
# 9 epoch 946 average loss: 0.3218
# saved new best metric model
# current epoch: 946 current mean dice: 0.76555282
# best mean dice: 0.76555282 at epoch: 946
# ----------
# 9: epoch 947/1000
# 1/0, train_loss: 0.2872
# 2/0, train_loss: 0.3529
# 9 epoch 947 average loss: 0.3200
# ----------
# 9: epoch 948/1000
# 1/0, train_loss: 0.3362
# 2/0, train_loss: 0.3221
# 9 epoch 948 average loss: 0.3291
# current epoch: 948 current mean dice: 0.76470959
# best mean dice: 0.76555282 at epoch: 946
# ----------
# 9: epoch 949/1000
# 1/0, train_loss: 0.3406
# 2/0, train_loss: 0.3031
# 9 epoch 949 average loss: 0.3218
# ----------
# 9: epoch 950/1000
# 1/0, train_loss: 0.3350
# 2/0, train_loss: 0.3002
# 9 epoch 950 average loss: 0.3176
# saved new best metric model
# current epoch: 950 current mean dice: 0.76812541
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 951/1000
# 1/0, train_loss: 0.3287
# 2/0, train_loss: 0.3080
# 9 epoch 951 average loss: 0.3184
# ----------
# 9: epoch 952/1000
# 1/0, train_loss: 0.3308
# 2/0, train_loss: 0.3174
# 9 epoch 952 average loss: 0.3241
# current epoch: 952 current mean dice: 0.76298857
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 953/1000
# 1/0, train_loss: 0.3332
# 2/0, train_loss: 0.3136
# 9 epoch 953 average loss: 0.3234
# ----------
# 9: epoch 954/1000
# 1/0, train_loss: 0.3349
# 2/0, train_loss: 0.2978
# 9 epoch 954 average loss: 0.3164
# current epoch: 954 current mean dice: 0.75123483
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 955/1000
# 1/0, train_loss: 0.3249
# 2/0, train_loss: 0.3149
# 9 epoch 955 average loss: 0.3199
# ----------
# 9: epoch 956/1000
# 1/0, train_loss: 0.3793
# 2/0, train_loss: 0.2670
# 9 epoch 956 average loss: 0.3232
# current epoch: 956 current mean dice: 0.75651413
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 957/1000
# 1/0, train_loss: 0.3333
# 2/0, train_loss: 0.3049
# 9 epoch 957 average loss: 0.3191
# ----------
# 9: epoch 958/1000
# 1/0, train_loss: 0.3654
# 2/0, train_loss: 0.2835
# 9 epoch 958 average loss: 0.3244
# current epoch: 958 current mean dice: 0.75867546
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 959/1000
# 1/0, train_loss: 0.3419
# 2/0, train_loss: 0.3058
# 9 epoch 959 average loss: 0.3238
# ----------
# 9: epoch 960/1000
# 1/0, train_loss: 0.2985
# 2/0, train_loss: 0.3374
# 9 epoch 960 average loss: 0.3179
# current epoch: 960 current mean dice: 0.73830539
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 961/1000
# 1/0, train_loss: 0.3177
# 2/0, train_loss: 0.3209
# 9 epoch 961 average loss: 0.3193
# ----------
# 9: epoch 962/1000
# 1/0, train_loss: 0.3533
# 2/0, train_loss: 0.2908
# 9 epoch 962 average loss: 0.3221
# current epoch: 962 current mean dice: 0.75429976
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 963/1000
# 1/0, train_loss: 0.3038
# 2/0, train_loss: 0.3444
# 9 epoch 963 average loss: 0.3241
# ----------
# 9: epoch 964/1000
# 1/0, train_loss: 0.2997
# 2/0, train_loss: 0.3461
# 9 epoch 964 average loss: 0.3229
# current epoch: 964 current mean dice: 0.75740200
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 965/1000
# 1/0, train_loss: 0.3471
# 2/0, train_loss: 0.2895
# 9 epoch 965 average loss: 0.3183
# ----------
# 9: epoch 966/1000
# 1/0, train_loss: 0.2829
# 2/0, train_loss: 0.3602
# 9 epoch 966 average loss: 0.3216
# current epoch: 966 current mean dice: 0.72862387
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 967/1000
# 1/0, train_loss: 0.3200
# 2/0, train_loss: 0.3157
# 9 epoch 967 average loss: 0.3178
# ----------
# 9: epoch 968/1000
# 1/0, train_loss: 0.3188
# 2/0, train_loss: 0.3204
# 9 epoch 968 average loss: 0.3196
# current epoch: 968 current mean dice: 0.74874204
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 969/1000
# 1/0, train_loss: 0.3216
# 2/0, train_loss: 0.3134
# 9 epoch 969 average loss: 0.3175
# ----------
# 9: epoch 970/1000
# 1/0, train_loss: 0.3564
# 2/0, train_loss: 0.2914
# 9 epoch 970 average loss: 0.3239
# current epoch: 970 current mean dice: 0.75060135
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 971/1000
# 1/0, train_loss: 0.3063
# 2/0, train_loss: 0.3349
# 9 epoch 971 average loss: 0.3206
# ----------
# 9: epoch 972/1000
# 1/0, train_loss: 0.3552
# 2/0, train_loss: 0.2863
# 9 epoch 972 average loss: 0.3207
# current epoch: 972 current mean dice: 0.75280714
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 973/1000
# 1/0, train_loss: 0.3316
# 2/0, train_loss: 0.3139
# 9 epoch 973 average loss: 0.3227
# ----------
# 9: epoch 974/1000
# 1/0, train_loss: 0.3359
# 2/0, train_loss: 0.2973
# 9 epoch 974 average loss: 0.3166
# current epoch: 974 current mean dice: 0.74694401
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 975/1000
# 1/0, train_loss: 0.3234
# 2/0, train_loss: 0.3264
# 9 epoch 975 average loss: 0.3249
# ----------
# 9: epoch 976/1000
# 1/0, train_loss: 0.3230
# 2/0, train_loss: 0.3221
# 9 epoch 976 average loss: 0.3225
# current epoch: 976 current mean dice: 0.74249762
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 977/1000
# 1/0, train_loss: 0.3452
# 2/0, train_loss: 0.2889
# 9 epoch 977 average loss: 0.3171
# ----------
# 9: epoch 978/1000
# 1/0, train_loss: 0.3409
# 2/0, train_loss: 0.3140
# 9 epoch 978 average loss: 0.3274
# current epoch: 978 current mean dice: 0.72365534
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 979/1000
# 1/0, train_loss: 0.2890
# 2/0, train_loss: 0.3601
# 9 epoch 979 average loss: 0.3246
# ----------
# 9: epoch 980/1000
# 1/0, train_loss: 0.2947
# 2/0, train_loss: 0.3461
# 9 epoch 980 average loss: 0.3204
# current epoch: 980 current mean dice: 0.75500047
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 981/1000
# 1/0, train_loss: 0.3185
# 2/0, train_loss: 0.3272
# 9 epoch 981 average loss: 0.3228
# ----------
# 9: epoch 982/1000
# 1/0, train_loss: 0.3056
# 2/0, train_loss: 0.3199
# 9 epoch 982 average loss: 0.3128
# current epoch: 982 current mean dice: 0.76368886
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 983/1000
# 1/0, train_loss: 0.3076
# 2/0, train_loss: 0.3422
# 9 epoch 983 average loss: 0.3249
# ----------
# 9: epoch 984/1000
# 1/0, train_loss: 0.3699
# 2/0, train_loss: 0.2577
# 9 epoch 984 average loss: 0.3138
# current epoch: 984 current mean dice: 0.75546753
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 985/1000
# 1/0, train_loss: 0.2884
# 2/0, train_loss: 0.3452
# 9 epoch 985 average loss: 0.3168
# ----------
# 9: epoch 986/1000
# 1/0, train_loss: 0.3101
# 2/0, train_loss: 0.3313
# 9 epoch 986 average loss: 0.3207
# current epoch: 986 current mean dice: 0.75673997
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 987/1000
# 1/0, train_loss: 0.2727
# 2/0, train_loss: 0.3668
# 9 epoch 987 average loss: 0.3198
# ----------
# 9: epoch 988/1000
# 1/0, train_loss: 0.3201
# 2/0, train_loss: 0.3188
# 9 epoch 988 average loss: 0.3194
# current epoch: 988 current mean dice: 0.76564109
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 989/1000
# 1/0, train_loss: 0.3300
# 2/0, train_loss: 0.3170
# 9 epoch 989 average loss: 0.3235
# ----------
# 9: epoch 990/1000
# 1/0, train_loss: 0.3193
# 2/0, train_loss: 0.3093
# 9 epoch 990 average loss: 0.3143
# current epoch: 990 current mean dice: 0.76594430
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 991/1000
# 1/0, train_loss: 0.2799
# 2/0, train_loss: 0.3603
# 9 epoch 991 average loss: 0.3201
# ----------
# 9: epoch 992/1000
# 1/0, train_loss: 0.3214
# 2/0, train_loss: 0.3048
# 9 epoch 992 average loss: 0.3131
# current epoch: 992 current mean dice: 0.75065523
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 993/1000
# 1/0, train_loss: 0.3474
# 2/0, train_loss: 0.3193
# 9 epoch 993 average loss: 0.3334
# ----------
# 9: epoch 994/1000
# 1/0, train_loss: 0.2648
# 2/0, train_loss: 0.3710
# 9 epoch 994 average loss: 0.3179
# current epoch: 994 current mean dice: 0.73950672
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 995/1000
# 1/0, train_loss: 0.2617
# 2/0, train_loss: 0.3882
# 9 epoch 995 average loss: 0.3250
# ----------
# 9: epoch 996/1000
# 1/0, train_loss: 0.3262
# 2/0, train_loss: 0.3058
# 9 epoch 996 average loss: 0.3160
# current epoch: 996 current mean dice: 0.74668998
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 997/1000
# 1/0, train_loss: 0.3271
# 2/0, train_loss: 0.3058
# 9 epoch 997 average loss: 0.3165
# ----------
# 9: epoch 998/1000
# 1/0, train_loss: 0.2986
# 2/0, train_loss: 0.3316
# 9 epoch 998 average loss: 0.3151
# current epoch: 998 current mean dice: 0.75011760
# best mean dice: 0.76812541 at epoch: 950
# ----------
# 9: epoch 999/1000
# 1/0, train_loss: 0.3218
# 2/0, train_loss: 0.3212
# 9 epoch 999 average loss: 0.3215
# ----------
# 9: epoch 1000/1000
# 1/0, train_loss: 0.2748
# 2/0, train_loss: 0.3504
# 9 epoch 1000 average loss: 0.3126
# current epoch: 1000 current mean dice: 0.76768488
# best mean dice: 0.76812541 at epoch: 950
