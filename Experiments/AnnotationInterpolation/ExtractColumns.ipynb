# %%
import numpy as np
import scipy as sp

import scipy
from scipy.stats import multivariate_normal
from scipy       import optimize

import skimage

import matplotlib.pyplot as plt

import pylab

from glob import glob
import sys
import os

from tqdm import tqdm

import math

from glob import glob

import matplotlib.pyplot as plt

import itk
from itk import TubeTK as ttk

import av
import ffmpeg

import json

import site
site.addsitedir('../../ARGUS')
from ARGUSUtils_IO import *
from ARGUSUtils_Linearization import *

# %%
def extract_columns(pathname, output_pathname):
    data_paths = sorted(glob(pathname+"-Annotations-Linear/*_?????.mha"))
    data_overlay_paths = sorted(glob(pathname+"-Annotations-Linear/*_?????.extruded-overlay.mha"))
        
    num_overlays = len(data_overlay_paths)
    for i in range(num_overlays):
        img = itk.imread(data_paths[i], itk.F)
        ovrimg = itk.imread(data_overlay_paths[i], itk.UC)
        print("Processing", data_overlay_paths[i])
        
        nos = 0
        rib = 0
        sli = 0
        c = 0
        while c<ovrimg.shape[2]:
            nos = np.count_nonzero(ovrimg[:,:,c]==1)
            rib = np.count_nonzero(ovrimg[:,:,c]==2)
            sli = np.count_nonzero(ovrimg[:,:,c]==3)
            start_c = 0
            end_c = 0
            val_c = 0
            name_c = ''
            if nos>0 and rib==0 and sli==0:
                val_c = 1
                name_c = "N"
            elif nos==0 and rib>0 and sli==0:
                val_c = 2
                name_c = "R"
            elif nos==0 and rib==0 and sli>0:
                val_c = 3
                name_c = "S"
            else:
                c += 1
                continue
            start_c = c
            end_c = c
            count = 1
            while count>0 and c<ovrimg.shape[2]:
                c += 1
                count = np.count_nonzero(ovrimg[:,:,c]==val_c)
            end_c = c
            outimg = img[:,:,start_c:end_c]
            
            (filepath,filename) = os.path.split(data_overlay_paths[i])
            
            new_name = output_pathname+"/"+filename.split('.')[0]+'_Class'+name_c+'_'+str(start_c)+'-'+str(end_c)+'.mha'
            itkimg = itk.GetImageFromArray(outimg.astype(np.float32))
            itk.imwrite(itkimg, new_name, compression=True)

# %%
output_pathname = "../../Data/VFoldData/ColumnData"

#pathname = "../../Data/VFoldData/BAMC-PTXNoSliding"
pathname = "../../Data/VFoldData/BAMC-PTXSliding"

extract_columns(pathname, output_pathname)
# Out:
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\004s_iimage_73815992352100_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\004s_iimage_74132233134844_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\019s_iimage_10705997566592_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\019s_iimage_10891015221417_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\030s_iimage_1180496934444_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\030s_iimage_677741729740_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\034s_iimage_3368391807672_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\034s_iimage_3401832241774_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\037s_iimage_588413346180_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\043s_iimage_10391571128899_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\043s_iimage_10395655826502_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\065s_iimage_1896534330004_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\065s_iimage_1901852337971_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\081s_iimage_2959672151786_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\081s_iimage_3320344386805_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\206s_iimage_1499268364374_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\206s_iimage_1511338287338_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\208s_iimage_104543812690743_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\208s_iimage_104548309385533_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\208s_iimage_104932526155699_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\211s_iimage_3925135436261_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\211s_iimage_3929217595322_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\212s_iimage_128683942015128_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\212s_iimage_128688523296793_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\212s_iimage_128692595484031_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\224s_iimage_3308406916756_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\224s_iimage_3315947589826_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\228s_iimage_3321463845606_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\228s_iimage_3384882513134_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\236s_iimage_1139765223418_CLEAN.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\236s_iimage_1327616672148_clean.extruded-overlay.mha
# Processing ../../Data/VFoldData/BAMC-PTXSliding-Annotations-Linear\237s_iimage_24164968068436_CLEAN.extruded-overlay.mha
