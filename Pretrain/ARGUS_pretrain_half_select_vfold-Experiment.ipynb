# %%
import site
site.addsitedir("../ARGUS")

from ARGUS_segmentation_train import ARGUS_segmentation_train

# %%
nnet = ARGUS_segmentation_train("ARGUS_pretrain_half_ar.cfg", "vfold", device_num=0)
nnet.image_dirname = ["Data_Pretrain/images_ptx"]
nnet.label_dirname = ["Data_Pretrain/labels_ptx"]
nnet.num_folds = 1
nnet.randomize_folds = False
nnet.train_data_portion = 1.0
nnet.validation_data_portion = 1.0
nnet.test_data_portion = 1.0

# %%
nnet.setup_vfold_files()
# Out:
# Num images / labels = 62 62
# Num pos / Num neg = 62 / 0
# VFold-Prefix[0] = ['n025ns_Image_262499', 'n025ns_image_267456', 'n026ns_image_108329', 'n026ns_image_108776', 'n027ns_image_464164', 'n027ns_image_474388', 'n035ns_image_139446', 'n035ns_image_140480', 'n048ns_image_154357', 'n048ns_image_174955', 'n055ns_image_271807', 'n055ns_image_271854', 'n117ns_image_417221', 'n117ns_image_426794', 'n135ns_image_241816', 'n135ns_image_245452', 'n193ns_image_634125', 'n193ns_image_642169', 'n210ns_image_603665', 'n210ns_image_614587', 'n215ns_image_573611', 'n215ns_image_610066', 'n218ns_image_605697', 'n218ns_image_637041', 'n219ns_image_188416', 'n219ns_image_189528', 'n221ns_image_584357', 'n221ns_image_588695', 'n247ns_image_273488', 'n247ns_image_274308', 's004s_iimage_738159', 's004s_iimage_741322', 's019s_iimage_107059', 's019s_iimage_108910', 's030s_iimage_118049', 's030s_iimage_677741', 's034s_iimage_336839', 's034s_iimage_340183', 's037s_iimage_588413', 's043s_iimage_103915', 's043s_iimage_103956', 's065s_iimage_189653', 's065s_iimage_190185', 's081s_iimage_295967', 's081s_iimage_332034', 's206s_iimage_149926', 's206s_iimage_151133', 's208s_iimage_104543', 's208s_iimage_104548', 's208s_iimage_104932', 's211s_iimage_392513', 's211s_iimage_392921', 's212s_iimage_128683', 's212s_iimage_128688', 's212s_iimage_128692', 's224s_iimage_330840', 's224s_iimage_331594', 's228s_iimage_332146', 's228s_iimage_338488', 's236s_iimage_113976', 's236s_iimage_132761', 's237s_iimage_241649']

# %%
for r in range(1): #nnet.num_models):
    for f in range(5):
        nnet.view_training_metric_curves(vfold_num=f,run_id=0)

# %%
nnet.setup_testing_vfold(vfold_num=0)

# %%
for vf in range(5):
    test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0], model_vfold=vf, summary_only=True)
# Out:
# VFOLD = 0 of 0
#    Using model from vfold 0
#   Test Mean Dice Score =  0.6217673420906067
# VFOLD = 0 of 0
#    Using model from vfold 1
#   Test Mean Dice Score =  0.6322627663612366
# VFOLD = 0 of 0
#    Using model from vfold 2
#   Test Mean Dice Score =  0.56623774766922
# VFOLD = 0 of 0
#    Using model from vfold 3
#   Test Mean Dice Score =  0.5726719498634338
# VFOLD = 0 of 0
#    Using model from vfold 4
#   Test Mean Dice Score =  0.540450930595398
