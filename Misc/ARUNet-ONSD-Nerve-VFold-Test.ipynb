# %%
from experiments.ONSD.ARUNet_Nerve_Network import ARUNet_Nerve_Network
from utils.ARGUS_vfold_setup import *
from utils.ARGUS_UNet_train_test import *
from utils.ARGUS_visualization import *
import argparse

# %%
img_folder = "/data/barry.ravichandran/repos/AnatomicRecon-POCUS-AI/ONSD/Data_ONSD/Preprocessed/Resized/"
annotations_folder = "/data/barry.ravichandran/repos/AnatomicRecon-POCUS-AI/ONSD/Data_ONSD/Annotations/CLEANED/Resized/"

p_prefix = [
    ' 239',
    ' 36',
    ' 40',
    ' 50',
    ' 64',
    ' 66',
    ' 87',
    ' 106',
    ' 117',
    ' 139',
    ' 158',
    ' 165',
    ' 107',
    ' 130',
    ' 146',
]
n_prefix = [
    ' 23',
    ' 108',
    ' 119',
    ' 129',
    ' 163',
    ' 191',
    ' 228',
    ' 250',
    ' 205',
    ' 209',
    ' 213',
    ' 215',
]

myNetwork = ARUNet_Nerve_Network()

# %%
setup_vfold_files(myNetwork,
                img_dir=img_folder,
                anno_dir=annotations_folder,
                p_prefix=p_prefix,
                n_prefix=n_prefix)
# Out:
# Total size of images in the dataset:
# 4.550912156701088 gibibyte
#
#
# Total size of labels in the dataset:
# 0.006907990202307701 gibibyte
#
#
# Num images / labels = 33 33
#
#
# 0 [[' 239'], [' 23']]
# 1 [[' 36'], [' 108']]
# 2 [[' 40'], [' 119']]
# 3 [[' 50'], [' 129']]
# 4 [[' 64'], [' 163']]
# 5 [[' 66'], [' 191']]
# 6 [[' 87'], [' 228']]
# 7 [[' 106'], [' 250']]
# 8 [[' 117'], [' 205']]
# 9 [[' 139'], [' 209']]
# 10 [[' 158'], [' 213']]
# 11 [[' 165'], [' 215']]
# 12 [[' 107']]
# 13 [[' 130']]
# 14 [[' 146']]
#
#
# 28  |  3  |  1  |  32
# 25  |  3  |  4  |  32
# 25  |  5  |  2  |  32
# 24  |  6  |  2  |  32
# 26  |  4  |  2  |  32
# 26  |  4  |  2  |  32
# 26  |  4  |  2  |  32
# 26  |  4  |  2  |  32
# 24  |  4  |  4  |  32
# 24  |  6  |  2  |  32
# 24  |  6  |  2  |  32
# 26  |  4  |  2  |  32
# 26  |  4  |  2  |  32
# 27  |  4  |  1  |  32
# 27  |  3  |  2  |  32

# %%
runs = [0,1,2]
for i in range(myNetwork.num_folds):
    setup_testing_vfold(myNetwork,
                        vfold_num=i)
    test_outputs_list = []
    test_images_list = []
    test_labels_list = []
    for r in runs:
        test_outputs, test_images, test_labels = test_vfold(myNetwork, model_type="best", run_id=r, device_num=0)
        test_outputs_list.append(test_outputs)
        test_images_list.append(test_images)
        test_labels_list.append(test_labels)
    view_testing_results_vfold(myNetwork,
                            test_outputs=test_outputs_list,
                            test_images=test_images_list,
                            test_labels=test_labels_list,
                            model_type="best",
                            run_id=runs, 
                            device_num=3)
# Out:
# Loading dataset: 100%|██████████| 1/1 [00:02<00:00,  2.60s/it]
# VFOLD = 0 of 14
# Image: 2. 146.1 Right_Lat_Video1_cropM.nii.gz
# Loading dataset: 100%|██████████| 4/4 [00:05<00:00,  1.43s/it]
# VFOLD = 1 of 14
# Image: 2. 239.1 Right_Lat_Video 1_cropM.nii.gz
# Image: 4. 23.1 Right_Long_Video 1_cropM.nii.gz
# Image: 7. 23.1 Left_Lat_Video 1_cropM.nii.gz
# Image: 8. 23.1 Left_Lat_Video 2_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# VFOLD = 2 of 14
# Image: 4. 36.1 Right Long_Video 1_cropM.nii.gz
# Image: 7. 108.1 Left_Lat_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:04<00:00,  2.17s/it]
# VFOLD = 3 of 14
# Image: 2. 119.1 Right_Lat_Video 1_cropM.nii.gz
# Image: 8. 40.1 Left Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# VFOLD = 4 of 14
# Image: 2. 50.3 Right_Lat_Video 1_cropM.nii.gz
# Image: 6. 129.1 Left_Lat_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.90s/it]
# VFOLD = 5 of 14
# Image: 2. 163.2 Right_Lat_Video 1_cropM.nii.gz
# Image: 2. 64.1 Right Lat_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.77s/it]
# VFOLD = 6 of 14
# Image: 4. 191.1 Right Long_Video 1_cropM.nii.gz
# Image: 4. 66.1 Right_Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.51s/it]
# VFOLD = 7 of 14
# Image: 2. 228.1 Right Lat_Video 1_cropM.nii.gz
# Image: 4. 87.2 Right Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 4/4 [00:04<00:00,  1.24s/it]
# VFOLD = 8 of 14
# Image: 10. 250.1 Left Lat_Video 1_cropM.nii.gz
# Image: 11. 106.1 Left Long Video 1_cropM.nii.gz
# Image: 15. 250.1 Left Long_Video 1_cropM.nii.gz
# Image: 3. 250.1 Right Lat_Video 2_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# VFOLD = 9 of 14
# Image: 6. 117.1 Left Lat_Video 1_cropM.nii.gz
# Image: 8. 205.1 Left Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# VFOLD = 10 of 14
# Image: 4. 139.1 Right Long_Video 1_cropM.nii.gz
# Image: 9. 209.1 Left_Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# VFOLD = 11 of 14
# Image: 2. 158.1 Right_Lat_Video 1_cropM.nii.gz
# Image: 9. 213.1 Left Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.59s/it]
# VFOLD = 12 of 14
# Image: 2. 165.4 Right_Lat_Video 1_cropM.nii.gz
# Image: 6. 215.2 Left_Lat_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 1/1 [00:02<00:00,  2.47s/it]
# VFOLD = 13 of 14
# Image: 8. 107.1 Left Long_Video 1_cropM.nii.gz
# Loading dataset: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# VFOLD = 14 of 14
# Image: 6. 130.1 Left_Lat_Video 1_cropM.nii.gz
# Image: 7. 130.1 Left_Lat_Video 2_cropM.nii.gz

# %%
import ipyparams
currentNotebook = "ARUNet-ONSD-Nerve-VFold-Test.ipynb"
exp = "EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s"

from datetime import datetime
now = datetime.now()
print(str(currentNotebook))
experimentName = exp+now.strftime("-%Y.%m.%d_%H.%M")
print(experimentName)
cmd = "jupyter nbconvert "+currentNotebook+" --output "+experimentName+" --to pdf"
import subprocess
subprocess.call(cmd, shell=True)
# Out:
# ARUNet-ONSD-Nerve-VFold-Test.ipynb
# EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19
# [NbConvertApp] Converting notebook ARUNet-ONSD-Nerve-VFold-Test.ipynb to pdf
# [NbConvertApp] Support files will be in EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files/
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Making directory ./EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19_files
# [NbConvertApp] Writing 41454 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 1763248 bytes to EnsembleClassPriorsTest-ONSD-Mean_StdOverTime_RawFrame_Gradient-LabelTrue-320x480-3s-2022.08.16_17.19.pdf
# 0
