# %%
from ARGUS_ptx_roi_train import ARGUS_ptx_roi_train

# %%
nnet = ARGUS_ptx_roi_train("../ARGUS/ARGUS_ptx_roi.cfg", "vfold", 0)
nnet.setup_vfold_files()
# Out:
# n : num images = 182
# s : num images = 192
# Total num images = 374
# Num images / labels = 374 374
# **** VFold = 0 : 263 74 37
# **** VFold = 1 : 262 74 38
# **** VFold = 2 : 261 75 38
# **** VFold = 3 : 260 76 38
# **** VFold = 4 : 260 76 38
# **** VFold = 5 : 261 76 37
# **** VFold = 6 : 262 75 37
# **** VFold = 7 : 263 74 37
# **** VFold = 8 : 263 74 37
# **** VFold = 9 : 263 74 37

# %%
nnet.view_metric_curves(vfold_num=0,run_id=0)

# %%
nnet.setup_testing_vfold(vfold_num=0)
test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0], model_vfold=0)
# Out:
# VFOLD = 0 of 9
#    Using model from vfold 0
#    Accuracy = 1.0
#    Confidence = 13.292891502380371
# Image: n221ns_image_584357289931_clean_17_ideal_arr.mha
#    Ideal output = 0
#    Run output (0) = [ 4.3638983 -4.6460285]
#    Ensemble output = [1. 0.]
#    Final output = 0
#
# Image: s206s_iimage_1511338287338_clean_37_pred_arr.mha
#    Ideal output = 1
#    Run output (0) = [-6.3251033  6.7200427]
#    Ensemble output = [0. 1.]
#    Final output = 1
#
# Image: s224s_iimage_3308406916756_clean_37_pred_arr.mha
#    Ideal output = 1
#    Run output (0) = [-5.561489  5.868505]
#    Ensemble output = [0. 1.]
#    Final output = 1
#
# Image: n221ns_image_584357289931_clean_37_ideal_arr.mha
#    Ideal output = 0
#    Run output (0) = [ 4.739433  -5.0348573]
#    Ensemble output = [1. 0.]
#    Final output = 0
#
# Image: s236s_iimage_1139765223418_CLEAN_17_ideal_arr.mha
#    Ideal output = 1
#    Run output (0) = [-5.931387  6.478557]
#    Ensemble output = [0. 1.]
# ...

# %%
test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0], model_vfold=0, summary_only=True)
# Out:
# VFOLD = 0 of 9
#    Using model from vfold 0
#    Accuracy = 1.0
#    Confidence = 13.292891502380371
#    Accuracy = 1.0
#    Confidence = 13.292891502380371
