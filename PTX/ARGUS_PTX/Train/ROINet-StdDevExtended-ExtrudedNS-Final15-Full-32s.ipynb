# %%
import warnings 
warnings.filterwarnings("ignore")

from monai.utils import first, set_determinism
from monai.transforms import (
    AddChanneld,
    AsChannelFirstd,
    AsDiscrete,
    AsDiscreted,
    Compose,
    EnsureChannelFirstd,
    EnsureTyped,
    EnsureType,
    Invertd,
    LabelFilterd,
    LoadImaged,
    RandFlipd,
    RandSpatialCropd,
    RandZoomd,
    Resized,
    ScaleIntensityRanged,
    SpatialCrop,
    SpatialCropd,
    ToTensord,
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
from glob import glob

import numpy as np

import itk

import sys

import site
site.addsitedir('../')
from ARGUSUtils_Transforms import *

# %%
device_num = 1

img1_dir = "../../Data/Final15/BAMC-PTX*Sliding-Annotations-Linear/"
    
all_images = sorted(glob(os.path.join(img1_dir, '*_?????.nii.gz')))
all_labels = sorted(glob(os.path.join(img1_dir, '*.extruded-overlay-NS.nii.gz')))

num_classes = 3

net_dims = 2
net_in_channels = 4

num_workers_tr = 1
batch_size_tr = 16
num_workers_vl = 1
batch_size_vl = 4

num_slices = 32
size_x = 160
size_y = 320

model_filename_base = "./results/BAMC_PTX_ROINet-StdDevExtended-ExtrudedNS-Final15-Full-32s/"

num_images = len(all_images)
print("Num images / labels =", num_images, len(all_labels))

ns_prefix = ['025ns','026ns','027ns','035ns','048ns','055ns','117ns',
             '135ns','193ns','210ns','215ns','218ns_image_60','218ns_image_63','219ns','247ns']
s_prefix = ['004s','019s','030s','034s','037s','043s','065s','081s',
            '206s','208s','211s','212s','224s','228s','236s','237s']
# Out:
# Num images / labels = 47 47

# %%
train_files =  []
train_files.append([
    {"image": img, "label": seg}
    for img, seg in zip(
        [im for im in all_images if any(pref in im for pref in ns_prefix)],
        [se for se in all_labels if any(pref in se for pref in ns_prefix)])
    ])
train_files.append([
    {"image": img, "label": seg}
    for img, seg in zip(
        [im for im in all_images if any(pref in im for pref in s_prefix)],
        [se for se in all_labels if any(pref in se for pref in s_prefix)])
    ])
train_files.append([
    {"image": img, "label": seg}
    for img, seg in zip(
        [im for im in all_images if any(pref in im for pref in ns_prefix)],
        [se for se in all_labels if any(pref in se for pref in ns_prefix)])
    ])
train_files = list(np.concatenate(train_files).flat)
print(len(train_files))
# Out:
# 62

# %%
imgnum = 1 #10 for ns, 0 for s

print(train_files[imgnum]["image"])
print(train_files[imgnum]["label"])

img = itk.imread(train_files[imgnum]["image"])
arrimg = itk.GetArrayFromImage(img)
img = itk.imread(train_files[imgnum]["label"])
arrlbl = itk.GetArrayFromImage(img)

plt.subplots()
plt.imshow(arrimg[0,:,:])
plt.subplots()
plt.imshow(arrlbl[0,:,:])
# Out:
# ../../Data/Final15/BAMC-PTXNoSliding-Annotations-Linear/026ns_image_1083297968960_clean.nii.gz
# ../../Data/Final15/BAMC-PTXNoSliding-Annotations-Linear/026ns_image_1083297968960_clean.extruded-overlay-NS.nii.gz

# %%
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AsChannelFirstd(keys='image'),
        AsChannelFirstd(keys='label'),
        ScaleIntensityRanged(
            a_min=0, a_max=255,
            b_min=0.0, b_max=1.0,
            keys=["image"]),
        SpatialCropd(
            roi_start=[80,0,1],
            roi_end=[240,320,61],
            keys=["image", "label"]),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=[num_slices,1],
            axis=0,
            reduce_to_statistics=[True,False],
            extended=True,
            keys=['image', 'label']),
        RandFlipd(prob=0.5, 
            spatial_axis=0,
            keys=['image', 'label']),
        RandZoomd(prob=0.5, 
            min_zoom=1.0,
            max_zoom=1.2,
            keep_size=True,
            mode=['bilinear', 'nearest'],
            keys=['image', 'label']),
        ToTensord(keys=["image", "label"]),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"]),
        AsChannelFirstd(keys='image'),
        AsChannelFirstd(keys='label'),
        ScaleIntensityRanged(
            a_min=0, a_max=255,
            b_min=0.0, b_max=1.0,
            keys=["image"]),
        SpatialCropd(
            roi_start=[80,0,1],
            roi_end=[240,320,61],
            keys=["image", "label"]),
        ARGUS_RandSpatialCropSlicesd(
            num_slices=[num_slices,1],
            axis=0,
            reduce_to_statistics=[True,False],
            extended=True,
            keys=['image', 'label']),
        ToTensord(keys=["image", "label"]),
    ]
)

# %%
train_ds = CacheDataset(data=train_files, transform=train_transforms,cache_rate=1.0, num_workers=num_workers_tr)
train_loader = DataLoader(train_ds, batch_size=batch_size_tr, shuffle=True, num_workers=num_workers_tr)
# Out:
# Loading dataset: 100%|██████████████████████████| 62/62 [00:08<00:00,  7.58it/s]

# %%
imgnum = 2
check_data = first(train_loader)
image, label = (check_data["image"][imgnum], check_data["label"][imgnum])
print(check_data["image"].shape)
print(image.shape)
print(f"image shape: {image.shape}, label shape: {label.shape}")
plt.figure("check", (12, 6))
plt.subplot(1, 5, 1)
plt.title("image")
plt.imshow(image[0, :, :], cmap="gray")
plt.subplot(1, 5, 2)
plt.title("image")
plt.imshow(image[1, :, :], cmap="gray")
plt.subplot(1, 5, 3)
plt.title("image")
plt.imshow(image[2, :, :], cmap="gray")
plt.subplot(1, 5, 4)
plt.title("image")
plt.imshow(image[3, :, :], cmap="gray")
plt.subplot(1, 5, 5)
plt.title("label")
plt.imshow(label[0, :, :])
plt.show()
print(label.min(), label.max())
# Out:
# torch.Size([16, 4, 160, 320])
# torch.Size([4, 160, 320])
# image shape: torch.Size([4, 160, 320]), label shape: torch.Size([1, 160, 320])
# tensor(0.) tensor(1.)

# %%
device = torch.device("cuda:"+str(device_num))

max_epochs = 500
net_channels=(32, 64, 128)
net_strides=(2, 2)

# %%
def net_train(train_loader):
    model = UNet(
        dimensions=net_dims,
        in_channels=net_in_channels,
        out_channels=num_classes,
        channels=net_channels,
        strides=net_strides,
        num_res_units=2,
        norm=Norm.BATCH,
    ).to(device)
    loss_function = DiceLoss(to_onehot_y=True, softmax=True)
    optimizer = torch.optim.Adam(model.parameters(), 1e-4)
    dice_metric = DiceMetric(include_background=False, reduction="mean")

    val_interval = 2
    best_metric = -1
    best_metric_epoch = -1
    epoch_loss_values = []
    metric_values = []

    post_pred = Compose([EnsureType(), AsDiscrete(argmax=True, to_onehot=True, num_classes=num_classes)])
    post_label = Compose([EnsureType(), AsDiscrete(to_onehot=True, num_classes=num_classes)])

    for epoch in range(max_epochs):
        print("-" * 10)
        print(f"Epoch {epoch + 1}/{max_epochs}")
        model.train()
        epoch_loss = 0
        step = 0
        for batch_data in train_loader:
            step += 1
            inputs, labels = (
                batch_data["image"].to(device),
                batch_data["label"].to(device),
            )
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()
            epoch_loss += loss.item()
            print(f"{step}/{len(train_ds) // train_loader.batch_size}, "
                  f"train_loss: {loss.item():.4f}")
        epoch_loss /= step
        epoch_loss_values.append(epoch_loss)
        print(f"Epoch {epoch + 1} average loss: {epoch_loss:.4f}")

        if (epoch + 1) % val_interval == 0:
            model.eval()
            with torch.no_grad():
                for val_data in train_loader:
                    val_inputs, val_labels = (
                        val_data["image"].to(device),
                        val_data["label"].to(device),
                    )
                    roi_size = (size_x, size_y)
                    sw_batch_size = batch_size_vl
                    val_outputs = sliding_window_inference(
                        val_inputs, roi_size, sw_batch_size, model)
                    val_outputs = [post_pred(i) for i in decollate_batch(val_outputs)]
                    val_labels = [post_label(i) for i in decollate_batch(val_labels)]
                    # compute metric for current iteration
                    dice_metric(y_pred=val_outputs, y=val_labels)

                # aggregate the final mean dice result
                metric = dice_metric.aggregate().item()
                # reset the status for next validation round
                dice_metric.reset()

                metric_values.append(metric)
                if epoch > 100:
                    metric = (metric_values[-1]+metric_values[-2]+metric_values[-3])/3
                    if metric > best_metric:
                        best_metric = metric
                        best_metric_epoch = epoch + 1
                        torch.save(model.state_dict(), model_filename_base+'best_model.pth')
                        print("saved new best metric model")
                if epoch == max_epochs // 3:
                    torch.save(model.state_dict(), model_filename_base+'Epoch'+str(epoch)+'_model.pth')
                if epoch == (2*max_epochs) // 3:
                    torch.save(model.state_dict(), model_filename_base+'Epoch'+str(epoch)+'_model.pth')
                print(
                    f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                    f"\nbest mean dice: {best_metric:.4f} "
                    f"at epoch: {best_metric_epoch}"
                )
                torch.save(model.state_dict(), model_filename_base+'last_model.pth')

    np.save(model_filename_base+"loss.npy", epoch_loss_values)
    np.save(model_filename_base+"val_dice.npy", metric_values)

# %%
net_train(train_loader)
# Out:
# ----------
# Epoch 1/500
# 1/3, train_loss: 0.7413
# 2/3, train_loss: 0.7334
# 3/3, train_loss: 0.7260
# 4/3, train_loss: 0.7208
# Epoch 1 average loss: 0.7304
# ----------
# Epoch 2/500
# 1/3, train_loss: 0.7153
# 2/3, train_loss: 0.7067
# 3/3, train_loss: 0.7078
# 4/3, train_loss: 0.7104
# Epoch 2 average loss: 0.7100
# current epoch: 2 current mean dice: 0.3192
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 3/500
# 1/3, train_loss: 0.6958
# 2/3, train_loss: 0.7078
# 3/3, train_loss: 0.6924
# 4/3, train_loss: 0.7032
# Epoch 3 average loss: 0.6998
# ----------
# Epoch 4/500
# 1/3, train_loss: 0.6911
# 2/3, train_loss: 0.6948
# 3/3, train_loss: 0.6907
# 4/3, train_loss: 0.6783
# Epoch 4 average loss: 0.6887
# current epoch: 4 current mean dice: 0.2490
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 5/500
# 1/3, train_loss: 0.6920
# 2/3, train_loss: 0.6704
# 3/3, train_loss: 0.6749
# 4/3, train_loss: 0.6841
# Epoch 5 average loss: 0.6804
# ----------
# Epoch 6/500
# 1/3, train_loss: 0.6788
# 2/3, train_loss: 0.6784
# 3/3, train_loss: 0.6651
# 4/3, train_loss: 0.6647
# Epoch 6 average loss: 0.6718
# current epoch: 6 current mean dice: 0.2857
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 7/500
# 1/3, train_loss: 0.6755
# 2/3, train_loss: 0.6675
# 3/3, train_loss: 0.6580
# 4/3, train_loss: 0.6545
# Epoch 7 average loss: 0.6639
# ----------
# Epoch 8/500
# 1/3, train_loss: 0.6587
# 2/3, train_loss: 0.6568
# 3/3, train_loss: 0.6557
# 4/3, train_loss: 0.6566
# Epoch 8 average loss: 0.6569
# current epoch: 8 current mean dice: 0.3431
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 9/500
# 1/3, train_loss: 0.6628
# 2/3, train_loss: 0.6704
# 3/3, train_loss: 0.6417
# 4/3, train_loss: 0.6444
# Epoch 9 average loss: 0.6548
# ----------
# Epoch 10/500
# 1/3, train_loss: 0.6646
# 2/3, train_loss: 0.6477
# 3/3, train_loss: 0.6482
# 4/3, train_loss: 0.6304
# Epoch 10 average loss: 0.6477
# current epoch: 10 current mean dice: 0.3694
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 11/500
# 1/3, train_loss: 0.6569
# 2/3, train_loss: 0.6415
# 3/3, train_loss: 0.6268
# 4/3, train_loss: 0.6338
# Epoch 11 average loss: 0.6397
# ----------
# Epoch 12/500
# 1/3, train_loss: 0.6265
# 2/3, train_loss: 0.6212
# 3/3, train_loss: 0.6503
# 4/3, train_loss: 0.6469
# Epoch 12 average loss: 0.6362
# current epoch: 12 current mean dice: 0.3082
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 13/500
# 1/3, train_loss: 0.6164
# 2/3, train_loss: 0.6627
# 3/3, train_loss: 0.6270
# 4/3, train_loss: 0.6222
# Epoch 13 average loss: 0.6321
# ----------
# Epoch 14/500
# 1/3, train_loss: 0.6302
# 2/3, train_loss: 0.6212
# 3/3, train_loss: 0.6468
# 4/3, train_loss: 0.6186
# Epoch 14 average loss: 0.6292
# current epoch: 14 current mean dice: 0.3346
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 15/500
# 1/3, train_loss: 0.6293
# 2/3, train_loss: 0.6287
# 3/3, train_loss: 0.6201
# 4/3, train_loss: 0.6217
# Epoch 15 average loss: 0.6250
# ----------
# Epoch 16/500
# 1/3, train_loss: 0.6318
# 2/3, train_loss: 0.6207
# 3/3, train_loss: 0.6298
# 4/3, train_loss: 0.6193
# Epoch 16 average loss: 0.6254
# current epoch: 16 current mean dice: 0.3710
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 17/500
# 1/3, train_loss: 0.6241
# 2/3, train_loss: 0.6073
# 3/3, train_loss: 0.6255
# 4/3, train_loss: 0.6485
# Epoch 17 average loss: 0.6263
# ----------
# Epoch 18/500
# 1/3, train_loss: 0.6181
# 2/3, train_loss: 0.6230
# 3/3, train_loss: 0.6253
# 4/3, train_loss: 0.6141
# Epoch 18 average loss: 0.6201
# current epoch: 18 current mean dice: 0.4729
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 19/500
# 1/3, train_loss: 0.6244
# 2/3, train_loss: 0.6124
# 3/3, train_loss: 0.6152
# 4/3, train_loss: 0.6032
# Epoch 19 average loss: 0.6138
# ----------
# Epoch 20/500
# 1/3, train_loss: 0.5824
# 2/3, train_loss: 0.6409
# 3/3, train_loss: 0.6403
# 4/3, train_loss: 0.5929
# Epoch 20 average loss: 0.6141
# current epoch: 20 current mean dice: 0.5104
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 21/500
# 1/3, train_loss: 0.6084
# 2/3, train_loss: 0.6030
# 3/3, train_loss: 0.6184
# 4/3, train_loss: 0.6196
# Epoch 21 average loss: 0.6124
# ----------
# Epoch 22/500
# 1/3, train_loss: 0.6315
# 2/3, train_loss: 0.6246
# 3/3, train_loss: 0.5861
# 4/3, train_loss: 0.6039
# Epoch 22 average loss: 0.6115
# current epoch: 22 current mean dice: 0.5566
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 23/500
# 1/3, train_loss: 0.5928
# 2/3, train_loss: 0.5930
# 3/3, train_loss: 0.6170
# 4/3, train_loss: 0.6392
# Epoch 23 average loss: 0.6105
# ----------
# Epoch 24/500
# 1/3, train_loss: 0.6198
# 2/3, train_loss: 0.5957
# 3/3, train_loss: 0.5876
# 4/3, train_loss: 0.6510
# Epoch 24 average loss: 0.6135
# current epoch: 24 current mean dice: 0.6097
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 25/500
# 1/3, train_loss: 0.6264
# 2/3, train_loss: 0.5889
# 3/3, train_loss: 0.5971
# 4/3, train_loss: 0.6018
# Epoch 25 average loss: 0.6036
# ----------
# Epoch 26/500
# 1/3, train_loss: 0.6245
# 2/3, train_loss: 0.5754
# 3/3, train_loss: 0.6043
# 4/3, train_loss: 0.5915
# Epoch 26 average loss: 0.5989
# current epoch: 26 current mean dice: 0.6545
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 27/500
# 1/3, train_loss: 0.6055
# 2/3, train_loss: 0.6044
# 3/3, train_loss: 0.6021
# 4/3, train_loss: 0.5870
# Epoch 27 average loss: 0.5997
# ----------
# Epoch 28/500
# 1/3, train_loss: 0.6149
# 2/3, train_loss: 0.5866
# 3/3, train_loss: 0.5916
# 4/3, train_loss: 0.5979
# Epoch 28 average loss: 0.5977
# current epoch: 28 current mean dice: 0.6286
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 29/500
# 1/3, train_loss: 0.5767
# 2/3, train_loss: 0.6181
# 3/3, train_loss: 0.5959
# 4/3, train_loss: 0.5808
# Epoch 29 average loss: 0.5929
# ----------
# Epoch 30/500
# 1/3, train_loss: 0.5787
# 2/3, train_loss: 0.6066
# 3/3, train_loss: 0.5868
# 4/3, train_loss: 0.6039
# Epoch 30 average loss: 0.5940
# current epoch: 30 current mean dice: 0.6497
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 31/500
# 1/3, train_loss: 0.5905
# 2/3, train_loss: 0.6338
# 3/3, train_loss: 0.5658
# 4/3, train_loss: 0.5844
# Epoch 31 average loss: 0.5936
# ----------
# Epoch 32/500
# 1/3, train_loss: 0.5810
# 2/3, train_loss: 0.5776
# 3/3, train_loss: 0.5878
# 4/3, train_loss: 0.6003
# Epoch 32 average loss: 0.5867
# current epoch: 32 current mean dice: 0.6347
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 33/500
# 1/3, train_loss: 0.5889
# 2/3, train_loss: 0.5728
# 3/3, train_loss: 0.5935
# 4/3, train_loss: 0.5828
# Epoch 33 average loss: 0.5845
# ----------
# Epoch 34/500
# 1/3, train_loss: 0.6134
# 2/3, train_loss: 0.5703
# 3/3, train_loss: 0.6073
# 4/3, train_loss: 0.5744
# Epoch 34 average loss: 0.5913
# current epoch: 34 current mean dice: 0.6299
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 35/500
# 1/3, train_loss: 0.5830
# 2/3, train_loss: 0.5857
# 3/3, train_loss: 0.5800
# 4/3, train_loss: 0.6172
# Epoch 35 average loss: 0.5915
# ----------
# Epoch 36/500
# 1/3, train_loss: 0.5719
# 2/3, train_loss: 0.5856
# 3/3, train_loss: 0.6031
# 4/3, train_loss: 0.6106
# Epoch 36 average loss: 0.5928
# current epoch: 36 current mean dice: 0.6377
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 37/500
# 1/3, train_loss: 0.5776
# 2/3, train_loss: 0.5631
# 3/3, train_loss: 0.5948
# 4/3, train_loss: 0.5851
# Epoch 37 average loss: 0.5802
# ----------
# Epoch 38/500
# 1/3, train_loss: 0.5894
# 2/3, train_loss: 0.5698
# 3/3, train_loss: 0.5800
# 4/3, train_loss: 0.5958
# Epoch 38 average loss: 0.5838
# current epoch: 38 current mean dice: 0.6565
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 39/500
# 1/3, train_loss: 0.5611
# 2/3, train_loss: 0.5767
# 3/3, train_loss: 0.5804
# 4/3, train_loss: 0.5981
# Epoch 39 average loss: 0.5790
# ----------
# Epoch 40/500
# 1/3, train_loss: 0.5670
# 2/3, train_loss: 0.5895
# 3/3, train_loss: 0.5672
# 4/3, train_loss: 0.5969
# Epoch 40 average loss: 0.5802
# current epoch: 40 current mean dice: 0.6787
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 41/500
# 1/3, train_loss: 0.5950
# 2/3, train_loss: 0.5650
# 3/3, train_loss: 0.5554
# 4/3, train_loss: 0.5977
# Epoch 41 average loss: 0.5783
# ----------
# Epoch 42/500
# 1/3, train_loss: 0.5645
# 2/3, train_loss: 0.5678
# 3/3, train_loss: 0.5782
# 4/3, train_loss: 0.5652
# Epoch 42 average loss: 0.5689
# current epoch: 42 current mean dice: 0.6920
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 43/500
# 1/3, train_loss: 0.5769
# 2/3, train_loss: 0.5884
# 3/3, train_loss: 0.5832
# 4/3, train_loss: 0.5807
# Epoch 43 average loss: 0.5823
# ----------
# Epoch 44/500
# 1/3, train_loss: 0.5617
# 2/3, train_loss: 0.5780
# 3/3, train_loss: 0.5627
# 4/3, train_loss: 0.6139
# Epoch 44 average loss: 0.5791
# current epoch: 44 current mean dice: 0.6454
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 45/500
# 1/3, train_loss: 0.5608
# 2/3, train_loss: 0.5887
# 3/3, train_loss: 0.5773
# 4/3, train_loss: 0.5557
# Epoch 45 average loss: 0.5706
# ----------
# Epoch 46/500
# 1/3, train_loss: 0.5704
# 2/3, train_loss: 0.5802
# 3/3, train_loss: 0.5829
# 4/3, train_loss: 0.5796
# Epoch 46 average loss: 0.5783
# current epoch: 46 current mean dice: 0.6445
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 47/500
# 1/3, train_loss: 0.5521
# 2/3, train_loss: 0.5917
# 3/3, train_loss: 0.5749
# 4/3, train_loss: 0.5911
# Epoch 47 average loss: 0.5774
# ----------
# Epoch 48/500
# 1/3, train_loss: 0.5666
# 2/3, train_loss: 0.5631
# 3/3, train_loss: 0.5830
# 4/3, train_loss: 0.5690
# Epoch 48 average loss: 0.5704
# current epoch: 48 current mean dice: 0.6642
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 49/500
# 1/3, train_loss: 0.5800
# 2/3, train_loss: 0.5661
# 3/3, train_loss: 0.5770
# 4/3, train_loss: 0.5635
# Epoch 49 average loss: 0.5717
# ----------
# Epoch 50/500
# 1/3, train_loss: 0.5488
# 2/3, train_loss: 0.5948
# 3/3, train_loss: 0.5706
# 4/3, train_loss: 0.5546
# Epoch 50 average loss: 0.5672
# current epoch: 50 current mean dice: 0.6779
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 51/500
# 1/3, train_loss: 0.5571
# 2/3, train_loss: 0.5759
# 3/3, train_loss: 0.5662
# 4/3, train_loss: 0.5601
# Epoch 51 average loss: 0.5648
# ----------
# Epoch 52/500
# 1/3, train_loss: 0.5602
# 2/3, train_loss: 0.5770
# 3/3, train_loss: 0.5783
# 4/3, train_loss: 0.5584
# Epoch 52 average loss: 0.5685
# current epoch: 52 current mean dice: 0.6715
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 53/500
# 1/3, train_loss: 0.5886
# 2/3, train_loss: 0.5765
# 3/3, train_loss: 0.5580
# 4/3, train_loss: 0.5495
# Epoch 53 average loss: 0.5681
# ----------
# Epoch 54/500
# 1/3, train_loss: 0.5750
# 2/3, train_loss: 0.5548
# 3/3, train_loss: 0.5648
# 4/3, train_loss: 0.5747
# Epoch 54 average loss: 0.5673
# current epoch: 54 current mean dice: 0.7148
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 55/500
# 1/3, train_loss: 0.5479
# 2/3, train_loss: 0.5568
# 3/3, train_loss: 0.5925
# 4/3, train_loss: 0.5533
# Epoch 55 average loss: 0.5626
# ----------
# Epoch 56/500
# 1/3, train_loss: 0.5776
# 2/3, train_loss: 0.5709
# 3/3, train_loss: 0.5562
# 4/3, train_loss: 0.5590
# Epoch 56 average loss: 0.5659
# current epoch: 56 current mean dice: 0.6852
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 57/500
# 1/3, train_loss: 0.5841
# 2/3, train_loss: 0.5532
# 3/3, train_loss: 0.5553
# 4/3, train_loss: 0.5830
# Epoch 57 average loss: 0.5689
# ----------
# Epoch 58/500
# 1/3, train_loss: 0.5446
# 2/3, train_loss: 0.5579
# 3/3, train_loss: 0.5658
# 4/3, train_loss: 0.5623
# Epoch 58 average loss: 0.5577
# current epoch: 58 current mean dice: 0.6902
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 59/500
# 1/3, train_loss: 0.5641
# 2/3, train_loss: 0.5510
# 3/3, train_loss: 0.5763
# 4/3, train_loss: 0.5578
# Epoch 59 average loss: 0.5623
# ----------
# Epoch 60/500
# 1/3, train_loss: 0.5915
# 2/3, train_loss: 0.5576
# 3/3, train_loss: 0.5487
# 4/3, train_loss: 0.5536
# Epoch 60 average loss: 0.5628
# current epoch: 60 current mean dice: 0.7017
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 61/500
# 1/3, train_loss: 0.5403
# 2/3, train_loss: 0.5542
# 3/3, train_loss: 0.5542
# 4/3, train_loss: 0.5742
# Epoch 61 average loss: 0.5557
# ----------
# Epoch 62/500
# 1/3, train_loss: 0.5430
# 2/3, train_loss: 0.5536
# 3/3, train_loss: 0.5842
# 4/3, train_loss: 0.5360
# Epoch 62 average loss: 0.5542
# current epoch: 62 current mean dice: 0.6995
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 63/500
# 1/3, train_loss: 0.5582
# 2/3, train_loss: 0.5638
# 3/3, train_loss: 0.5628
# 4/3, train_loss: 0.5458
# Epoch 63 average loss: 0.5576
# ----------
# Epoch 64/500
# 1/3, train_loss: 0.5550
# 2/3, train_loss: 0.5408
# 3/3, train_loss: 0.5458
# 4/3, train_loss: 0.5537
# Epoch 64 average loss: 0.5488
# current epoch: 64 current mean dice: 0.6942
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 65/500
# 1/3, train_loss: 0.5440
# 2/3, train_loss: 0.5650
# 3/3, train_loss: 0.5265
# 4/3, train_loss: 0.5648
# Epoch 65 average loss: 0.5501
# ----------
# Epoch 66/500
# 1/3, train_loss: 0.5512
# 2/3, train_loss: 0.5470
# 3/3, train_loss: 0.5599
# 4/3, train_loss: 0.5631
# Epoch 66 average loss: 0.5553
# current epoch: 66 current mean dice: 0.7061
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 67/500
# 1/3, train_loss: 0.5556
# 2/3, train_loss: 0.5447
# 3/3, train_loss: 0.5432
# 4/3, train_loss: 0.5605
# Epoch 67 average loss: 0.5510
# ----------
# Epoch 68/500
# 1/3, train_loss: 0.5608
# 2/3, train_loss: 0.5451
# 3/3, train_loss: 0.5474
# 4/3, train_loss: 0.5449
# Epoch 68 average loss: 0.5496
# current epoch: 68 current mean dice: 0.7192
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 69/500
# 1/3, train_loss: 0.5698
# 2/3, train_loss: 0.5630
# 3/3, train_loss: 0.5489
# 4/3, train_loss: 0.5643
# Epoch 69 average loss: 0.5615
# ----------
# Epoch 70/500
# 1/3, train_loss: 0.5264
# 2/3, train_loss: 0.5645
# 3/3, train_loss: 0.5626
# 4/3, train_loss: 0.5463
# Epoch 70 average loss: 0.5499
# current epoch: 70 current mean dice: 0.6758
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 71/500
# 1/3, train_loss: 0.5522
# 2/3, train_loss: 0.5443
# 3/3, train_loss: 0.5560
# 4/3, train_loss: 0.5386
# Epoch 71 average loss: 0.5478
# ----------
# Epoch 72/500
# 1/3, train_loss: 0.5507
# 2/3, train_loss: 0.5351
# 3/3, train_loss: 0.5400
# 4/3, train_loss: 0.5620
# Epoch 72 average loss: 0.5470
# current epoch: 72 current mean dice: 0.7185
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 73/500
# 1/3, train_loss: 0.5724
# 2/3, train_loss: 0.5548
# 3/3, train_loss: 0.5423
# 4/3, train_loss: 0.5498
# Epoch 73 average loss: 0.5548
# ----------
# Epoch 74/500
# 1/3, train_loss: 0.5578
# 2/3, train_loss: 0.5564
# 3/3, train_loss: 0.5340
# 4/3, train_loss: 0.5467
# Epoch 74 average loss: 0.5487
# current epoch: 74 current mean dice: 0.7226
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 75/500
# 1/3, train_loss: 0.5372
# 2/3, train_loss: 0.5393
# 3/3, train_loss: 0.5375
# 4/3, train_loss: 0.5611
# Epoch 75 average loss: 0.5438
# ----------
# Epoch 76/500
# 1/3, train_loss: 0.5515
# 2/3, train_loss: 0.5437
# 3/3, train_loss: 0.5709
# 4/3, train_loss: 0.5489
# Epoch 76 average loss: 0.5537
# current epoch: 76 current mean dice: 0.6645
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 77/500
# 1/3, train_loss: 0.5477
# 2/3, train_loss: 0.5395
# 3/3, train_loss: 0.5499
# 4/3, train_loss: 0.5366
# Epoch 77 average loss: 0.5434
# ----------
# Epoch 78/500
# 1/3, train_loss: 0.5474
# 2/3, train_loss: 0.5360
# 3/3, train_loss: 0.5613
# 4/3, train_loss: 0.5371
# Epoch 78 average loss: 0.5455
# current epoch: 78 current mean dice: 0.7237
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 79/500
# 1/3, train_loss: 0.5345
# 2/3, train_loss: 0.5624
# 3/3, train_loss: 0.5344
# 4/3, train_loss: 0.5779
# Epoch 79 average loss: 0.5523
# ----------
# Epoch 80/500
# 1/3, train_loss: 0.5411
# 2/3, train_loss: 0.5528
# 3/3, train_loss: 0.5695
# 4/3, train_loss: 0.5145
# Epoch 80 average loss: 0.5445
# current epoch: 80 current mean dice: 0.7138
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 81/500
# 1/3, train_loss: 0.5477
# 2/3, train_loss: 0.5586
# 3/3, train_loss: 0.5338
# 4/3, train_loss: 0.5411
# Epoch 81 average loss: 0.5453
# ----------
# Epoch 82/500
# 1/3, train_loss: 0.5525
# 2/3, train_loss: 0.5251
# 3/3, train_loss: 0.5475
# 4/3, train_loss: 0.5478
# Epoch 82 average loss: 0.5432
# current epoch: 82 current mean dice: 0.7050
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 83/500
# 1/3, train_loss: 0.5592
# 2/3, train_loss: 0.5278
# 3/3, train_loss: 0.5605
# 4/3, train_loss: 0.5249
# Epoch 83 average loss: 0.5431
# ----------
# Epoch 84/500
# 1/3, train_loss: 0.5301
# 2/3, train_loss: 0.5541
# 3/3, train_loss: 0.5327
# 4/3, train_loss: 0.5362
# Epoch 84 average loss: 0.5382
# current epoch: 84 current mean dice: 0.7242
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 85/500
# 1/3, train_loss: 0.5243
# 2/3, train_loss: 0.5378
# 3/3, train_loss: 0.5680
# 4/3, train_loss: 0.5423
# Epoch 85 average loss: 0.5431
# ----------
# Epoch 86/500
# 1/3, train_loss: 0.5563
# 2/3, train_loss: 0.5744
# 3/3, train_loss: 0.5316
# 4/3, train_loss: 0.5065
# Epoch 86 average loss: 0.5422
# current epoch: 86 current mean dice: 0.7450
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 87/500
# 1/3, train_loss: 0.5337
# 2/3, train_loss: 0.5522
# 3/3, train_loss: 0.5290
# 4/3, train_loss: 0.5428
# Epoch 87 average loss: 0.5394
# ----------
# Epoch 88/500
# 1/3, train_loss: 0.5200
# 2/3, train_loss: 0.5512
# 3/3, train_loss: 0.5356
# 4/3, train_loss: 0.5495
# Epoch 88 average loss: 0.5391
# current epoch: 88 current mean dice: 0.7102
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 89/500
# 1/3, train_loss: 0.5181
# 2/3, train_loss: 0.5356
# 3/3, train_loss: 0.5389
# 4/3, train_loss: 0.5470
# Epoch 89 average loss: 0.5349
# ----------
# Epoch 90/500
# 1/3, train_loss: 0.5500
# 2/3, train_loss: 0.5223
# 3/3, train_loss: 0.5320
# 4/3, train_loss: 0.5236
# Epoch 90 average loss: 0.5320
# current epoch: 90 current mean dice: 0.7005
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 91/500
# 1/3, train_loss: 0.5416
# 2/3, train_loss: 0.5297
# 3/3, train_loss: 0.5538
# 4/3, train_loss: 0.5198
# Epoch 91 average loss: 0.5362
# ----------
# Epoch 92/500
# 1/3, train_loss: 0.5532
# 2/3, train_loss: 0.5320
# 3/3, train_loss: 0.5125
# 4/3, train_loss: 0.5282
# Epoch 92 average loss: 0.5314
# current epoch: 92 current mean dice: 0.7212
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 93/500
# 1/3, train_loss: 0.5153
# 2/3, train_loss: 0.5187
# 3/3, train_loss: 0.5433
# 4/3, train_loss: 0.5211
# Epoch 93 average loss: 0.5246
# ----------
# Epoch 94/500
# 1/3, train_loss: 0.5524
# 2/3, train_loss: 0.5351
# 3/3, train_loss: 0.5148
# 4/3, train_loss: 0.5499
# Epoch 94 average loss: 0.5380
# current epoch: 94 current mean dice: 0.7443
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 95/500
# 1/3, train_loss: 0.5199
# 2/3, train_loss: 0.5294
# 3/3, train_loss: 0.5127
# 4/3, train_loss: 0.5368
# Epoch 95 average loss: 0.5247
# ----------
# Epoch 96/500
# 1/3, train_loss: 0.5183
# 2/3, train_loss: 0.5192
# 3/3, train_loss: 0.5375
# 4/3, train_loss: 0.5377
# Epoch 96 average loss: 0.5282
# current epoch: 96 current mean dice: 0.7186
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 97/500
# 1/3, train_loss: 0.5111
# 2/3, train_loss: 0.5212
# 3/3, train_loss: 0.5521
# 4/3, train_loss: 0.5128
# Epoch 97 average loss: 0.5243
# ----------
# Epoch 98/500
# 1/3, train_loss: 0.5287
# 2/3, train_loss: 0.5374
# 3/3, train_loss: 0.5561
# 4/3, train_loss: 0.5151
# Epoch 98 average loss: 0.5343
# current epoch: 98 current mean dice: 0.7357
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 99/500
# 1/3, train_loss: 0.5203
# 2/3, train_loss: 0.5254
# 3/3, train_loss: 0.5366
# 4/3, train_loss: 0.5357
# Epoch 99 average loss: 0.5295
# ----------
# Epoch 100/500
# 1/3, train_loss: 0.5187
# 2/3, train_loss: 0.5250
# 3/3, train_loss: 0.5431
# 4/3, train_loss: 0.5473
# Epoch 100 average loss: 0.5335
# current epoch: 100 current mean dice: 0.7212
# best mean dice: -1.0000 at epoch: -1
# ----------
# Epoch 101/500
# 1/3, train_loss: 0.5137
# 2/3, train_loss: 0.5285
# 3/3, train_loss: 0.5372
# 4/3, train_loss: 0.5352
# Epoch 101 average loss: 0.5287
# ----------
# Epoch 102/500
# 1/3, train_loss: 0.5312
# 2/3, train_loss: 0.5302
# 3/3, train_loss: 0.5278
# 4/3, train_loss: 0.5308
# Epoch 102 average loss: 0.5300
# saved new best metric model
# current epoch: 102 current mean dice: 0.7262
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 103/500
# 1/3, train_loss: 0.5282
# 2/3, train_loss: 0.5283
# 3/3, train_loss: 0.5318
# 4/3, train_loss: 0.5379
# Epoch 103 average loss: 0.5315
# ----------
# Epoch 104/500
# 1/3, train_loss: 0.5301
# 2/3, train_loss: 0.5252
# 3/3, train_loss: 0.5194
# 4/3, train_loss: 0.5156
# Epoch 104 average loss: 0.5226
# current epoch: 104 current mean dice: 0.7200
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 105/500
# 1/3, train_loss: 0.5219
# 2/3, train_loss: 0.5080
# 3/3, train_loss: 0.5309
# 4/3, train_loss: 0.5251
# Epoch 105 average loss: 0.5215
# ----------
# Epoch 106/500
# 1/3, train_loss: 0.5251
# 2/3, train_loss: 0.5447
# 3/3, train_loss: 0.5236
# 4/3, train_loss: 0.5309
# Epoch 106 average loss: 0.5311
# current epoch: 106 current mean dice: 0.7122
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 107/500
# 1/3, train_loss: 0.5269
# 2/3, train_loss: 0.5177
# 3/3, train_loss: 0.5356
# 4/3, train_loss: 0.5139
# Epoch 107 average loss: 0.5235
# ----------
# Epoch 108/500
# 1/3, train_loss: 0.5120
# 2/3, train_loss: 0.5362
# 3/3, train_loss: 0.5441
# 4/3, train_loss: 0.5221
# Epoch 108 average loss: 0.5286
# current epoch: 108 current mean dice: 0.7103
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 109/500
# 1/3, train_loss: 0.5308
# 2/3, train_loss: 0.5152
# 3/3, train_loss: 0.5330
# 4/3, train_loss: 0.5082
# Epoch 109 average loss: 0.5218
# ----------
# Epoch 110/500
# 1/3, train_loss: 0.5328
# 2/3, train_loss: 0.5054
# 3/3, train_loss: 0.5490
# 4/3, train_loss: 0.5101
# Epoch 110 average loss: 0.5243
# current epoch: 110 current mean dice: 0.7150
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 111/500
# 1/3, train_loss: 0.5505
# 2/3, train_loss: 0.5059
# 3/3, train_loss: 0.5153
# 4/3, train_loss: 0.5103
# Epoch 111 average loss: 0.5205
# ----------
# Epoch 112/500
# 1/3, train_loss: 0.5328
# 2/3, train_loss: 0.5183
# 3/3, train_loss: 0.5158
# 4/3, train_loss: 0.5165
# Epoch 112 average loss: 0.5209
# current epoch: 112 current mean dice: 0.7247
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 113/500
# 1/3, train_loss: 0.4932
# 2/3, train_loss: 0.5357
# 3/3, train_loss: 0.5176
# 4/3, train_loss: 0.5237
# Epoch 113 average loss: 0.5176
# ----------
# Epoch 114/500
# 1/3, train_loss: 0.5068
# 2/3, train_loss: 0.5362
# 3/3, train_loss: 0.5212
# 4/3, train_loss: 0.5276
# Epoch 114 average loss: 0.5230
# current epoch: 114 current mean dice: 0.7242
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 115/500
# 1/3, train_loss: 0.5321
# 2/3, train_loss: 0.5380
# 3/3, train_loss: 0.5048
# 4/3, train_loss: 0.5055
# Epoch 115 average loss: 0.5201
# ----------
# Epoch 116/500
# 1/3, train_loss: 0.5165
# 2/3, train_loss: 0.5172
# 3/3, train_loss: 0.5089
# 4/3, train_loss: 0.5199
# Epoch 116 average loss: 0.5156
# current epoch: 116 current mean dice: 0.7253
# best mean dice: 0.7262 at epoch: 102
# ----------
# Epoch 117/500
# 1/3, train_loss: 0.5052
# 2/3, train_loss: 0.5209
# 3/3, train_loss: 0.5346
# 4/3, train_loss: 0.5285
# Epoch 117 average loss: 0.5223
# ----------
# Epoch 118/500
# 1/3, train_loss: 0.5155
# 2/3, train_loss: 0.5046
# 3/3, train_loss: 0.5170
# 4/3, train_loss: 0.5406
# Epoch 118 average loss: 0.5194
# saved new best metric model
# current epoch: 118 current mean dice: 0.7284
# best mean dice: 0.7284 at epoch: 118
# ----------
# Epoch 119/500
# 1/3, train_loss: 0.5228
# 2/3, train_loss: 0.5285
# 3/3, train_loss: 0.4929
# 4/3, train_loss: 0.5260
# Epoch 119 average loss: 0.5176
# ----------
# Epoch 120/500
# 1/3, train_loss: 0.5314
# 2/3, train_loss: 0.4903
# 3/3, train_loss: 0.5306
# 4/3, train_loss: 0.5282
# Epoch 120 average loss: 0.5201
# saved new best metric model
# current epoch: 120 current mean dice: 0.7304
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 121/500
# 1/3, train_loss: 0.5063
# 2/3, train_loss: 0.5047
# 3/3, train_loss: 0.5282
# 4/3, train_loss: 0.5232
# Epoch 121 average loss: 0.5156
# ----------
# Epoch 122/500
# 1/3, train_loss: 0.5111
# 2/3, train_loss: 0.5320
# 3/3, train_loss: 0.5206
# 4/3, train_loss: 0.5242
# Epoch 122 average loss: 0.5220
# current epoch: 122 current mean dice: 0.7297
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 123/500
# 1/3, train_loss: 0.5172
# 2/3, train_loss: 0.5172
# 3/3, train_loss: 0.4909
# 4/3, train_loss: 0.5185
# Epoch 123 average loss: 0.5110
# ----------
# Epoch 124/500
# 1/3, train_loss: 0.5090
# 2/3, train_loss: 0.5319
# 3/3, train_loss: 0.5082
# 4/3, train_loss: 0.5012
# Epoch 124 average loss: 0.5126
# current epoch: 124 current mean dice: 0.7278
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 125/500
# 1/3, train_loss: 0.5344
# 2/3, train_loss: 0.5212
# 3/3, train_loss: 0.5317
# 4/3, train_loss: 0.5259
# Epoch 125 average loss: 0.5283
# ----------
# Epoch 126/500
# 1/3, train_loss: 0.5069
# 2/3, train_loss: 0.5147
# 3/3, train_loss: 0.5267
# 4/3, train_loss: 0.5130
# Epoch 126 average loss: 0.5153
# current epoch: 126 current mean dice: 0.7285
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 127/500
# 1/3, train_loss: 0.5169
# 2/3, train_loss: 0.5295
# 3/3, train_loss: 0.5032
# 4/3, train_loss: 0.5139
# Epoch 127 average loss: 0.5159
# ----------
# Epoch 128/500
# 1/3, train_loss: 0.5227
# 2/3, train_loss: 0.4963
# 3/3, train_loss: 0.5165
# 4/3, train_loss: 0.5078
# Epoch 128 average loss: 0.5108
# current epoch: 128 current mean dice: 0.7265
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 129/500
# 1/3, train_loss: 0.5234
# 2/3, train_loss: 0.5004
# 3/3, train_loss: 0.5020
# 4/3, train_loss: 0.5044
# Epoch 129 average loss: 0.5076
# ----------
# Epoch 130/500
# 1/3, train_loss: 0.5454
# 2/3, train_loss: 0.4998
# 3/3, train_loss: 0.5057
# 4/3, train_loss: 0.5257
# Epoch 130 average loss: 0.5191
# current epoch: 130 current mean dice: 0.7221
# best mean dice: 0.7304 at epoch: 120
# ----------
# Epoch 131/500
# 1/3, train_loss: 0.4983
# 2/3, train_loss: 0.5230
# 3/3, train_loss: 0.5006
# 4/3, train_loss: 0.5154
# Epoch 131 average loss: 0.5093
# ----------
# Epoch 132/500
# 1/3, train_loss: 0.5087
# 2/3, train_loss: 0.5195
# 3/3, train_loss: 0.5213
# 4/3, train_loss: 0.4934
# Epoch 132 average loss: 0.5107
# saved new best metric model
# current epoch: 132 current mean dice: 0.7314
# best mean dice: 0.7314 at epoch: 132
# ----------
# Epoch 133/500
# 1/3, train_loss: 0.5359
# 2/3, train_loss: 0.5082
# 3/3, train_loss: 0.5151
# 4/3, train_loss: 0.4916
# Epoch 133 average loss: 0.5127
# ----------
# Epoch 134/500
# 1/3, train_loss: 0.5031
# 2/3, train_loss: 0.5253
# 3/3, train_loss: 0.5073
# 4/3, train_loss: 0.5016
# Epoch 134 average loss: 0.5093
# saved new best metric model
# current epoch: 134 current mean dice: 0.7431
# best mean dice: 0.7431 at epoch: 134
# ----------
# Epoch 135/500
# 1/3, train_loss: 0.5487
# 2/3, train_loss: 0.4878
# 3/3, train_loss: 0.5124
# 4/3, train_loss: 0.5050
# Epoch 135 average loss: 0.5135
# ----------
# Epoch 136/500
# 1/3, train_loss: 0.5132
# 2/3, train_loss: 0.5190
# 3/3, train_loss: 0.5061
# 4/3, train_loss: 0.5026
# Epoch 136 average loss: 0.5102
# saved new best metric model
# current epoch: 136 current mean dice: 0.7483
# best mean dice: 0.7483 at epoch: 136
# ----------
# Epoch 137/500
# 1/3, train_loss: 0.5202
# 2/3, train_loss: 0.4841
# 3/3, train_loss: 0.5288
# 4/3, train_loss: 0.4895
# Epoch 137 average loss: 0.5056
# ----------
# Epoch 138/500
# 1/3, train_loss: 0.5258
# 2/3, train_loss: 0.5189
# 3/3, train_loss: 0.4841
# 4/3, train_loss: 0.4829
# Epoch 138 average loss: 0.5029
# saved new best metric model
# current epoch: 138 current mean dice: 0.7504
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 139/500
# 1/3, train_loss: 0.5201
# 2/3, train_loss: 0.5066
# 3/3, train_loss: 0.4924
# 4/3, train_loss: 0.5143
# Epoch 139 average loss: 0.5083
# ----------
# Epoch 140/500
# 1/3, train_loss: 0.4992
# 2/3, train_loss: 0.5060
# 3/3, train_loss: 0.5033
# 4/3, train_loss: 0.5167
# Epoch 140 average loss: 0.5063
# current epoch: 140 current mean dice: 0.7344
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 141/500
# 1/3, train_loss: 0.5037
# 2/3, train_loss: 0.5006
# 3/3, train_loss: 0.5265
# 4/3, train_loss: 0.5011
# Epoch 141 average loss: 0.5080
# ----------
# Epoch 142/500
# 1/3, train_loss: 0.5072
# 2/3, train_loss: 0.4813
# 3/3, train_loss: 0.5024
# 4/3, train_loss: 0.5165
# Epoch 142 average loss: 0.5018
# current epoch: 142 current mean dice: 0.7348
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 143/500
# 1/3, train_loss: 0.4987
# 2/3, train_loss: 0.5038
# 3/3, train_loss: 0.5167
# 4/3, train_loss: 0.5035
# Epoch 143 average loss: 0.5057
# ----------
# Epoch 144/500
# 1/3, train_loss: 0.5056
# 2/3, train_loss: 0.4954
# 3/3, train_loss: 0.5048
# 4/3, train_loss: 0.4944
# Epoch 144 average loss: 0.5000
# current epoch: 144 current mean dice: 0.7348
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 145/500
# 1/3, train_loss: 0.5234
# 2/3, train_loss: 0.4987
# 3/3, train_loss: 0.5181
# 4/3, train_loss: 0.4813
# Epoch 145 average loss: 0.5054
# ----------
# Epoch 146/500
# 1/3, train_loss: 0.5040
# 2/3, train_loss: 0.5042
# 3/3, train_loss: 0.4966
# 4/3, train_loss: 0.4938
# Epoch 146 average loss: 0.4996
# current epoch: 146 current mean dice: 0.7456
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 147/500
# 1/3, train_loss: 0.4981
# 2/3, train_loss: 0.4919
# 3/3, train_loss: 0.5156
# 4/3, train_loss: 0.5014
# Epoch 147 average loss: 0.5017
# ----------
# Epoch 148/500
# 1/3, train_loss: 0.4828
# 2/3, train_loss: 0.5127
# 3/3, train_loss: 0.5086
# 4/3, train_loss: 0.4933
# Epoch 148 average loss: 0.4994
# current epoch: 148 current mean dice: 0.7394
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 149/500
# 1/3, train_loss: 0.4959
# 2/3, train_loss: 0.5096
# 3/3, train_loss: 0.5142
# 4/3, train_loss: 0.5065
# Epoch 149 average loss: 0.5066
# ----------
# Epoch 150/500
# 1/3, train_loss: 0.5057
# 2/3, train_loss: 0.4900
# 3/3, train_loss: 0.5052
# 4/3, train_loss: 0.4938
# Epoch 150 average loss: 0.4987
# current epoch: 150 current mean dice: 0.7412
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 151/500
# 1/3, train_loss: 0.5110
# 2/3, train_loss: 0.5022
# 3/3, train_loss: 0.5284
# 4/3, train_loss: 0.5089
# Epoch 151 average loss: 0.5126
# ----------
# Epoch 152/500
# 1/3, train_loss: 0.4953
# 2/3, train_loss: 0.5133
# 3/3, train_loss: 0.4962
# 4/3, train_loss: 0.4738
# Epoch 152 average loss: 0.4947
# current epoch: 152 current mean dice: 0.7382
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 153/500
# 1/3, train_loss: 0.4984
# 2/3, train_loss: 0.4975
# 3/3, train_loss: 0.5060
# 4/3, train_loss: 0.5003
# Epoch 153 average loss: 0.5006
# ----------
# Epoch 154/500
# 1/3, train_loss: 0.5162
# 2/3, train_loss: 0.5154
# 3/3, train_loss: 0.5083
# 4/3, train_loss: 0.4963
# Epoch 154 average loss: 0.5090
# current epoch: 154 current mean dice: 0.7361
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 155/500
# 1/3, train_loss: 0.4832
# 2/3, train_loss: 0.5158
# 3/3, train_loss: 0.4845
# 4/3, train_loss: 0.5248
# Epoch 155 average loss: 0.5021
# ----------
# Epoch 156/500
# 1/3, train_loss: 0.5286
# 2/3, train_loss: 0.4887
# 3/3, train_loss: 0.5025
# 4/3, train_loss: 0.5191
# Epoch 156 average loss: 0.5097
# current epoch: 156 current mean dice: 0.7230
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 157/500
# 1/3, train_loss: 0.4915
# 2/3, train_loss: 0.4969
# 3/3, train_loss: 0.4861
# 4/3, train_loss: 0.5394
# Epoch 157 average loss: 0.5035
# ----------
# Epoch 158/500
# 1/3, train_loss: 0.4761
# 2/3, train_loss: 0.5240
# 3/3, train_loss: 0.4945
# 4/3, train_loss: 0.4897
# Epoch 158 average loss: 0.4961
# current epoch: 158 current mean dice: 0.7318
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 159/500
# 1/3, train_loss: 0.4816
# 2/3, train_loss: 0.5019
# 3/3, train_loss: 0.5067
# 4/3, train_loss: 0.4900
# Epoch 159 average loss: 0.4951
# ----------
# Epoch 160/500
# 1/3, train_loss: 0.4886
# 2/3, train_loss: 0.4855
# 3/3, train_loss: 0.4827
# 4/3, train_loss: 0.5032
# Epoch 160 average loss: 0.4900
# current epoch: 160 current mean dice: 0.7459
# best mean dice: 0.7504 at epoch: 138
# ----------
# Epoch 161/500
# 1/3, train_loss: 0.4893
# 2/3, train_loss: 0.4937
# 3/3, train_loss: 0.5145
# 4/3, train_loss: 0.4925
# Epoch 161 average loss: 0.4975
# ----------
# Epoch 162/500
# 1/3, train_loss: 0.5028
# 2/3, train_loss: 0.4982
# 3/3, train_loss: 0.4937
# 4/3, train_loss: 0.5095
# Epoch 162 average loss: 0.5010
# saved new best metric model
# current epoch: 162 current mean dice: 0.7545
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 163/500
# 1/3, train_loss: 0.5152
# 2/3, train_loss: 0.4959
# 3/3, train_loss: 0.4954
# 4/3, train_loss: 0.4990
# Epoch 163 average loss: 0.5014
# ----------
# Epoch 164/500
# 1/3, train_loss: 0.4845
# 2/3, train_loss: 0.4954
# 3/3, train_loss: 0.4831
# 4/3, train_loss: 0.5096
# Epoch 164 average loss: 0.4931
# current epoch: 164 current mean dice: 0.7512
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 165/500
# 1/3, train_loss: 0.4896
# 2/3, train_loss: 0.4767
# 3/3, train_loss: 0.4876
# 4/3, train_loss: 0.5101
# Epoch 165 average loss: 0.4910
# ----------
# Epoch 166/500
# 1/3, train_loss: 0.5012
# 2/3, train_loss: 0.4840
# 3/3, train_loss: 0.5139
# 4/3, train_loss: 0.4738
# Epoch 166 average loss: 0.4932
# current epoch: 166 current mean dice: 0.7520
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 167/500
# 1/3, train_loss: 0.4899
# 2/3, train_loss: 0.5072
# 3/3, train_loss: 0.4887
# 4/3, train_loss: 0.4897
# Epoch 167 average loss: 0.4939
# ----------
# Epoch 168/500
# 1/3, train_loss: 0.4896
# 2/3, train_loss: 0.4983
# 3/3, train_loss: 0.4936
# 4/3, train_loss: 0.5038
# Epoch 168 average loss: 0.4963
# current epoch: 168 current mean dice: 0.7500
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 169/500
# 1/3, train_loss: 0.4689
# 2/3, train_loss: 0.4993
# 3/3, train_loss: 0.4989
# 4/3, train_loss: 0.5037
# Epoch 169 average loss: 0.4927
# ----------
# Epoch 170/500
# 1/3, train_loss: 0.4947
# 2/3, train_loss: 0.4982
# 3/3, train_loss: 0.5168
# 4/3, train_loss: 0.4912
# Epoch 170 average loss: 0.5002
# current epoch: 170 current mean dice: 0.7529
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 171/500
# 1/3, train_loss: 0.4946
# 2/3, train_loss: 0.5206
# 3/3, train_loss: 0.4785
# 4/3, train_loss: 0.4946
# Epoch 171 average loss: 0.4971
# ----------
# Epoch 172/500
# 1/3, train_loss: 0.5050
# 2/3, train_loss: 0.5041
# 3/3, train_loss: 0.4883
# 4/3, train_loss: 0.5171
# Epoch 172 average loss: 0.5036
# current epoch: 172 current mean dice: 0.7409
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 173/500
# 1/3, train_loss: 0.5152
# 2/3, train_loss: 0.4963
# 3/3, train_loss: 0.4889
# 4/3, train_loss: 0.4828
# Epoch 173 average loss: 0.4958
# ----------
# Epoch 174/500
# 1/3, train_loss: 0.4661
# 2/3, train_loss: 0.5013
# 3/3, train_loss: 0.5017
# 4/3, train_loss: 0.5113
# Epoch 174 average loss: 0.4951
# current epoch: 174 current mean dice: 0.7400
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 175/500
# 1/3, train_loss: 0.5040
# 2/3, train_loss: 0.5014
# 3/3, train_loss: 0.4938
# 4/3, train_loss: 0.4912
# Epoch 175 average loss: 0.4976
# ----------
# Epoch 176/500
# 1/3, train_loss: 0.4657
# 2/3, train_loss: 0.4776
# 3/3, train_loss: 0.5175
# 4/3, train_loss: 0.5083
# Epoch 176 average loss: 0.4923
# current epoch: 176 current mean dice: 0.7233
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 177/500
# 1/3, train_loss: 0.4957
# 2/3, train_loss: 0.4920
# 3/3, train_loss: 0.4795
# 4/3, train_loss: 0.4852
# Epoch 177 average loss: 0.4881
# ----------
# Epoch 178/500
# 1/3, train_loss: 0.4773
# 2/3, train_loss: 0.4864
# 3/3, train_loss: 0.5064
# 4/3, train_loss: 0.4869
# Epoch 178 average loss: 0.4892
# current epoch: 178 current mean dice: 0.7377
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 179/500
# 1/3, train_loss: 0.4791
# 2/3, train_loss: 0.4786
# 3/3, train_loss: 0.5048
# 4/3, train_loss: 0.4831
# Epoch 179 average loss: 0.4864
# ----------
# Epoch 180/500
# 1/3, train_loss: 0.5060
# 2/3, train_loss: 0.4836
# 3/3, train_loss: 0.4714
# 4/3, train_loss: 0.4990
# Epoch 180 average loss: 0.4900
# current epoch: 180 current mean dice: 0.7359
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 181/500
# 1/3, train_loss: 0.4886
# 2/3, train_loss: 0.4675
# 3/3, train_loss: 0.4921
# 4/3, train_loss: 0.5001
# Epoch 181 average loss: 0.4871
# ----------
# Epoch 182/500
# 1/3, train_loss: 0.5046
# 2/3, train_loss: 0.4693
# 3/3, train_loss: 0.4906
# 4/3, train_loss: 0.4697
# Epoch 182 average loss: 0.4835
# current epoch: 182 current mean dice: 0.7465
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 183/500
# 1/3, train_loss: 0.4757
# 2/3, train_loss: 0.4712
# 3/3, train_loss: 0.5100
# 4/3, train_loss: 0.4948
# Epoch 183 average loss: 0.4879
# ----------
# Epoch 184/500
# 1/3, train_loss: 0.4817
# 2/3, train_loss: 0.4834
# 3/3, train_loss: 0.4966
# 4/3, train_loss: 0.4846
# Epoch 184 average loss: 0.4866
# current epoch: 184 current mean dice: 0.7381
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 185/500
# 1/3, train_loss: 0.4730
# 2/3, train_loss: 0.4924
# 3/3, train_loss: 0.4910
# 4/3, train_loss: 0.4928
# Epoch 185 average loss: 0.4873
# ----------
# Epoch 186/500
# 1/3, train_loss: 0.4885
# 2/3, train_loss: 0.4898
# 3/3, train_loss: 0.4804
# 4/3, train_loss: 0.4845
# Epoch 186 average loss: 0.4858
# current epoch: 186 current mean dice: 0.7504
# best mean dice: 0.7545 at epoch: 162
# ----------
# Epoch 187/500
# 1/3, train_loss: 0.4798
# 2/3, train_loss: 0.4932
# 3/3, train_loss: 0.4918
# 4/3, train_loss: 0.4809
# Epoch 187 average loss: 0.4864
# ----------
# Epoch 188/500
# 1/3, train_loss: 0.4663
# 2/3, train_loss: 0.4725
# 3/3, train_loss: 0.5116
# 4/3, train_loss: 0.4787
# Epoch 188 average loss: 0.4823
# saved new best metric model
# current epoch: 188 current mean dice: 0.7571
# best mean dice: 0.7571 at epoch: 188
# ----------
# Epoch 189/500
# 1/3, train_loss: 0.4805
# 2/3, train_loss: 0.4850
# 3/3, train_loss: 0.5104
# 4/3, train_loss: 0.5003
# Epoch 189 average loss: 0.4941
# ----------
# Epoch 190/500
# 1/3, train_loss: 0.5136
# 2/3, train_loss: 0.4781
# 3/3, train_loss: 0.4771
# 4/3, train_loss: 0.4695
# Epoch 190 average loss: 0.4846
# saved new best metric model
# current epoch: 190 current mean dice: 0.7651
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 191/500
# 1/3, train_loss: 0.5017
# 2/3, train_loss: 0.4748
# 3/3, train_loss: 0.4796
# 4/3, train_loss: 0.4967
# Epoch 191 average loss: 0.4882
# ----------
# Epoch 192/500
# 1/3, train_loss: 0.4607
# 2/3, train_loss: 0.5010
# 3/3, train_loss: 0.4891
# 4/3, train_loss: 0.4906
# Epoch 192 average loss: 0.4854
# current epoch: 192 current mean dice: 0.7539
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 193/500
# 1/3, train_loss: 0.4776
# 2/3, train_loss: 0.5025
# 3/3, train_loss: 0.4938
# 4/3, train_loss: 0.4650
# Epoch 193 average loss: 0.4847
# ----------
# Epoch 194/500
# 1/3, train_loss: 0.4881
# 2/3, train_loss: 0.4982
# 3/3, train_loss: 0.4742
# 4/3, train_loss: 0.4567
# Epoch 194 average loss: 0.4793
# current epoch: 194 current mean dice: 0.7586
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 195/500
# 1/3, train_loss: 0.4817
# 2/3, train_loss: 0.4797
# 3/3, train_loss: 0.4715
# 4/3, train_loss: 0.4838
# Epoch 195 average loss: 0.4792
# ----------
# Epoch 196/500
# 1/3, train_loss: 0.4900
# 2/3, train_loss: 0.4730
# 3/3, train_loss: 0.4715
# 4/3, train_loss: 0.5055
# Epoch 196 average loss: 0.4850
# current epoch: 196 current mean dice: 0.7558
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 197/500
# 1/3, train_loss: 0.4838
# 2/3, train_loss: 0.4516
# 3/3, train_loss: 0.4854
# 4/3, train_loss: 0.4814
# Epoch 197 average loss: 0.4755
# ----------
# Epoch 198/500
# 1/3, train_loss: 0.4664
# 2/3, train_loss: 0.4939
# 3/3, train_loss: 0.4958
# 4/3, train_loss: 0.4681
# Epoch 198 average loss: 0.4811
# current epoch: 198 current mean dice: 0.7596
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 199/500
# 1/3, train_loss: 0.4851
# 2/3, train_loss: 0.4789
# 3/3, train_loss: 0.4653
# 4/3, train_loss: 0.4872
# Epoch 199 average loss: 0.4791
# ----------
# Epoch 200/500
# 1/3, train_loss: 0.4729
# 2/3, train_loss: 0.4710
# 3/3, train_loss: 0.4544
# 4/3, train_loss: 0.4962
# Epoch 200 average loss: 0.4736
# current epoch: 200 current mean dice: 0.7572
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 201/500
# 1/3, train_loss: 0.4735
# 2/3, train_loss: 0.4897
# 3/3, train_loss: 0.4789
# 4/3, train_loss: 0.4677
# Epoch 201 average loss: 0.4775
# ----------
# Epoch 202/500
# 1/3, train_loss: 0.4663
# 2/3, train_loss: 0.5055
# 3/3, train_loss: 0.4759
# 4/3, train_loss: 0.4802
# Epoch 202 average loss: 0.4820
# current epoch: 202 current mean dice: 0.7466
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 203/500
# 1/3, train_loss: 0.4971
# 2/3, train_loss: 0.4957
# 3/3, train_loss: 0.4554
# 4/3, train_loss: 0.4637
# Epoch 203 average loss: 0.4780
# ----------
# Epoch 204/500
# 1/3, train_loss: 0.5046
# 2/3, train_loss: 0.4658
# 3/3, train_loss: 0.4590
# 4/3, train_loss: 0.4716
# Epoch 204 average loss: 0.4753
# current epoch: 204 current mean dice: 0.7466
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 205/500
# 1/3, train_loss: 0.4722
# 2/3, train_loss: 0.4733
# 3/3, train_loss: 0.4703
# 4/3, train_loss: 0.4723
# Epoch 205 average loss: 0.4720
# ----------
# Epoch 206/500
# 1/3, train_loss: 0.4884
# 2/3, train_loss: 0.4699
# 3/3, train_loss: 0.4628
# 4/3, train_loss: 0.5023
# Epoch 206 average loss: 0.4808
# current epoch: 206 current mean dice: 0.7364
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 207/500
# 1/3, train_loss: 0.4983
# 2/3, train_loss: 0.4538
# 3/3, train_loss: 0.4718
# 4/3, train_loss: 0.4994
# Epoch 207 average loss: 0.4808
# ----------
# Epoch 208/500
# 1/3, train_loss: 0.4540
# 2/3, train_loss: 0.4776
# 3/3, train_loss: 0.4639
# 4/3, train_loss: 0.4706
# Epoch 208 average loss: 0.4665
# current epoch: 208 current mean dice: 0.7597
# best mean dice: 0.7651 at epoch: 190
# ----------
# Epoch 209/500
# 1/3, train_loss: 0.4798
# 2/3, train_loss: 0.4592
# 3/3, train_loss: 0.4829
# 4/3, train_loss: 0.4672
# Epoch 209 average loss: 0.4723
# ----------
# Epoch 210/500
# 1/3, train_loss: 0.4917
# 2/3, train_loss: 0.4933
# 3/3, train_loss: 0.4654
# 4/3, train_loss: 0.4861
# Epoch 210 average loss: 0.4841
# saved new best metric model
# current epoch: 210 current mean dice: 0.7685
# best mean dice: 0.7685 at epoch: 210
# ----------
# Epoch 211/500
# 1/3, train_loss: 0.4722
# 2/3, train_loss: 0.4860
# 3/3, train_loss: 0.4840
# 4/3, train_loss: 0.4776
# Epoch 211 average loss: 0.4800
# ----------
# Epoch 212/500
# 1/3, train_loss: 0.4669
# 2/3, train_loss: 0.4702
# 3/3, train_loss: 0.4917
# 4/3, train_loss: 0.4840
# Epoch 212 average loss: 0.4782
# saved new best metric model
# current epoch: 212 current mean dice: 0.7768
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 213/500
# 1/3, train_loss: 0.5091
# 2/3, train_loss: 0.4817
# 3/3, train_loss: 0.4601
# 4/3, train_loss: 0.4781
# Epoch 213 average loss: 0.4823
# ----------
# Epoch 214/500
# 1/3, train_loss: 0.4877
# 2/3, train_loss: 0.4700
# 3/3, train_loss: 0.4712
# 4/3, train_loss: 0.4824
# Epoch 214 average loss: 0.4778
# current epoch: 214 current mean dice: 0.7548
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 215/500
# 1/3, train_loss: 0.5074
# 2/3, train_loss: 0.4916
# 3/3, train_loss: 0.4703
# 4/3, train_loss: 0.4728
# Epoch 215 average loss: 0.4855
# ----------
# Epoch 216/500
# 1/3, train_loss: 0.4740
# 2/3, train_loss: 0.4880
# 3/3, train_loss: 0.4677
# 4/3, train_loss: 0.4760
# Epoch 216 average loss: 0.4765
# current epoch: 216 current mean dice: 0.7463
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 217/500
# 1/3, train_loss: 0.4782
# 2/3, train_loss: 0.4814
# 3/3, train_loss: 0.4734
# 4/3, train_loss: 0.4669
# Epoch 217 average loss: 0.4750
# ----------
# Epoch 218/500
# 1/3, train_loss: 0.4598
# 2/3, train_loss: 0.4808
# 3/3, train_loss: 0.5031
# 4/3, train_loss: 0.4583
# Epoch 218 average loss: 0.4755
# current epoch: 218 current mean dice: 0.7371
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 219/500
# 1/3, train_loss: 0.4666
# 2/3, train_loss: 0.4763
# 3/3, train_loss: 0.4807
# 4/3, train_loss: 0.4840
# Epoch 219 average loss: 0.4769
# ----------
# Epoch 220/500
# 1/3, train_loss: 0.4671
# 2/3, train_loss: 0.4686
# 3/3, train_loss: 0.4626
# 4/3, train_loss: 0.4687
# Epoch 220 average loss: 0.4667
# current epoch: 220 current mean dice: 0.7389
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 221/500
# 1/3, train_loss: 0.4671
# 2/3, train_loss: 0.4831
# 3/3, train_loss: 0.4741
# 4/3, train_loss: 0.4871
# Epoch 221 average loss: 0.4779
# ----------
# Epoch 222/500
# 1/3, train_loss: 0.4738
# 2/3, train_loss: 0.4647
# 3/3, train_loss: 0.4694
# 4/3, train_loss: 0.4935
# Epoch 222 average loss: 0.4753
# current epoch: 222 current mean dice: 0.7452
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 223/500
# 1/3, train_loss: 0.4736
# 2/3, train_loss: 0.4964
# 3/3, train_loss: 0.4612
# 4/3, train_loss: 0.4859
# Epoch 223 average loss: 0.4793
# ----------
# Epoch 224/500
# 1/3, train_loss: 0.4867
# 2/3, train_loss: 0.4775
# 3/3, train_loss: 0.4617
# 4/3, train_loss: 0.4643
# Epoch 224 average loss: 0.4726
# current epoch: 224 current mean dice: 0.7563
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 225/500
# 1/3, train_loss: 0.4521
# 2/3, train_loss: 0.4763
# 3/3, train_loss: 0.4743
# 4/3, train_loss: 0.5047
# Epoch 225 average loss: 0.4769
# ----------
# Epoch 226/500
# 1/3, train_loss: 0.4857
# 2/3, train_loss: 0.4773
# 3/3, train_loss: 0.4758
# 4/3, train_loss: 0.4710
# Epoch 226 average loss: 0.4775
# current epoch: 226 current mean dice: 0.7635
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 227/500
# 1/3, train_loss: 0.4954
# 2/3, train_loss: 0.4727
# 3/3, train_loss: 0.4684
# 4/3, train_loss: 0.4520
# Epoch 227 average loss: 0.4721
# ----------
# Epoch 228/500
# 1/3, train_loss: 0.4731
# 2/3, train_loss: 0.4566
# 3/3, train_loss: 0.4821
# 4/3, train_loss: 0.4661
# Epoch 228 average loss: 0.4695
# current epoch: 228 current mean dice: 0.7679
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 229/500
# 1/3, train_loss: 0.4599
# 2/3, train_loss: 0.4854
# 3/3, train_loss: 0.4842
# 4/3, train_loss: 0.4864
# Epoch 229 average loss: 0.4790
# ----------
# Epoch 230/500
# 1/3, train_loss: 0.4672
# 2/3, train_loss: 0.4950
# 3/3, train_loss: 0.4821
# 4/3, train_loss: 0.4776
# Epoch 230 average loss: 0.4805
# current epoch: 230 current mean dice: 0.7600
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 231/500
# 1/3, train_loss: 0.4715
# 2/3, train_loss: 0.4868
# 3/3, train_loss: 0.4631
# 4/3, train_loss: 0.4682
# Epoch 231 average loss: 0.4724
# ----------
# Epoch 232/500
# 1/3, train_loss: 0.4954
# 2/3, train_loss: 0.4830
# 3/3, train_loss: 0.4603
# 4/3, train_loss: 0.4485
# Epoch 232 average loss: 0.4718
# current epoch: 232 current mean dice: 0.7667
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 233/500
# 1/3, train_loss: 0.4633
# 2/3, train_loss: 0.4751
# 3/3, train_loss: 0.4815
# 4/3, train_loss: 0.4732
# Epoch 233 average loss: 0.4733
# ----------
# Epoch 234/500
# 1/3, train_loss: 0.4683
# 2/3, train_loss: 0.4733
# 3/3, train_loss: 0.4747
# 4/3, train_loss: 0.4713
# Epoch 234 average loss: 0.4719
# current epoch: 234 current mean dice: 0.7617
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 235/500
# 1/3, train_loss: 0.4798
# 2/3, train_loss: 0.4628
# 3/3, train_loss: 0.4642
# 4/3, train_loss: 0.4695
# Epoch 235 average loss: 0.4691
# ----------
# Epoch 236/500
# 1/3, train_loss: 0.4666
# 2/3, train_loss: 0.4709
# 3/3, train_loss: 0.4713
# 4/3, train_loss: 0.4698
# Epoch 236 average loss: 0.4696
# current epoch: 236 current mean dice: 0.7745
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 237/500
# 1/3, train_loss: 0.4522
# 2/3, train_loss: 0.4891
# 3/3, train_loss: 0.4784
# 4/3, train_loss: 0.4854
# Epoch 237 average loss: 0.4763
# ----------
# Epoch 238/500
# 1/3, train_loss: 0.4732
# 2/3, train_loss: 0.4633
# 3/3, train_loss: 0.4705
# 4/3, train_loss: 0.4736
# Epoch 238 average loss: 0.4701
# current epoch: 238 current mean dice: 0.7722
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 239/500
# 1/3, train_loss: 0.4902
# 2/3, train_loss: 0.4672
# 3/3, train_loss: 0.4594
# 4/3, train_loss: 0.4767
# Epoch 239 average loss: 0.4734
# ----------
# Epoch 240/500
# 1/3, train_loss: 0.4737
# 2/3, train_loss: 0.4657
# 3/3, train_loss: 0.4767
# 4/3, train_loss: 0.4494
# Epoch 240 average loss: 0.4663
# current epoch: 240 current mean dice: 0.7714
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 241/500
# 1/3, train_loss: 0.4656
# 2/3, train_loss: 0.4685
# 3/3, train_loss: 0.4782
# 4/3, train_loss: 0.4838
# Epoch 241 average loss: 0.4740
# ----------
# Epoch 242/500
# 1/3, train_loss: 0.4692
# 2/3, train_loss: 0.4590
# 3/3, train_loss: 0.4603
# 4/3, train_loss: 0.4773
# Epoch 242 average loss: 0.4665
# current epoch: 242 current mean dice: 0.7675
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 243/500
# 1/3, train_loss: 0.4731
# 2/3, train_loss: 0.4670
# 3/3, train_loss: 0.4681
# 4/3, train_loss: 0.4635
# Epoch 243 average loss: 0.4679
# ----------
# Epoch 244/500
# 1/3, train_loss: 0.4481
# 2/3, train_loss: 0.4839
# 3/3, train_loss: 0.4664
# 4/3, train_loss: 0.4647
# Epoch 244 average loss: 0.4658
# current epoch: 244 current mean dice: 0.7746
# best mean dice: 0.7768 at epoch: 212
# ----------
# Epoch 245/500
# 1/3, train_loss: 0.4935
# 2/3, train_loss: 0.4638
# 3/3, train_loss: 0.4637
# 4/3, train_loss: 0.4491
# Epoch 245 average loss: 0.4675
# ----------
# Epoch 246/500
# 1/3, train_loss: 0.4662
# 2/3, train_loss: 0.4807
# 3/3, train_loss: 0.4916
# 4/3, train_loss: 0.4623
# Epoch 246 average loss: 0.4752
# saved new best metric model
# current epoch: 246 current mean dice: 0.7831
# best mean dice: 0.7831 at epoch: 246
# ----------
# Epoch 247/500
# 1/3, train_loss: 0.4699
# 2/3, train_loss: 0.4769
# 3/3, train_loss: 0.4827
# 4/3, train_loss: 0.4462
# Epoch 247 average loss: 0.4689
# ----------
# Epoch 248/500
# 1/3, train_loss: 0.4711
# 2/3, train_loss: 0.4651
# 3/3, train_loss: 0.4482
# 4/3, train_loss: 0.4776
# Epoch 248 average loss: 0.4655
# current epoch: 248 current mean dice: 0.7807
# best mean dice: 0.7831 at epoch: 246
# ----------
# Epoch 249/500
# ...
# Epoch 418 average loss: 0.4331
# current epoch: 418 current mean dice: 0.8129
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 419/500
# 1/3, train_loss: 0.4465
# 2/3, train_loss: 0.4355
# 3/3, train_loss: 0.4260
# 4/3, train_loss: 0.4418
# Epoch 419 average loss: 0.4375
# ----------
# Epoch 420/500
# 1/3, train_loss: 0.4447
# 2/3, train_loss: 0.4365
# 3/3, train_loss: 0.4628
# 4/3, train_loss: 0.4377
# Epoch 420 average loss: 0.4454
# current epoch: 420 current mean dice: 0.8048
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 421/500
# 1/3, train_loss: 0.4479
# 2/3, train_loss: 0.4353
# 3/3, train_loss: 0.4331
# 4/3, train_loss: 0.4602
# Epoch 421 average loss: 0.4441
# ----------
# Epoch 422/500
# 1/3, train_loss: 0.4357
# 2/3, train_loss: 0.4501
# 3/3, train_loss: 0.4464
# 4/3, train_loss: 0.4258
# Epoch 422 average loss: 0.4395
# current epoch: 422 current mean dice: 0.7946
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 423/500
# 1/3, train_loss: 0.4390
# 2/3, train_loss: 0.4436
# 3/3, train_loss: 0.4355
# 4/3, train_loss: 0.4289
# Epoch 423 average loss: 0.4368
# ----------
# Epoch 424/500
# 1/3, train_loss: 0.4212
# 2/3, train_loss: 0.4497
# 3/3, train_loss: 0.4676
# 4/3, train_loss: 0.4293
# Epoch 424 average loss: 0.4419
# current epoch: 424 current mean dice: 0.7974
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 425/500
# 1/3, train_loss: 0.4324
# 2/3, train_loss: 0.4323
# 3/3, train_loss: 0.4458
# 4/3, train_loss: 0.4437
# Epoch 425 average loss: 0.4385
# ----------
# Epoch 426/500
# 1/3, train_loss: 0.4306
# 2/3, train_loss: 0.4383
# 3/3, train_loss: 0.4296
# 4/3, train_loss: 0.4514
# Epoch 426 average loss: 0.4375
# current epoch: 426 current mean dice: 0.8021
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 427/500
# 1/3, train_loss: 0.4513
# 2/3, train_loss: 0.4543
# 3/3, train_loss: 0.4241
# 4/3, train_loss: 0.4235
# Epoch 427 average loss: 0.4383
# ----------
# Epoch 428/500
# 1/3, train_loss: 0.4269
# 2/3, train_loss: 0.4493
# 3/3, train_loss: 0.4227
# 4/3, train_loss: 0.4462
# Epoch 428 average loss: 0.4363
# current epoch: 428 current mean dice: 0.8042
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 429/500
# 1/3, train_loss: 0.4235
# 2/3, train_loss: 0.4418
# 3/3, train_loss: 0.4331
# 4/3, train_loss: 0.4462
# Epoch 429 average loss: 0.4362
# ----------
# Epoch 430/500
# 1/3, train_loss: 0.4486
# 2/3, train_loss: 0.4509
# 3/3, train_loss: 0.4536
# 4/3, train_loss: 0.4215
# Epoch 430 average loss: 0.4436
# current epoch: 430 current mean dice: 0.7988
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 431/500
# 1/3, train_loss: 0.4205
# 2/3, train_loss: 0.4413
# 3/3, train_loss: 0.4349
# 4/3, train_loss: 0.4475
# Epoch 431 average loss: 0.4361
# ----------
# Epoch 432/500
# 1/3, train_loss: 0.4384
# 2/3, train_loss: 0.4254
# 3/3, train_loss: 0.4292
# 4/3, train_loss: 0.4300
# Epoch 432 average loss: 0.4308
# current epoch: 432 current mean dice: 0.8063
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 433/500
# 1/3, train_loss: 0.4462
# 2/3, train_loss: 0.4509
# 3/3, train_loss: 0.4550
# 4/3, train_loss: 0.4473
# Epoch 433 average loss: 0.4499
# ----------
# Epoch 434/500
# 1/3, train_loss: 0.4385
# 2/3, train_loss: 0.4348
# 3/3, train_loss: 0.4363
# 4/3, train_loss: 0.4313
# Epoch 434 average loss: 0.4352
# current epoch: 434 current mean dice: 0.8022
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 435/500
# 1/3, train_loss: 0.4259
# 2/3, train_loss: 0.4386
# 3/3, train_loss: 0.4216
# 4/3, train_loss: 0.4312
# Epoch 435 average loss: 0.4293
# ----------
# Epoch 436/500
# 1/3, train_loss: 0.4401
# 2/3, train_loss: 0.4445
# 3/3, train_loss: 0.4543
# 4/3, train_loss: 0.4337
# Epoch 436 average loss: 0.4431
# current epoch: 436 current mean dice: 0.7973
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 437/500
# 1/3, train_loss: 0.4420
# 2/3, train_loss: 0.4365
# 3/3, train_loss: 0.4408
# 4/3, train_loss: 0.4331
# Epoch 437 average loss: 0.4381
# ----------
# Epoch 438/500
# 1/3, train_loss: 0.4317
# 2/3, train_loss: 0.4577
# 3/3, train_loss: 0.4536
# 4/3, train_loss: 0.4560
# Epoch 438 average loss: 0.4497
# current epoch: 438 current mean dice: 0.7896
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 439/500
# 1/3, train_loss: 0.4247
# 2/3, train_loss: 0.4297
# 3/3, train_loss: 0.4303
# 4/3, train_loss: 0.4497
# Epoch 439 average loss: 0.4336
# ----------
# Epoch 440/500
# 1/3, train_loss: 0.4184
# 2/3, train_loss: 0.4668
# 3/3, train_loss: 0.4456
# 4/3, train_loss: 0.4345
# Epoch 440 average loss: 0.4413
# current epoch: 440 current mean dice: 0.7984
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 441/500
# 1/3, train_loss: 0.4226
# 2/3, train_loss: 0.4699
# 3/3, train_loss: 0.4283
# 4/3, train_loss: 0.4435
# Epoch 441 average loss: 0.4411
# ----------
# Epoch 442/500
# 1/3, train_loss: 0.4323
# 2/3, train_loss: 0.4321
# 3/3, train_loss: 0.4307
# 4/3, train_loss: 0.4273
# Epoch 442 average loss: 0.4306
# current epoch: 442 current mean dice: 0.8089
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 443/500
# 1/3, train_loss: 0.4345
# 2/3, train_loss: 0.4304
# 3/3, train_loss: 0.4499
# 4/3, train_loss: 0.4316
# Epoch 443 average loss: 0.4366
# ----------
# Epoch 444/500
# 1/3, train_loss: 0.4365
# 2/3, train_loss: 0.4526
# 3/3, train_loss: 0.4444
# 4/3, train_loss: 0.4217
# Epoch 444 average loss: 0.4388
# current epoch: 444 current mean dice: 0.7939
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 445/500
# 1/3, train_loss: 0.4424
# 2/3, train_loss: 0.4608
# 3/3, train_loss: 0.4496
# 4/3, train_loss: 0.4401
# Epoch 445 average loss: 0.4482
# ----------
# Epoch 446/500
# 1/3, train_loss: 0.4460
# 2/3, train_loss: 0.4347
# 3/3, train_loss: 0.4304
# 4/3, train_loss: 0.4398
# Epoch 446 average loss: 0.4377
# current epoch: 446 current mean dice: 0.7885
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 447/500
# 1/3, train_loss: 0.4242
# 2/3, train_loss: 0.4337
# 3/3, train_loss: 0.4395
# 4/3, train_loss: 0.4368
# Epoch 447 average loss: 0.4335
# ----------
# Epoch 448/500
# 1/3, train_loss: 0.4517
# 2/3, train_loss: 0.4251
# 3/3, train_loss: 0.4348
# 4/3, train_loss: 0.4376
# Epoch 448 average loss: 0.4373
# current epoch: 448 current mean dice: 0.7936
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 449/500
# 1/3, train_loss: 0.4194
# 2/3, train_loss: 0.4488
# 3/3, train_loss: 0.4389
# 4/3, train_loss: 0.4293
# Epoch 449 average loss: 0.4341
# ----------
# Epoch 450/500
# 1/3, train_loss: 0.4375
# 2/3, train_loss: 0.4276
# 3/3, train_loss: 0.4543
# 4/3, train_loss: 0.4278
# Epoch 450 average loss: 0.4368
# current epoch: 450 current mean dice: 0.8112
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 451/500
# 1/3, train_loss: 0.4298
# 2/3, train_loss: 0.4435
# 3/3, train_loss: 0.4503
# 4/3, train_loss: 0.4295
# Epoch 451 average loss: 0.4383
# ----------
# Epoch 452/500
# 1/3, train_loss: 0.4617
# 2/3, train_loss: 0.4220
# 3/3, train_loss: 0.4299
# 4/3, train_loss: 0.4291
# Epoch 452 average loss: 0.4357
# current epoch: 452 current mean dice: 0.8175
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 453/500
# 1/3, train_loss: 0.4377
# 2/3, train_loss: 0.4323
# 3/3, train_loss: 0.4341
# 4/3, train_loss: 0.4536
# Epoch 453 average loss: 0.4394
# ----------
# Epoch 454/500
# 1/3, train_loss: 0.4334
# 2/3, train_loss: 0.4317
# 3/3, train_loss: 0.4160
# 4/3, train_loss: 0.4444
# Epoch 454 average loss: 0.4314
# current epoch: 454 current mean dice: 0.8119
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 455/500
# 1/3, train_loss: 0.4585
# 2/3, train_loss: 0.4289
# 3/3, train_loss: 0.4337
# 4/3, train_loss: 0.4666
# Epoch 455 average loss: 0.4469
# ----------
# Epoch 456/500
# 1/3, train_loss: 0.4470
# 2/3, train_loss: 0.4282
# 3/3, train_loss: 0.4330
# 4/3, train_loss: 0.4294
# Epoch 456 average loss: 0.4344
# current epoch: 456 current mean dice: 0.8154
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 457/500
# 1/3, train_loss: 0.4504
# 2/3, train_loss: 0.4205
# 3/3, train_loss: 0.4346
# 4/3, train_loss: 0.4343
# Epoch 457 average loss: 0.4350
# ----------
# Epoch 458/500
# 1/3, train_loss: 0.4398
# 2/3, train_loss: 0.4281
# 3/3, train_loss: 0.4255
# 4/3, train_loss: 0.4242
# Epoch 458 average loss: 0.4294
# current epoch: 458 current mean dice: 0.8120
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 459/500
# 1/3, train_loss: 0.4340
# 2/3, train_loss: 0.4328
# 3/3, train_loss: 0.4378
# 4/3, train_loss: 0.4349
# Epoch 459 average loss: 0.4349
# ----------
# Epoch 460/500
# 1/3, train_loss: 0.4219
# 2/3, train_loss: 0.4521
# 3/3, train_loss: 0.4442
# 4/3, train_loss: 0.4444
# Epoch 460 average loss: 0.4406
# current epoch: 460 current mean dice: 0.8089
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 461/500
# 1/3, train_loss: 0.4078
# 2/3, train_loss: 0.4382
# 3/3, train_loss: 0.4250
# 4/3, train_loss: 0.4346
# Epoch 461 average loss: 0.4264
# ----------
# Epoch 462/500
# 1/3, train_loss: 0.4254
# 2/3, train_loss: 0.4315
# 3/3, train_loss: 0.4518
# 4/3, train_loss: 0.4216
# Epoch 462 average loss: 0.4326
# current epoch: 462 current mean dice: 0.8100
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 463/500
# 1/3, train_loss: 0.4410
# 2/3, train_loss: 0.4460
# 3/3, train_loss: 0.4172
# 4/3, train_loss: 0.4396
# Epoch 463 average loss: 0.4359
# ----------
# Epoch 464/500
# 1/3, train_loss: 0.4290
# 2/3, train_loss: 0.4262
# 3/3, train_loss: 0.4328
# 4/3, train_loss: 0.4201
# Epoch 464 average loss: 0.4270
# current epoch: 464 current mean dice: 0.8123
# best mean dice: 0.8184 at epoch: 416
# ----------
# Epoch 465/500
# 1/3, train_loss: 0.4281
# 2/3, train_loss: 0.4542
# 3/3, train_loss: 0.4334
# 4/3, train_loss: 0.4378
# Epoch 465 average loss: 0.4384
# ----------
# Epoch 466/500
# 1/3, train_loss: 0.4198
# 2/3, train_loss: 0.4405
# 3/3, train_loss: 0.4403
# 4/3, train_loss: 0.4257
# Epoch 466 average loss: 0.4316
# saved new best metric model
# current epoch: 466 current mean dice: 0.8252
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 467/500
# 1/3, train_loss: 0.4268
# 2/3, train_loss: 0.4455
# 3/3, train_loss: 0.4252
# 4/3, train_loss: 0.4229
# Epoch 467 average loss: 0.4301
# ----------
# Epoch 468/500
# 1/3, train_loss: 0.4267
# 2/3, train_loss: 0.4327
# 3/3, train_loss: 0.4438
# 4/3, train_loss: 0.4344
# Epoch 468 average loss: 0.4344
# current epoch: 468 current mean dice: 0.8089
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 469/500
# 1/3, train_loss: 0.4214
# 2/3, train_loss: 0.4300
# 3/3, train_loss: 0.4172
# 4/3, train_loss: 0.4407
# Epoch 469 average loss: 0.4273
# ----------
# Epoch 470/500
# 1/3, train_loss: 0.4475
# 2/3, train_loss: 0.4182
# 3/3, train_loss: 0.4173
# 4/3, train_loss: 0.4353
# Epoch 470 average loss: 0.4296
# current epoch: 470 current mean dice: 0.8096
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 471/500
# 1/3, train_loss: 0.4299
# 2/3, train_loss: 0.4361
# 3/3, train_loss: 0.4321
# 4/3, train_loss: 0.4249
# Epoch 471 average loss: 0.4308
# ----------
# Epoch 472/500
# 1/3, train_loss: 0.4196
# 2/3, train_loss: 0.4233
# 3/3, train_loss: 0.4259
# 4/3, train_loss: 0.4303
# Epoch 472 average loss: 0.4248
# current epoch: 472 current mean dice: 0.8002
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 473/500
# 1/3, train_loss: 0.4171
# 2/3, train_loss: 0.4440
# 3/3, train_loss: 0.4317
# 4/3, train_loss: 0.4218
# Epoch 473 average loss: 0.4286
# ----------
# Epoch 474/500
# 1/3, train_loss: 0.4303
# 2/3, train_loss: 0.4277
# 3/3, train_loss: 0.4345
# 4/3, train_loss: 0.4360
# Epoch 474 average loss: 0.4321
# current epoch: 474 current mean dice: 0.8132
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 475/500
# 1/3, train_loss: 0.4364
# 2/3, train_loss: 0.4474
# 3/3, train_loss: 0.4213
# 4/3, train_loss: 0.4172
# Epoch 475 average loss: 0.4306
# ----------
# Epoch 476/500
# 1/3, train_loss: 0.4258
# 2/3, train_loss: 0.4140
# 3/3, train_loss: 0.4529
# 4/3, train_loss: 0.4331
# Epoch 476 average loss: 0.4314
# current epoch: 476 current mean dice: 0.8105
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 477/500
# 1/3, train_loss: 0.4267
# 2/3, train_loss: 0.4121
# 3/3, train_loss: 0.4363
# 4/3, train_loss: 0.4283
# Epoch 477 average loss: 0.4258
# ----------
# Epoch 478/500
# 1/3, train_loss: 0.4252
# 2/3, train_loss: 0.4220
# 3/3, train_loss: 0.4434
# 4/3, train_loss: 0.4417
# Epoch 478 average loss: 0.4330
# current epoch: 478 current mean dice: 0.8121
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 479/500
# 1/3, train_loss: 0.4395
# 2/3, train_loss: 0.4111
# 3/3, train_loss: 0.4367
# 4/3, train_loss: 0.4210
# Epoch 479 average loss: 0.4271
# ----------
# Epoch 480/500
# 1/3, train_loss: 0.4451
# 2/3, train_loss: 0.4247
# 3/3, train_loss: 0.4436
# 4/3, train_loss: 0.4262
# Epoch 480 average loss: 0.4349
# current epoch: 480 current mean dice: 0.8128
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 481/500
# 1/3, train_loss: 0.4237
# 2/3, train_loss: 0.4247
# 3/3, train_loss: 0.4216
# 4/3, train_loss: 0.4464
# Epoch 481 average loss: 0.4291
# ----------
# Epoch 482/500
# 1/3, train_loss: 0.4325
# 2/3, train_loss: 0.4301
# 3/3, train_loss: 0.4160
# 4/3, train_loss: 0.4205
# Epoch 482 average loss: 0.4248
# current epoch: 482 current mean dice: 0.8147
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 483/500
# 1/3, train_loss: 0.4205
# 2/3, train_loss: 0.4261
# 3/3, train_loss: 0.4341
# 4/3, train_loss: 0.4318
# Epoch 483 average loss: 0.4281
# ----------
# Epoch 484/500
# 1/3, train_loss: 0.4238
# 2/3, train_loss: 0.4436
# 3/3, train_loss: 0.4392
# 4/3, train_loss: 0.4308
# Epoch 484 average loss: 0.4344
# current epoch: 484 current mean dice: 0.8128
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 485/500
# 1/3, train_loss: 0.4250
# 2/3, train_loss: 0.4318
# 3/3, train_loss: 0.4370
# 4/3, train_loss: 0.4227
# Epoch 485 average loss: 0.4291
# ----------
# Epoch 486/500
# 1/3, train_loss: 0.4265
# 2/3, train_loss: 0.4099
# 3/3, train_loss: 0.4381
# 4/3, train_loss: 0.4434
# Epoch 486 average loss: 0.4295
# current epoch: 486 current mean dice: 0.8092
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 487/500
# 1/3, train_loss: 0.4335
# 2/3, train_loss: 0.4277
# 3/3, train_loss: 0.4313
# 4/3, train_loss: 0.4390
# Epoch 487 average loss: 0.4329
# ----------
# Epoch 488/500
# 1/3, train_loss: 0.4443
# 2/3, train_loss: 0.4339
# 3/3, train_loss: 0.4228
# 4/3, train_loss: 0.4211
# Epoch 488 average loss: 0.4305
# current epoch: 488 current mean dice: 0.8087
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 489/500
# 1/3, train_loss: 0.4480
# 2/3, train_loss: 0.4666
# 3/3, train_loss: 0.4170
# 4/3, train_loss: 0.4278
# Epoch 489 average loss: 0.4399
# ----------
# Epoch 490/500
# 1/3, train_loss: 0.4336
# 2/3, train_loss: 0.4337
# 3/3, train_loss: 0.4346
# 4/3, train_loss: 0.4213
# Epoch 490 average loss: 0.4308
# current epoch: 490 current mean dice: 0.8176
# best mean dice: 0.8252 at epoch: 466
# ----------
# Epoch 491/500
# 1/3, train_loss: 0.4339
# 2/3, train_loss: 0.4293
# 3/3, train_loss: 0.4308
# 4/3, train_loss: 0.4253
# Epoch 491 average loss: 0.4298
# ----------
# Epoch 492/500
# 1/3, train_loss: 0.4285
# 2/3, train_loss: 0.4267
# 3/3, train_loss: 0.4286
# 4/3, train_loss: 0.4346
# Epoch 492 average loss: 0.4296
# saved new best metric model
# current epoch: 492 current mean dice: 0.8255
# best mean dice: 0.8255 at epoch: 492
# ----------
# Epoch 493/500
# 1/3, train_loss: 0.4416
# 2/3, train_loss: 0.4225
# 3/3, train_loss: 0.4235
# 4/3, train_loss: 0.4279
# Epoch 493 average loss: 0.4289
# ----------
# Epoch 494/500
# 1/3, train_loss: 0.4426
# 2/3, train_loss: 0.4290
# 3/3, train_loss: 0.4600
# 4/3, train_loss: 0.4321
# Epoch 494 average loss: 0.4409
# current epoch: 494 current mean dice: 0.8219
# best mean dice: 0.8255 at epoch: 492
# ----------
# Epoch 495/500
# 1/3, train_loss: 0.4196
# 2/3, train_loss: 0.4259
# 3/3, train_loss: 0.4107
# 4/3, train_loss: 0.4609
# Epoch 495 average loss: 0.4293
# ----------
# Epoch 496/500
# 1/3, train_loss: 0.4397
# 2/3, train_loss: 0.4260
# 3/3, train_loss: 0.4269
# 4/3, train_loss: 0.4378
# Epoch 496 average loss: 0.4326
# current epoch: 496 current mean dice: 0.8192
# best mean dice: 0.8255 at epoch: 492
# ----------
# Epoch 497/500
# 1/3, train_loss: 0.4297
# 2/3, train_loss: 0.4182
# 3/3, train_loss: 0.4315
# 4/3, train_loss: 0.4151
# Epoch 497 average loss: 0.4237
# ----------
# Epoch 498/500
# 1/3, train_loss: 0.4344
# 2/3, train_loss: 0.4376
# 3/3, train_loss: 0.4346
# 4/3, train_loss: 0.4458
# Epoch 498 average loss: 0.4381
# current epoch: 498 current mean dice: 0.8083
# best mean dice: 0.8255 at epoch: 492
# ----------
# Epoch 499/500
# 1/3, train_loss: 0.4261
# 2/3, train_loss: 0.4261
# 3/3, train_loss: 0.4227
# 4/3, train_loss: 0.4443
# Epoch 499 average loss: 0.4298
# ----------
# Epoch 500/500
# 1/3, train_loss: 0.4399
# 2/3, train_loss: 0.4197
# 3/3, train_loss: 0.4350
# 4/3, train_loss: 0.4292
# Epoch 500 average loss: 0.4310
# current epoch: 500 current mean dice: 0.8080
# best mean dice: 0.8255 at epoch: 492
