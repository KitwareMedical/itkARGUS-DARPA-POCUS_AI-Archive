# %%
from ARGUS_Needle_Network import ARGUS_Needle_Network

# %%
img_dir = "../../Data_PNB/stephen_prep"
anno_dir = "../../Data_PNB/stephen_prep"

# %%
nnet = ARGUS_Needle_Network(use_needle_settings=True)
nnet.results_dirname = "Results-Needle-2022.08.15-Full"
nnet.setup_vfold_files(img_dir, anno_dir)
# Out:
# 6.528864338062704 gibibyte
# 0.01287497766315937 gibibyte
# Num images / labels = 30 30
# 0 [[' 11'], [' 57']]
# 1 [[' 46'], [' 136']]
# 2 [[' 207'], [' 179']]
# 3 [[' 67'], [' 189']]
# 4 [[' 93'], [' 204']]
# 5 [[' 94'], [' 205']]
# 6 [[' 134'], [' 211'], [' 217']]
# 7 [[' 222A'], [' 238'], [' 39']]
# 8 [[' 153'], [' 240'], [' 230']]
# 9 [[' 193'], [' 54'], [' 191']]
# 20 7 3
# 22 6 2
# 23 5 2
# 24 4 2
# 23 4 3
# 23 5 2
# 22 5 3
# 19 5 6
# 17 9 4
# 17 10 3

# %%
nnet.view_metric_curves(vfold_num=0,run_id=0)

# %%
nnet.setup_testing_vfold(vfold_num=2)

# %%
test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0,1], device_num=0)
# Out:
# VFOLD = 2 of 9
# Image: 1. 136 AC_Video 1_cropM_prep.nii.gz
# Image: 2. 46_Video 2_cropM_prep.nii.gz
