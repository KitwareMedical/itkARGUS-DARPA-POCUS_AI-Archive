# %%
import site
site.addsitedir("../ARGUS")

from ARGUS_pnb_ar_train import ARGUS_pnb_ar_train

# %%
nnet = ARGUS_pnb_ar_train("../ARGUS/ARGUS_pnb_ar.cfg", "vfold", device_num=0)
nnet.setup_vfold_files()
# Out:
# Num images / labels = 30 30
# Num pos / Num neg = 16 / 14
# VFold-Prefix[0] = ['p3. 11', 'p5. 15', 'n1. 205', 'n1. 136']
# VFold-Prefix[1] = ['p3. 93', 'p7. 19', 'n5. 191', 'n1. 238']
# VFold-Prefix[2] = ['p3. 23', 'p3. 94', 'n1. 211', 'n1. 189']
# VFold-Prefix[3] = ['p5. 24', 'p4. 22', 'n1. 57 ', 'n1. 179']
# VFold-Prefix[4] = ['p3. 13', 'p3. 67', 'n1. 207']
# VFold-Prefix[5] = ['p3. 21', 'p4. 21', 'n2. 39 ']
# VFold-Prefix[6] = ['p4. 23', 'n1. 134']
# VFold-Prefix[7] = ['p3. 20', 'n2. 46_']
# VFold-Prefix[8] = ['p5. 54', 'n1. 217']
# VFold-Prefix[9] = ['p3. 18', 'n1. 204']

# %%
for f in range(nnet.num_folds):
    nnet.view_training_metric_curves(vfold_num=f, run_id=0)

# %%
nnet.setup_testing_vfold(0)
nnet.view_testing_results_vfold("best",[0])
# Out:
# VFOLD = 0 of 9
# Image: n1. 204 AC Video 1_cropM_prep.mha
# Image: p3. 189 AC_Video 2_cropM_prep.mha
#   Test Mean Dice Score =  0.0
