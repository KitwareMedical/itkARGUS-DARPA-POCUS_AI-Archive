# %%
from ARGUS_taskid import ARGUS_taskid

# %%
nnet = ARGUS_taskid("vfold")
nnet.setup_vfold_files()
# Out:
# PTX : num images = 62
# PNB : num images = 31
# ONS : num images = 25
# ETT : num images = 46
# Total num images = 164
# **** VFold = 0 : 132 16 16
# **** VFold = 1 : 131 16 17
# **** VFold = 2 : 130 17 17
# **** VFold = 3 : 130 17 17
# **** VFold = 4 : 130 17 17
# **** VFold = 5 : 131 17 16
# **** VFold = 6 : 132 16 16
# **** VFold = 7 : 132 16 16
# **** VFold = 8 : 132 16 16
# **** VFold = 9 : 132 16 16

# %%
nnet.view_metric_curves(vfold_num=0,run_id=0)

# %%
nnet.setup_testing_vfold(vfold_num=0)
test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0], device_num=0)
# Out:
# VFOLD = 0 of 9
# VFold 0: Accuracy = 1.0
# Image: PTXNS_image_1404802450036_clean.mha
#    Ideal output = 0
#    Run output (0) = [ 5.805593  -2.2804592 -2.3879533 -1.6296436]
#    Ensemble output = [ 5.80559301 -2.28045917 -2.38795328 -1.62964356]
#    Final output = 0
#
# Image: PNBN_1. 211 AC_Video 1.mha
#    Ideal output = 1
#    Run output (0) = [-3.29786    5.0922246 -1.71669   -1.2016457]
#    Ensemble output = [-3.29785991  5.0922246  -1.71668994 -1.20164573]
#    Final output = 1
#
# Image: ETTP_2. 119A to B_Video.mha
#    Ideal output = 3
#    Run output (0) = [-4.0183682  -2.955359   -0.52275467  5.958377  ]
#    Ensemble output = [-4.01836824 -2.95535898 -0.52275467  5.95837688]
#    Final output = 3
#
# Image: PTXNS_image_1895283541879_clean.mha
#    Ideal output = 0
#    Run output (0) = [ 5.5582004 -1.8899162 -2.4543884 -1.7045232]
#    Ensemble output = [ 5.55820036 -1.88991618 -2.45438838 -1.70452321]
#    Final output = 0
#
# Image: PNBP_3. 93 AC_Video 2.mha
# ...
