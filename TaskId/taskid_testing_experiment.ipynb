# %%
from ARGUS_taskid_train import ARGUS_taskid_train

# %%
nnet = ARGUS_taskid_train("../ARGUS/ARGUS_taskid.cfg", "vfold", 0)
nnet.setup_vfold_files()
# Out:
# PTX : num images = 62
# PNB : num images = 31
# ONS : num images = 25
# ETT : num images = 46
# Total num images = 164
# Num images / labels = 164 164
# **** VFold = 0 : 132 16 16
# **** VFold = 1 : 131 16 17
# **** VFold = 2 : 130 17 17
# **** VFold = 3 : 130 17 17
# **** VFold = 4 : 130 17 17
# **** VFold = 5 : 131 17 16
# **** VFold = 6 : 132 16 16
# **** VFold = 7 : 132 16 16
# **** VFold = 8 : 132 16 16
# **** VFold = 9 : 132 16 16

# %%
nnet.view_metric_curves(vfold_num=0,run_id=0)

# %%
nnet.setup_testing_vfold(vfold_num=0)
test_output = nnet.view_testing_results_vfold(model_type="best", run_ids=[0])
# Out:
# VFOLD = 0 of 9
# VFold 0: Accuracy = 1.0
# Image: ETTP_2. 18A_Video.mha
#    Ideal output = 3
#    Run output (0) = [-3.7058568 -1.7298597 -2.306399   7.3966045]
#    Ensemble output = [0.         0.13648353 0.09666155 0.76685492]
#    Final output = 3
#
# Image: ETTN_13. 99C_Video.mha
#    Ideal output = 3
#    Run output (0) = [-4.162384  -1.9103924 -1.5572032  7.308503 ]
#    Ensemble output = [0.         0.13792158 0.15955237 0.70252605]
#    Final output = 3
#
# Image: PNBP_3. 134 AC_Video 2.mha
#    Ideal output = 1
#    Run output (0) = [-2.4225533   4.850498   -1.975416   -0.59909105]
#    Ensemble output = [0.         0.7620827  0.04685181 0.19106549]
#    Final output = 1
#
# Image: ETTN_6. 99C_Video.mha
#    Ideal output = 3
#    Run output (0) = [-4.065082  -1.2678081 -1.8849087  6.9006577]
#    Ensemble output = [0.         0.17545263 0.13674639 0.68780098]
#    Final output = 3
#
# Image: PTXS_image_104543812690743_CLEAN.mha
#    Ideal output = 0
#    Run output (0) = [ 5.538992  -2.3438087 -1.8207533 -1.4623669]
#    Ensemble output = [0.84877226 0.         0.05631944 0.09490831]
#    Final output = 0
#
# Image: ONSDP_6. 117.1 Left Lat_Video 1.mha
#    Ideal output = 2
#    Run output (0) = [-2.4126644 -2.4811947  6.0005245 -2.0130901]
#    Ensemble output = [0.00759898 0.         0.94049525 0.05190577]
#    Final output = 2
#
# Image: ONSDN_8. 23.1 Left_Lat_Video 2.mha
#    Ideal output = 2
#    Run output (0) = [-3.2565196 -2.4194255  6.5551186 -1.6521208]
#    Ensemble output = [0.         0.06831675 0.8007454  0.13093785]
#    Final output = 2
#
# Image: PTXS_image_1499268364374_clean.mha
#    Ideal output = 0
#    Run output (0) = [ 5.6842475 -1.8662125 -1.8694503 -2.0907102]
#    Ensemble output = [0.94577631 0.02730878 0.02691491 0.        ]
#    Final output = 0
#
# Image: PNBN_1. 189 AC_Video 1.mha
#    Ideal output = 1
#    Run output (0) = [-3.0608459  5.339342  -1.7013924 -1.0663601]
#    Ensemble output = [0.         0.71465861 0.11565754 0.16968386]
#    Final output = 1
#
# Image: PNBP_5. 54 AC_Video 3.mha
#    Ideal output = 1
#    Run output (0) = [-2.6416438  5.7271914 -2.2987235 -1.3143975]
#    Ensemble output = [0.         0.8336322  0.03415881 0.132209  ]
#    Final output = 1
#
# Image: ETTP_2. 161A_Video.mha
#    Ideal output = 3
#    Run output (0) = [-4.3793073 -2.3844848 -1.354887   7.687999 ]
#    Ensemble output = [0.         0.11674812 0.17700592 0.70624596]
#    Final output = 3
#
# Image: PTXS_image_104932526155699_CLEAN.mha
#    Ideal output = 0
#    Run output (0) = [ 5.733274  -2.3188233 -1.9881327 -1.5146838]
#    Ensemble output = [0.87647338 0.         0.03599578 0.08753084]
#    Final output = 0
#
# Image: ONSDP_2. 158.1 Right_Lat_Video 1.mha
#    Ideal output = 2
#    Run output (0) = [-2.7956946 -2.7531009  5.7493525 -0.9403958]
#    Ensemble output = [0.         0.00407871 0.8182607  0.17766059]
#    Final output = 2
#
# Image: ETTP_2. 34A to B_Video.mha
#    Ideal output = 3
#    Run output (0) = [-3.9478524 -2.7430944 -0.7658808  7.0609994]
#    Ensemble output = [0.         0.07825348 0.20668083 0.71506569]
#    Final output = 3
#
# Image: PTXS_image_73815992352100_clean.mha
#    Ideal output = 0
#    Run output (0) = [ 5.4371223 -2.1650465 -1.714535  -1.56812  ]
#    Ensemble output = [0.87890341 0.         0.05208461 0.06901197]
#    Final output = 0
#
# Image: PTXS_image_1901852337971_clean.mha
#    Ideal output = 0
#    Run output (0) = [ 5.733304  -1.9641534 -1.8938584 -1.9355134]
#    Ensemble output = [0.98731015 0.         0.00901635 0.0036735 ]
#    Final output = 0
